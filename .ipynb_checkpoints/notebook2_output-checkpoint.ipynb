# %%
import pandas as pd
import json

dashboard = pd.ExcelFile("data.xlsx")

# %%
data = pd.read_excel(dashboard,"Statistics")

aes = pd.read_excel(dashboard, 'AEs')

referrals = pd.read_excel(dashboard, 'Referrals')

def convert_numeric_text_columns(df):
    for col in df.columns:
        # Check if the column starts with "Shangring"
        if col.startswith('shangring') or col.startswith('sgDisposable')or col.startswith('sgReusable') or col.startswith('total') or col.startswith('hiv') or col.startswith('fu') or col.startswith('referralToOtherServices'):
            # Replace NaN values with 0 in columns starting with "Shangring"
            df[col] = df[col].fillna(0)
        # Use 'and' to check if the column is NOT one of the specified columns
        elif col != 'ReferrelRecordingYear' and col != 'AERecordingYear' and col != 'year':
            # Convert column to numeric if all values are numeric-like strings
            if df[col].astype(str).str.isnumeric().all():
                df[col] = pd.to_numeric(df[col])
    return df

# Assuming 'data' is the DataFrame you want to process
converted_data = convert_numeric_text_columns(data)

# Display the converted data
converted_data
# Out:
#   AERecordingMonth               AERecordingSite  AERecordingYear  \
# 0         December  Gwanyika Rural Health Centre           2024.0
# 1              NaN                           NaN              NaN
# 2         November                    Katema RDC           2024.0
# 3         November                 Jahana Clinic           2024.0
#
#       District ReferrelRecordingMonth         ReferrelRecordingSite  \
# 0  GOKWE SOUTH               December  Gwanyika Rural Health Centre
# 1  GOKWE SOUTH                    NaN                           NaN
# 2  GOKWE SOUTH                    NaN                           NaN
# 3  GOKWE SOUTH                    NaN                           NaN
#
#    ReferrelRecordingYear  TotalMCsBYMethod  \
# 0                 2024.0                37
# 1                    NaN                25
# 2                    NaN                94
# 3                    NaN                80
#
#                                         aeComments ae_classification  ...  \
# 0                                Client is healing            Severe  ...
# 1                                              NaN               NaN  ...
# 2                                Client is healing          Moderate  ...
# 3  Sature elavated  by lignocaine,\nclient healing            Severe  ...
#
#   total_surgicalReusable.4  total_surgicalReusable.5  \
# 0                       OK                         0
# 1                        0                         0
# 2                       OK                         0
# 3                       OK                        OK
#
#    total_surgicalReusable.6  total_surgicalReusable.7  \
# 0                        OK                        OK
# 1                        OK                         0
# 2                        OK                        OK
# 3                        OK                        OK
#
#   total_surgicalReusable.8  totalhivNegative totalhivNegativeNC  \
# 0                        0                37                  0
# 1                        0                25                  0
# 2                        0                13                  0
# 3                       OK                80                  1
#
#   uncircumcisedClientsForHTS  vmmc_number  year
# 0                          0     345534.0  2024
# 1                          0          NaN  2024
# 2                          0     234556.0  2024
# 3                          1     234455.0  2024
#
# [4 rows x 145 columns]

# %%
aes
# Out:
#   AERecordingMonth               AERecordingSite  AERecordingYear  \
# 0         November                  Krima Clinic             2024
# 1         November                  Krima Clinic             2024
# 2         December  Gwanyika Rural Health Centre             2024
# 3         November                    Katema RDC             2024
# 4         November                 Jahana Clinic             2024
#
#       District  cancelthisAEReport  \
# 0  GOKWE SOUTH                 NaN
# 1  GOKWE SOUTH                 NaN
# 2  GOKWE SOUTH                 NaN
# 3  GOKWE SOUTH                 NaN
# 4  GOKWE SOUTH                 NaN
#
#                                         aeComments ae_classification  \
# 0                                   Client healing            Severe
# 1                                   Client healing          Moderate
# 2                                Client is healing            Severe
# 3                                Client is healing          Moderate
# 4  Sature elavated  by lignocaine,\nclient healing            Severe
#
#   ae_type_code circumcising_cadre  client_age date_ae_identified  mcMethod  \
# 0          COA              Nurse          25         2024-11-10  Surgical
# 1           BL              Nurse          18         2024-11-08  Surgical
# 2           BL              Nurse          24         2024-12-12  Surgical
# 3           BL              Nurse          25         2024-11-14  Surgical
# 4          COA              Nurse          24         2024-11-10  Surgical
#
#    vmmc_number
# 0       467233
# 1       245555
# 2       345534
# 3       234556
# 4       234455

# %%
# Ensure Month-Year columns are strings for easy comparison
data['year'] = data['year'].astype(str)
aes['AERecordingYear'] = aes['AERecordingYear'].astype(str)
referrals['ReferrelRecordingYear'] = referrals['ReferrelRecordingYear'].astype(str)


data['recordingMonth'] = data['recordingMonth'].astype(str)
aes['AERecordingMonth'] = aes['AERecordingMonth'].astype(str)
referrals['ReferrelRecordingMonth'] = referrals['ReferrelRecordingMonth'].astype(str)

# Transform df1 to include the list object
json_data = []
data = data.fillna("")
for _, row in data.iterrows():
    row_data = row.to_dict()
    
    if row['totalAES'] >= 1:
        # Filter df2 to find matching rows
        recordedAEs = aes[
            (aes['AERecordingSite'] == row['facilityName']) &
            (aes['AERecordingMonth'] == row['recordingMonth']) &
            (aes['AERecordingYear'] == row['year'])
        ]
        
        # Add list object to the row if matches are found
        row_data['matchingAES'] = recordedAEs.to_dict(orient='records')
    else:
        # Add an empty list if no matches
        row_data['matchingAES'] = []


    if row['referralToOtherServices'] >= 1:
        # Filter df2 to find matching rows
        otherReferrals = referrals[
            (referrals['ReferrelRecordingSite'] == row['facilityName']) &
            (referrals['ReferrelRecordingMonth'] == row['recordingMonth']) &
            (referrals['ReferrelRecordingYear'] == row['year'])
        ]
        
        # Add list object to the row if matches are found
        row_data['otherReferrals'] = otherReferrals.to_dict(orient='records')
    else:
        # Add an empty list if no matches
        row_data['otherReferrals'] = []
    
    # Append to the final JSON structure
    json_data.append(row_data)

# Convert to JSON
result_json = json.dumps(json_data, indent=4)

output_file = "data.json"

# Save the JSON data to the file
with open(output_file, "w") as file:
    json.dump(json_data, file, indent=4)

# Print the JSON
print(result_json)
# Out:
# [
#     {
#         "AERecordingMonth": "December",
#         "AERecordingSite": "Gwanyika Rural Health Centre",
#         "AERecordingYear": 2024.0,
#         "District": "GOKWE SOUTH",
#         "ReferrelRecordingMonth": "December",
#         "ReferrelRecordingSite": "Gwanyika Rural Health Centre",
#         "ReferrelRecordingYear": 2024.0,
#         "TotalMCsBYMethod": 37,
#         "aeComments": "Client is healing",
#         "ae_classification": "Severe",
#         "ae_type_code": "BL",
#         "checkMonthValidation": 1.0,
#         "checkYearValidation": 1.0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": "Nurse",
#         "client_age": 24.0,
#         "date_ae_identified": "2024-12-12",
#         "facilityName": "Gwanyika Rural Health Centre",
#         "followUpTotal": "",
#         "fu15-19": 25,
#         "fu20-24": 12.0,
#         "fu25-29": 0.0,
#         "fu30-34": 0,
#         "fu35-39": 0.0,
#         "fu40-44": 0.0,
#         "fu45-49": 0.0,
#         "fu50": 0.0,
#         "hivNegative15-19": 25,
#         "hivNegative20-24": 12.0,
#         "hivNegative25-29": 0.0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0.0,
#         "hivNegative40-44": 0.0,
#         "hivNegative45-49": 0.0,
#         "hivNegative50": 0.0,
#         "hivNegativeNC15-19": 0.0,
#         "hivNegativeNC20-24": 0.0,
#         "hivNegativeNC25-29": 0.0,
#         "hivNegativeNC30-34": 0.0,
#         "hivNegativeNC35-39": 0.0,
#         "hivNegativeNC40-44": 0.0,
#         "hivNegativeNC45-49": 0.0,
#         "hivNegativeNC50": 0.0,
#         "hivPositive15-19": 0.0,
#         "hivPositive20-24": 0.0,
#         "hivPositive30-34": 0.0,
#         "hivPositiveNC15-19": 0.0,
#         "hivPositiveNC20-24": 0.0,
#         "hivPositiveNC25-29": 0.0,
#         "hivPositiveNC35-39": 0.0,
#         "hivPositiveNC40-44": 0.0,
#         "hivPositiveNC45-49": 0.0,
#         "hivPositiveNC50": 0.0,
#         "mc15-19": 25,
#         "mc20-24": 12,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": 0,
#         "mcMethod": "Surgical",
#         "reason_for_referral": "Client had high fever",
#         "recordingMonth": "December",
#         "recordingMonth.1": "December",
#         "recordingMonth.2": "December",
#         "recordingMonth.3": "December",
#         "referralToOtherServices": 1,
#         "services_referred": "OPD",
#         "sgDisposable15-19": 0,
#         "sgDisposable20-24": 0.0,
#         "sgDisposable25-29": 0.0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0.0,
#         "sgDisposable40-44": 0.0,
#         "sgDisposable45-49": 0.0,
#         "sgDisposable50": 0.0,
#         "sgReusable15-19": 25.0,
#         "sgReusable20-24": 12.0,
#         "sgReusable25-29": 0.0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0.0,
#         "sgReusable40-44": 0.0,
#         "sgReusable45-49": 0.0,
#         "sgReusable50": 0.0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0.0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "total15-19HIVTested": 0.0,
#         "total15-19NCHIVTested": 0.0,
#         "total20-24HIVTested": 0.0,
#         "total20-24NCHIVTested": 0.0,
#         "total25-29HIVTested": 0.0,
#         "total25-29NCHIVTested": 0.0,
#         "total30-34HIVTested": 0.0,
#         "total30-34NCHIVTested": 0.0,
#         "total35-39HIVTested": 0.0,
#         "total35-39NCHIVTested": 0.0,
#         "total40-44HIVTested": 0.0,
#         "total40-44NCHIVTested": 0.0,
#         "total45-49HIVTested": 0.0,
#         "total45-49NCHIVTested": 0.0,
#         "total50ByMethod": 0.0,
#         "total50HIVTested": 0.0,
#         "total50NCHIVTested": 0.0,
#         "totalAES": 1,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 0,
#         "totalMCs": 37,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 0,
#         "totalSurgicalReusableMCs": 37,
#         "total_hiv_negative_linked_to_prep": 12,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 12,
#         "total_mcs_referred_for_sti_services": 12,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalDisposable.1": "OK",
#         "total_surgicalDisposable.2": 0,
#         "total_surgicalDisposable.3": "OK",
#         "total_surgicalDisposable.4": "OK",
#         "total_surgicalDisposable.5": 0,
#         "total_surgicalDisposable.6": "OK",
#         "total_surgicalDisposable.7": "OK",
#         "total_surgicalDisposable.8": 0,
#         "total_surgicalReusable": "OK",
#         "total_surgicalReusable.1": "OK",
#         "total_surgicalReusable.2": 0,
#         "total_surgicalReusable.3": "OK",
#         "total_surgicalReusable.4": "OK",
#         "total_surgicalReusable.5": 0,
#         "total_surgicalReusable.6": "OK",
#         "total_surgicalReusable.7": "OK",
#         "total_surgicalReusable.8": 0,
#         "totalhivNegative": 37,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0,
#         "vmmc_number": 345534.0,
#         "year": "2024",
#         "matchingAES": [
#             {
#                 "AERecordingMonth": "December",
#                 "AERecordingSite": "Gwanyika Rural Health Centre",
#                 "AERecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "cancelthisAEReport": NaN,
#                 "aeComments": "Client is healing",
#                 "ae_classification": "Severe",
#                 "ae_type_code": "BL",
#                 "circumcising_cadre": "Nurse",
#                 "client_age": 24,
#                 "date_ae_identified": "2024-12-12",
#                 "mcMethod": "Surgical",
#                 "vmmc_number": 345534
#             }
#         ],
#         "otherReferrals": [
#             {
#                 "ReferrelRecordingMonth": "December",
#                 "ReferrelRecordingSite": "Gwanyika Rural Health Centre",
#                 "ReferrelRecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "reason_for_referral": "Client had high fever",
#                 "services_referred": "OPD"
#             }
#         ]
#     },
#     {
#         "AERecordingMonth": "",
#         "AERecordingSite": "",
#         "AERecordingYear": "",
#         "District": "GOKWE SOUTH",
#         "ReferrelRecordingMonth": "",
#         "ReferrelRecordingSite": "",
#         "ReferrelRecordingYear": "",
#         "TotalMCsBYMethod": 25,
#         "aeComments": "",
#         "ae_classification": "",
#         "ae_type_code": "",
#         "checkMonthValidation": "",
#         "checkYearValidation": "",
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": "",
#         "client_age": "",
#         "date_ae_identified": "",
#         "facilityName": "Krima Clinic",
#         "followUpTotal": "",
#         "fu15-19": 25,
#         "fu20-24": 0.0,
#         "fu25-29": 0.0,
#         "fu30-34": 0,
#         "fu35-39": 0.0,
#         "fu40-44": 0.0,
#         "fu45-49": 0.0,
#         "fu50": 0.0,
#         "hivNegative15-19": 25,
#         "hivNegative20-24": 0.0,
#         "hivNegative25-29": 0.0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0.0,
#         "hivNegative40-44": 0.0,
#         "hivNegative45-49": 0.0,
#         "hivNegative50": 0.0,
#         "hivNegativeNC15-19": 0.0,
#         "hivNegativeNC20-24": 0.0,
#         "hivNegativeNC25-29": 0.0,
#         "hivNegativeNC30-34": 0.0,
#         "hivNegativeNC35-39": 0.0,
#         "hivNegativeNC40-44": 0.0,
#         "hivNegativeNC45-49": 0.0,
#         "hivNegativeNC50": 0.0,
#         "hivPositive15-19": 0.0,
#         "hivPositive20-24": 0.0,
#         "hivPositive30-34": 0.0,
#         "hivPositiveNC15-19": 0.0,
#         "hivPositiveNC20-24": 0.0,
#         "hivPositiveNC25-29": 0.0,
#         "hivPositiveNC35-39": 0.0,
#         "hivPositiveNC40-44": 0.0,
#         "hivPositiveNC45-49": 0.0,
#         "hivPositiveNC50": 0.0,
#         "mc15-19": 25,
#         "mc20-24": 0,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": 0,
#         "mcMethod": "",
#         "reason_for_referral": "",
#         "recordingMonth": "November",
#         "recordingMonth.1": "November",
#         "recordingMonth.2": "November",
#         "recordingMonth.3": "November",
#         "referralToOtherServices": 2,
#         "services_referred": "",
#         "sgDisposable15-19": 25,
#         "sgDisposable20-24": 0.0,
#         "sgDisposable25-29": 0.0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0.0,
#         "sgDisposable40-44": 0.0,
#         "sgDisposable45-49": 0.0,
#         "sgDisposable50": 0.0,
#         "sgReusable15-19": 0.0,
#         "sgReusable20-24": 0.0,
#         "sgReusable25-29": 0.0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0.0,
#         "sgReusable40-44": 0.0,
#         "sgReusable45-49": 0.0,
#         "sgReusable50": 0.0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0.0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "total15-19HIVTested": 0.0,
#         "total15-19NCHIVTested": 0.0,
#         "total20-24HIVTested": 0.0,
#         "total20-24NCHIVTested": 0.0,
#         "total25-29HIVTested": 0.0,
#         "total25-29NCHIVTested": 0.0,
#         "total30-34HIVTested": 0.0,
#         "total30-34NCHIVTested": 0.0,
#         "total35-39HIVTested": 0.0,
#         "total35-39NCHIVTested": 0.0,
#         "total40-44HIVTested": 0.0,
#         "total40-44NCHIVTested": 0.0,
#         "total45-49HIVTested": 0.0,
#         "total45-49NCHIVTested": 0.0,
#         "total50ByMethod": 0.0,
#         "total50HIVTested": 0.0,
#         "total50NCHIVTested": 0.0,
#         "totalAES": 2,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 0,
#         "totalMCs": 25,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 25,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 2,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalDisposable.1": "OK",
#         "total_surgicalDisposable.2": 0,
#         "total_surgicalDisposable.3": "OK",
#         "total_surgicalDisposable.4": "OK",
#         "total_surgicalDisposable.5": 0,
#         "total_surgicalDisposable.6": "OK",
#         "total_surgicalDisposable.7": "OK",
#         "total_surgicalDisposable.8": 0,
#         "total_surgicalReusable": "OK",
#         "total_surgicalReusable.1": 0,
#         "total_surgicalReusable.2": 0,
#         "total_surgicalReusable.3": "OK",
#         "total_surgicalReusable.4": 0,
#         "total_surgicalReusable.5": 0,
#         "total_surgicalReusable.6": "OK",
#         "total_surgicalReusable.7": 0,
#         "total_surgicalReusable.8": 0,
#         "totalhivNegative": 25,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0,
#         "vmmc_number": "",
#         "year": "2024",
#         "matchingAES": [
#             {
#                 "AERecordingMonth": "November",
#                 "AERecordingSite": "Krima Clinic",
#                 "AERecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "cancelthisAEReport": NaN,
#                 "aeComments": "Client healing",
#                 "ae_classification": "Severe",
#                 "ae_type_code": "COA",
#                 "circumcising_cadre": "Nurse",
#                 "client_age": 25,
#                 "date_ae_identified": "2024-11-10",
#                 "mcMethod": "Surgical",
#                 "vmmc_number": 467233
#             },
#             {
#                 "AERecordingMonth": "November",
#                 "AERecordingSite": "Krima Clinic",
#                 "AERecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "cancelthisAEReport": NaN,
#                 "aeComments": "Client healing",
#                 "ae_classification": "Moderate",
#                 "ae_type_code": "BL",
#                 "circumcising_cadre": "Nurse",
#                 "client_age": 18,
#                 "date_ae_identified": "2024-11-08",
#                 "mcMethod": "Surgical",
#                 "vmmc_number": 245555
#             }
#         ],
#         "otherReferrals": [
#             {
#                 "ReferrelRecordingMonth": "November",
#                 "ReferrelRecordingSite": "Krima Clinic",
#                 "ReferrelRecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "reason_for_referral": "high fever",
#                 "services_referred": "OPD"
#             },
#             {
#                 "ReferrelRecordingMonth": "November",
#                 "ReferrelRecordingSite": "Krima Clinic",
#                 "ReferrelRecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "reason_for_referral": "Client had high BP",
#                 "services_referred": "Hypertensive"
#             }
#         ]
#     },
#     {
#         "AERecordingMonth": "November",
#         "AERecordingSite": "Katema RDC",
#         "AERecordingYear": 2024.0,
#         "District": "GOKWE SOUTH",
#         "ReferrelRecordingMonth": "",
#         "ReferrelRecordingSite": "",
#         "ReferrelRecordingYear": "",
#         "TotalMCsBYMethod": 94,
#         "aeComments": "Client is healing",
#         "ae_classification": "Moderate",
#         "ae_type_code": "BL",
#         "checkMonthValidation": 1.0,
#         "checkYearValidation": 1.0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": "Nurse",
#         "client_age": 25.0,
#         "date_ae_identified": "2024-11-14",
#         "facilityName": "Katema RDC",
#         "followUpTotal": "",
#         "fu15-19": 13,
#         "fu20-24": 15.0,
#         "fu25-29": 18.0,
#         "fu30-34": 0,
#         "fu35-39": 21.0,
#         "fu40-44": 13.0,
#         "fu45-49": 12.0,
#         "fu50": 2.0,
#         "hivNegative15-19": 5,
#         "hivNegative20-24": 0.0,
#         "hivNegative25-29": 2.0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 6.0,
#         "hivNegative40-44": 0.0,
#         "hivNegative45-49": 0.0,
#         "hivNegative50": 0.0,
#         "hivNegativeNC15-19": 0.0,
#         "hivNegativeNC20-24": 0.0,
#         "hivNegativeNC25-29": 0.0,
#         "hivNegativeNC30-34": 0.0,
#         "hivNegativeNC35-39": 0.0,
#         "hivNegativeNC40-44": 0.0,
#         "hivNegativeNC45-49": 0.0,
#         "hivNegativeNC50": 0.0,
#         "hivPositive15-19": 0.0,
#         "hivPositive20-24": 0.0,
#         "hivPositive30-34": 0.0,
#         "hivPositiveNC15-19": 0.0,
#         "hivPositiveNC20-24": 0.0,
#         "hivPositiveNC25-29": 0.0,
#         "hivPositiveNC35-39": 0.0,
#         "hivPositiveNC40-44": 0.0,
#         "hivPositiveNC45-49": 0.0,
#         "hivPositiveNC50": 0.0,
#         "mc15-19": 13,
#         "mc20-24": 15,
#         "mc25-29": 18,
#         "mc30-34": 0,
#         "mc35-39": 21,
#         "mc40-44": 13,
#         "mc45-49": 12,
#         "mc50": 2,
#         "mcMethod": "Surgical",
#         "reason_for_referral": "",
#         "recordingMonth": "November",
#         "recordingMonth.1": "November",
#         "recordingMonth.2": "November",
#         "recordingMonth.3": "November",
#         "referralToOtherServices": 2,
#         "services_referred": "",
#         "sgDisposable15-19": 0,
#         "sgDisposable20-24": 0.0,
#         "sgDisposable25-29": 0.0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0.0,
#         "sgDisposable40-44": 0.0,
#         "sgDisposable45-49": 0.0,
#         "sgDisposable50": 0.0,
#         "sgReusable15-19": 13.0,
#         "sgReusable20-24": 15.0,
#         "sgReusable25-29": 18.0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 21.0,
#         "sgReusable40-44": 13.0,
#         "sgReusable45-49": 12.0,
#         "sgReusable50": 2.0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0.0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "total15-19HIVTested": 5.0,
#         "total15-19NCHIVTested": 0.0,
#         "total20-24HIVTested": 0.0,
#         "total20-24NCHIVTested": 0.0,
#         "total25-29HIVTested": 4.0,
#         "total25-29NCHIVTested": 0.0,
#         "total30-34HIVTested": 0.0,
#         "total30-34NCHIVTested": 0.0,
#         "total35-39HIVTested": 8.0,
#         "total35-39NCHIVTested": 0.0,
#         "total40-44HIVTested": 0.0,
#         "total40-44NCHIVTested": 0.0,
#         "total45-49HIVTested": 0.0,
#         "total45-49NCHIVTested": 0.0,
#         "total50ByMethod": 0.0,
#         "total50HIVTested": 0.0,
#         "total50NCHIVTested": 0.0,
#         "totalAES": 1,
#         "totalHIVPositive": 4,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 77,
#         "totalMCs": 94,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 0,
#         "totalSurgicalReusableMCs": 94,
#         "total_hiv_negative_linked_to_prep": 6,
#         "total_hiv_positive_linked_to_care": 4,
#         "total_mcs_referred_for_srh_services": 5,
#         "total_mcs_referred_for_sti_services": 2,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalDisposable.1": "OK",
#         "total_surgicalDisposable.2": 0,
#         "total_surgicalDisposable.3": "OK",
#         "total_surgicalDisposable.4": "OK",
#         "total_surgicalDisposable.5": 0,
#         "total_surgicalDisposable.6": "OK",
#         "total_surgicalDisposable.7": "OK",
#         "total_surgicalDisposable.8": 0,
#         "total_surgicalReusable": "OK",
#         "total_surgicalReusable.1": "OK",
#         "total_surgicalReusable.2": 0,
#         "total_surgicalReusable.3": "OK",
#         "total_surgicalReusable.4": "OK",
#         "total_surgicalReusable.5": 0,
#         "total_surgicalReusable.6": "OK",
#         "total_surgicalReusable.7": "OK",
#         "total_surgicalReusable.8": 0,
#         "totalhivNegative": 13,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0,
#         "vmmc_number": 234556.0,
#         "year": "2024",
#         "matchingAES": [
#             {
#                 "AERecordingMonth": "November",
#                 "AERecordingSite": "Katema RDC",
#                 "AERecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "cancelthisAEReport": NaN,
#                 "aeComments": "Client is healing",
#                 "ae_classification": "Moderate",
#                 "ae_type_code": "BL",
#                 "circumcising_cadre": "Nurse",
#                 "client_age": 25,
#                 "date_ae_identified": "2024-11-14",
#                 "mcMethod": "Surgical",
#                 "vmmc_number": 234556
#             }
#         ],
#         "otherReferrals": [
#             {
#                 "ReferrelRecordingMonth": "November",
#                 "ReferrelRecordingSite": "Katema RDC",
#                 "ReferrelRecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "reason_for_referral": "Client had  severe fever",
#                 "services_referred": "OPD"
#             },
#             {
#                 "ReferrelRecordingMonth": "November",
#                 "ReferrelRecordingSite": "Katema RDC",
#                 "ReferrelRecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "reason_for_referral": NaN,
#                 "services_referred": NaN
#             }
#         ]
#     },
#     {
#         "AERecordingMonth": "November",
#         "AERecordingSite": "Jahana Clinic",
#         "AERecordingYear": 2024.0,
#         "District": "GOKWE SOUTH",
#         "ReferrelRecordingMonth": "",
#         "ReferrelRecordingSite": "",
#         "ReferrelRecordingYear": "",
#         "TotalMCsBYMethod": 80,
#         "aeComments": "Sature elavated  by lignocaine,\nclient healing",
#         "ae_classification": "Severe",
#         "ae_type_code": "COA",
#         "checkMonthValidation": 1.0,
#         "checkYearValidation": 1.0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": "Nurse",
#         "client_age": 24.0,
#         "date_ae_identified": "2024-11-10",
#         "facilityName": "Jahana Clinic",
#         "followUpTotal": "",
#         "fu15-19": 25,
#         "fu20-24": 12.0,
#         "fu25-29": 15.0,
#         "fu30-34": 0,
#         "fu35-39": 22.0,
#         "fu40-44": 0.0,
#         "fu45-49": 0.0,
#         "fu50": 0.0,
#         "hivNegative15-19": 28,
#         "hivNegative20-24": 12.0,
#         "hivNegative25-29": 15.0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 25.0,
#         "hivNegative40-44": 0.0,
#         "hivNegative45-49": 0.0,
#         "hivNegative50": 0.0,
#         "hivNegativeNC15-19": 1.0,
#         "hivNegativeNC20-24": 0.0,
#         "hivNegativeNC25-29": 0.0,
#         "hivNegativeNC30-34": 0.0,
#         "hivNegativeNC35-39": 0.0,
#         "hivNegativeNC40-44": 0.0,
#         "hivNegativeNC45-49": 0.0,
#         "hivNegativeNC50": 0.0,
#         "hivPositive15-19": 0.0,
#         "hivPositive20-24": 0.0,
#         "hivPositive30-34": 0.0,
#         "hivPositiveNC15-19": 0.0,
#         "hivPositiveNC20-24": 0.0,
#         "hivPositiveNC25-29": 0.0,
#         "hivPositiveNC35-39": 0.0,
#         "hivPositiveNC40-44": 0.0,
#         "hivPositiveNC45-49": 0.0,
#         "hivPositiveNC50": 0.0,
#         "mc15-19": 28,
#         "mc20-24": 12,
#         "mc25-29": 15,
#         "mc30-34": 0,
#         "mc35-39": 25,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": 0,
#         "mcMethod": "Surgical",
#         "reason_for_referral": "",
#         "recordingMonth": "November",
#         "recordingMonth.1": "November",
#         "recordingMonth.2": "November",
#         "recordingMonth.3": "November",
#         "referralToOtherServices": 0,
#         "services_referred": "",
#         "sgDisposable15-19": 0,
#         "sgDisposable20-24": 0.0,
#         "sgDisposable25-29": 0.0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0.0,
#         "sgDisposable40-44": 0.0,
#         "sgDisposable45-49": 0.0,
#         "sgDisposable50": 0.0,
#         "sgReusable15-19": 28.0,
#         "sgReusable20-24": 12.0,
#         "sgReusable25-29": 15.0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 22.0,
#         "sgReusable40-44": 0.0,
#         "sgReusable45-49": 0.0,
#         "sgReusable50": 0.0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 3.0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "total15-19HIVTested": 0.0,
#         "total15-19NCHIVTested": 1.0,
#         "total20-24HIVTested": 0.0,
#         "total20-24NCHIVTested": 0.0,
#         "total25-29HIVTested": 0.0,
#         "total25-29NCHIVTested": 0.0,
#         "total30-34HIVTested": 0.0,
#         "total30-34NCHIVTested": 0.0,
#         "total35-39HIVTested": 0.0,
#         "total35-39NCHIVTested": 0.0,
#         "total40-44HIVTested": 0.0,
#         "total40-44NCHIVTested": 0.0,
#         "total45-49HIVTested": 0.0,
#         "total45-49NCHIVTested": 0.0,
#         "total50ByMethod": 0.0,
#         "total50HIVTested": 0.0,
#         "total50NCHIVTested": 0.0,
#         "totalAES": 1,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 0,
#         "totalMCs": 80,
#         "totalShangringMCs": 3,
#         "totalSurgicalDisposableMCs": 0,
#         "totalSurgicalReusableMCs": 77,
#         "total_hiv_negative_linked_to_prep": 25,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 8,
#         "total_mcs_referred_for_sti_services": 15,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalDisposable.1": "OK",
#         "total_surgicalDisposable.2": "OK",
#         "total_surgicalDisposable.3": "OK",
#         "total_surgicalDisposable.4": "OK",
#         "total_surgicalDisposable.5": "OK",
#         "total_surgicalDisposable.6": "OK",
#         "total_surgicalDisposable.7": "OK",
#         "total_surgicalDisposable.8": "OK",
#         "total_surgicalReusable": "OK",
#         "total_surgicalReusable.1": "OK",
#         "total_surgicalReusable.2": "OK",
#         "total_surgicalReusable.3": "OK",
#         "total_surgicalReusable.4": "OK",
#         "total_surgicalReusable.5": "OK",
#         "total_surgicalReusable.6": "OK",
#         "total_surgicalReusable.7": "OK",
#         "total_surgicalReusable.8": "OK",
#         "totalhivNegative": 80,
#         "totalhivNegativeNC": 1,
#         "uncircumcisedClientsForHTS": 1,
#         "vmmc_number": 234455.0,
#         "year": "2024",
#         "matchingAES": [
#             {
#                 "AERecordingMonth": "November",
#                 "AERecordingSite": "Jahana Clinic",
#                 "AERecordingYear": "2024",
#                 "District": "GOKWE SOUTH",
#                 "cancelthisAEReport": NaN,
#                 "aeComments": "Sature elavated  by lignocaine,\nclient healing",
#                 "ae_classification": "Severe",
#                 "ae_type_code": "COA",
#                 "circumcising_cadre": "Nurse",
#                 "client_age": 24,
#                 "date_ae_identified": "2024-11-10",
#                 "mcMethod": "Surgical",
#                 "vmmc_number": 234455
#             }
#         ],
#         "otherReferrals": []
#     }
# ]
