# %%
import papermill as pm

# %%
# Execute the first notebook
pm.execute_notebook("CommcareAPI.ipynb", "notebook1_output.ipynb")

# Execute the second notebook
pm.execute_notebook("dataOrganisation.ipynb", "notebook2_output.ipynb")
# Out:
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# Executing:   0%|          | 0/5 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'ac9a49fc-8055-46c0-aa30-4b2ae7a7b6de',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-25T12:07:02.595958',
#      'end_time': '2024-12-25T12:07:03.829016',
#      'duration': 1.233058,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-25T12:07:02.595958Z',
#      'iopub.execute_input': '2024-12-25T12:07:02.595958Z',
#      'shell.execute_reply': '2024-12-25T12:07:03.829016Z',
#      'iopub.status.idle': '2024-12-25T12:07:03.829016Z'}},
#    'outputs': [],
#    'source': 'import pandas as pd\nimport json\n\ndashboard = pd.ExcelFile("data.xlsx")'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'id': '05354aa1-7dab-4a33-828a-e4e2f2a0422a',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-25T12:07:03.829016',
#      'end_time': '2024-12-25T12:07:03.902761',
#      'duration': 0.073745,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-25T12:07:03.838523Z',
#      'iopub.execute_input': '2024-12-25T12:07:03.838523Z',
#      'iopub.status.idle': '2024-12-25T12:07:03.902761Z',
#      'shell.execute_reply': '2024-12-25T12:07:03.902761Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '  AERecordingMonth               AERecordingSite  AERecordingYear  \\\n0              NaN                           NaN              NaN   \n1         December  Gwanyika Rural Health Centre           2024.0   \n2              NaN                           NaN              NaN   \n3         November                    Katema RDC           2024.0   \n4         November                 Jahana Clinic           2024.0   \n5              NaN                           NaN              NaN   \n6         November                  Huchu Clinic           2024.0   \n\n      District ReferrelRecordingMonth          ReferrelRecordingSite  \\\n0  GOKWE SOUTH               December  Gokwe South District Hospital   \n1  GOKWE SOUTH               December   Gwanyika Rural Health Centre   \n2  GOKWE SOUTH                    NaN                            NaN   \n3  GOKWE SOUTH                    NaN                            NaN   \n4  GOKWE SOUTH                    NaN                            NaN   \n5  GOKWE SOUTH                    NaN                            NaN   \n6  GOKWE SOUTH               November                   Huchu Clinic   \n\n   ReferrelRecordingYear                           Site_Name  \\\n0                 2024.0  GOKWE - 100513 - DISTRICT HOSPITAL   \n1                 2024.0  GOKWE - 100513 - DISTRICT HOSPITAL   \n2                    NaN  GOKWE - 100513 - DISTRICT HOSPITAL   \n3                    NaN  GOKWE - 100513 - DISTRICT HOSPITAL   \n4                    NaN  GOKWE - 100513 - DISTRICT HOSPITAL   \n5                    NaN  GOKWE - 100513 - DISTRICT HOSPITAL   \n6                 2024.0  GOKWE - 100513 - DISTRICT HOSPITAL   \n\n   TotalMCsBYMethod                                       aeComments  ...  \\\n0                73                                              NaN  ...   \n1                37                                Client is healing  ...   \n2                25                                              NaN  ...   \n3                94                                Client is healing  ...   \n4                80  Sature elavated  by lignocaine,\\nclient healing  ...   \n5                35                                              NaN  ...   \n6                60                                Client is healing  ...   \n\n  total_surgicalReusable.5 total_surgicalReusable.6  total_surgicalReusable.7  \\\n0                        0                       OK                        OK   \n1                        0                       OK                        OK   \n2                        0                       OK                         0   
td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>November</td>\n      <td>Jahana Clinic</td>\n      <td>2024.0</td>\n      <td>GOKWE SOUTH</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>GOKWE - 100513 - DISTRICT HOSPITAL</td>\n      <td>80</td>\n      <td>Sature elavated  by lignocaine,\\nclient healing</td>\n      <td>...</td>\n      <td>OK</td>\n      <td>OK</td>\n      <td>OK</td>\n      <td>OK</td>\n      <td>80</td>\n      <td>1</td>\n      <td>1</td>\n      <td>234455.0</td>\n      <td>2024</td>\n      <td>Outreach</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>GOKWE SOUTH</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>GOKWE - 100513 - DISTRICT HOSPIT ...
#      'execution_count': 2}],
#    'source': 'data = pd.read_excel(dashboard,"Statistics")\n\naes = pd.read_excel(dashboard, \'AEs\')\n\nreferrals = pd.read_excel(dashboard, \'Referrals\')\n\ndef convert_numeric_text_columns(df):\n    for col in df.columns:\n        # Check if the column starts with "Shangring"\n        if col.startswith(\'shangring\') or col.startswith(\'sgDisposable\')or col.startswith(\'sgReusable\') or col.startswith(\'total\') or col.startswith(\'hiv\') or col.startswith(\'fu\') or col.startswith(\'referralToOtherServices\'):\n            # Replace NaN values with 0 in columns starting with "Shangring"\n            df[col] = df[col].fillna(0)\n        # Use \'and\' to check if the column is NOT one of the specified columns\n        elif col != \'ReferrelRecordingYear\' and col != \'AERecordingYear\' and col != \'year\':\n            # Convert column to numeric if all values are numeric-like strings\n            if df[col].astype(str).str.isnumeric().all():\n                df[col] = pd.to_numeric(df[col])\n    return df\n\n# Assuming \'data\' is the DataFrame you want to process\nconverted_data = convert_numeric_text_columns(data)\n\n# Display the converted data\nconverted_data\n'},
#   {'cell_type': 'code',
#    'execution_count': 3,
#    'id': 'd832cd9b-a598-4eab-96f4-9fae55a2f74a',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-25T12:07:03.910778',
#      'end_time': '2024-12-25T12:07:03.939571',
#      'duration': 0.028793,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-12-25T12:07:03.916840Z',
#      'iopub.execute_input': '2024-12-25T12:07:03.916840Z',
#      'shell.execute_reply': '2024-12-25T12:07:03.936496Z',
#      'iopub.status.idle': '2024-12-25T12:07:03.937523Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '  AERecordingMonth               AERecordingSite  AERecordingYear  \\\n0         November                  Krima Clinic             2024   \n1         November                  Krima Clinic             2024   \n2         December  Gwanyika Rural Health Centre             2024   \n3         November                    Katema RDC             2024   \n4         November                 Jahana Clinic             2024   \n5         November                  Huchu Clinic             2024   \n\n      District  cancelthisAEReport  \\\n0  GOKWE SOUTH                 NaN   \n1  GOKWE SOUTH                 NaN   \n2  GOKWE SOUTH                 NaN   \n3  GOKWE SOUTH                 NaN   \n4  GOKWE SOUTH                 NaN   \n5  GOKWE SOUTH                 NaN   \n\n                                        aeComments ae_classification  \\\n0                                   Client healing            Severe   \n1                                   Client healing          Moderate   \n2                                Client is healing            Severe   \n3                                Client is healing          Moderate   \n4  Sature elavated  by lignocaine,\\nclient healing            Severe   \n5                                Client is healing          Moderate   \n\n  ae_type_code circumcising_cadre  client_age date_ae_identified  mcMethod  \\\n0          COA              Nurse          25         2024-11-10  Surgical   \n1           BL              Nurse          18         2024-11-08  Surgical   \n2           BL              Nurse          24         2024-12-12  Surgical   \n3           BL              Nurse          25         2024-11-14  Surgical   \n4          COA              Nurse          24         2024-11-10  Surgical   \n5          SSE              Nurse          55         2024-11-05  Surgical   \n\n   vmmc_number  \n0       467233  \n1       245555  \n2       345534  \n3       234556  \n4       234455  \n5           56  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th
",\n        "ae_classification": "",\n        "ae_type_code": "",\n        "checkMonthValidation": "",\n        "checkYearValidation": "",\n        "checkifFacilityHasBeenSaved": 0,\n        "circumcising_cadre": "",\n        "client_age": "",\n        "date_ae_identified": "",\n        "facilityName": "Gokwe South District Hospital",\n        "followUpTotal": "",\n        "fu15-19": 25,\n        "fu20-24": 15.0,\n        "fu25-29": 19.0,\n        "fu30-34": 14.0,\n        "fu35-39": 0.0,\n        "fu40-44": 0.0,\n        "fu45-49": 0.0,\n        "fu50": 0.0,\n        "hivNegative15-19": 25,\n        "hivNegative20-24": 15.0,\n        "hivNegative25-29": 15.0,\n        "hivNegative30-34": 14.0,\n        "hivNegative35-39": 0.0,\n        "hivNegative40-44": 0.0,\n        "hivNegative45-49": 0.0,\n        "hivNegative50": 0.0,\n        "hivNegativeNC15-19": 0.0,\n        "hivNegativeNC20-24": 0.0,\n        "hivNegativeNC25-29": 0.0,\n        "hivNegativeNC30-34": 0.0,\n        "hivNegativeNC35-39": 0.0,\n        "hivNegativeNC40-44": 0.0,\n        "hivNegativeNC45-49": 0.0,\n        "hivNegativeNC50": 0.0,\n        "hivPositive15-19": 0.0,\n        "hivPositive20-24": 0.0,\n        "hivPositive25-29": 1.0,\n        "hivPositive30-34": 0.0,\n        "hivPositive35-39": 0.0,\n        "hivPositive40-44": 0.0,\n        "hivPositive45-49": 0.0,\n        "hivPositive50": 0.0,\n        "hivPositiveNC15-19": 0.0,\n        "hivPositiveNC20-24": 0.0,\n        "hivPositiveNC25-29": 0.0,\n        "hivPositiveNC35-39": 0.0,\n        "hivPositiveNC40-44": 0.0,\n        "hivPositiveNC45-49": 0.0,\n        "hivPositiveNC50": 0.0,\n        "mc15-19": 25,\n        "mc20-24": 15,\n        "mc25-29": 19,\n        "mc30-34": 14,\n        "mc35-39": 0,\n        "mc40-44": 0,\n        "mc45-49": 0,\n        "mc50": 0,\n        "mcMethod": "",\n        "reason_for_referral": "Client had elavated BP",\n        "recordingMonth": "December",\n        "recordingMonth.1": "December",\n        "recordingMonth.2": "December",\n        "recordingMonth.3": "December",\n        "referralToOtherServices": 1,\n        "services_referred": "Hypertensive",\n        "sgDisposable15-19": 25,\n        "sgDisposable20-24": 15.0,\n        "sgDisposable25-29": 19.0,\n        "sgDisposable30-34": 12.0,\n        "sgDisposable35-39": 0.0,\n        "sgDisposable40-44": 0.0,\n        "sgDisposable45-49": 0.0,\n        "sgDisposable50": 0.0,\n        "sgReusable15-19": 0.0,\n        "sgReusable20-24": 0.0,\n        "sgReusable25-29": 0.0,\n        "sgReusable30-34": 0.0,\n        "sgReusable35-39": 0.0,\n        "sgReusable40-44": 0.0,\n        "sgReusable45-49": 0.0,\n        "sgReusable50": 0.0,\n        "shangring15-19": 0.0,\n        "shangring20-24": 0.0,\n        "shangring25-29": 0.0,\n        "shangring30-34": 2.0,\n        "shangring35-39": 0.0,\n        "shangring40-44": 0.0,\n        "shangring45-49": 0.0,\n        "shangring50": 0,\n        "total15-19HIVTested": 0.0,\n        "total15-19NCHIVTested": 0.0,\n        "total20-24HIVTested": 0.0,\n        "total20-24NCHIVTested": 0.0,\n        "total25-29HIVTested": 16.0,\n        "total25-29NCHIVTested": 0.0,\n        "total30-34HIVTested": 0.0,\n        "total30-34NCHIVTested": 0.0,\n        "total35-39HIVTested": 0.0,\n        "total35-39NCHIVTested": 0.0,\n        "total40-44HIVTested": 0.0,\n        "total40-44NCHIVTested": 0.0,\n        "total45-49HIVTested": 0.0,\n        "total45-49NCHIVTested": 0.0,\n        "total50ByMethod": 0.0,\n        "total50HIVTested": 0.0,\n        "total50NCHIVTes ...
#    'source': '# Ensure Month-Year columns are strings for easy comparison\ndata[\'year\'] = data[\'year\'].astype(str)\naes[\'AERecordingYear\'] = aes[\'AERecordingYear\'].astype(str)\nreferrals[\'ReferrelRecordingYear\'] = referrals[\'ReferrelRecordingYear\'].astype(str)\n\n\ndata[\'recordingMonth\'] = data[\'recordingMonth\'].astype(str)\naes[\'AERecordingMonth\'] = aes[\'AERecordingMonth\'].astype(str)\nreferrals[\'ReferrelRecordingMonth\'] = referrals[\'ReferrelRecordingMonth\'].astype(str)\n\n# Transform df1 to include the list object\njson_data = []\ndata = data.fillna("")\nfor _, row in data.iterrows():\n    row_data = row.to_dict()\n    \n    if row[\'totalAES\'] >= 1:\n        # Filter df2 to find matching rows\n        recordedAEs = aes[\n            (aes[\'AERecordingSite\'] == row[\'facilityName\']) &\n            (aes[\'AERecordingMonth\'] == row[\'recordingMonth\']) &\n            (aes[\'AERecordingYear\'] == row[\'year\'])\n        ]\n        \n        # Add list object to the row if matches are found\n        row_data[\'matchingAES\'] = recordedAEs.to_dict(orient=\'records\')\n    else:\n        # Add an empty list if no matches\n        row_data[\'matchingAES\'] = []\n\n\n    if row[\'referralToOtherServices\'] >= 1:\n        # Filter df2 to find matching rows\n        otherReferrals = referrals[\n            (referrals[\'ReferrelRecordingSite\'] == row[\'facilityName\']) &\n            (referrals[\'ReferrelRecordingMonth\'] == row[\'recordingMonth\']) &\n            (referrals[\'ReferrelRecordingYear\'] == row[\'year\'])\n        ]\n        \n        # Add list object to the row if matches are found\n        row_data[\'otherReferrals\'] = otherReferrals.to_dict(orient=\'records\')\n    else:\n        # Add an empty list if no matches\n        row_data[\'otherReferrals\'] = []\n    \n    # Append to the final JSON structure\n    json_data.append(row_data)\n\n# Convert to JSON\nresult_json = json.dumps(json_data, indent=4)\n\noutput_file = "data.json"\n\n# Save the JSON data to the file\nwith open(output_file, "w") as file:\n    json.dump(json_data, file, indent=4)\n\n# Print the JSON\nprint(result_json)'},
#   {'cell_type': 'code',
#    'execution_count': None,
#    'id': '298c3871-01b3-4d5c-a9ce-1e0d7fbe5cd4',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-12-25T12:07:03.996937',
#      'end_time': '2024-12-25T12:07:03.996937',
#      'duration': 0.0,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': ''}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3 (ipykernel)',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.12.7',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'default_parameters': {},
#    'parameters': {},
#    'environment_variables': {},
#    'version': '2.6.0',
#    'input_path': 'dataOrganisation.ipynb',
#    'output_path': 'notebook2_output.ipynb',
#    'start_time': '2024-12-25T12:07:00.599848',
#    'end_time': '2024-12-25T12:07:04.246920',
#    'duration': 3.647072,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 5}
