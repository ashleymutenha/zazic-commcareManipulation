# %%
import papermill as pm

# %%
# Execute the first notebook
pm.execute_notebook("CommcareAPI.ipynb", "notebook1_output.ipynb")

# Execute the second notebook
pm.execute_notebook("dataOrganisation.ipynb", "notebook2_output.ipynb")
# Out:
# ...
# Executing:   0%|          | 0/3 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': '05354aa1-7dab-4a33-828a-e4e2f2a0422a',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2025-01-14T08:09:12.404639',
#      'end_time': '2025-01-14T08:09:12.794356',
#      'duration': 0.389717,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2025-01-14T08:09:12.404639Z',
#      'iopub.execute_input': '2025-01-14T08:09:12.404639Z',
#      'iopub.status.idle': '2025-01-14T08:09:12.794356Z',
#      'shell.execute_reply': '2025-01-14T08:09:12.794356Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
# ...
