# %%
import pandas as pd
from commcare_export.checkpoint import CheckpointManagerWithDetails
from commcare_export.commcare_hq_client import CommCareHqClient, AUTH_MODE_APIKEY
from commcare_export.commcare_minilinq import get_paginator, PaginationMode
from datetime import datetime
import re

# CommCare credentials
username = 'amutenha@zimttech.org'  # Replace with your actual CommCare username
domain = 'zdip-qa'  # Your CommCare project domain
hq_host = 'https://zdip.zimttech.org'  # Your CommCare HQ custom host
API_KEY = '548bb49381030201a991d1e801a2a6fb1332b5f5'  # Replace with the API key generated in CommCare


zazicSites= pd.read_excel('zazicFacilities.xlsx')
# Initialize API client
api_client = CommCareHqClient(hq_host, domain, username, API_KEY, AUTH_MODE_APIKEY)

# Create a paginator for the 'form' resource (fetching data from a form)
form_paginator = get_paginator(resource='form', pagination_mode=PaginationMode.date_modified, page_size=100)
form_paginator.init()

# Initialize checkpoint manager (None used here for simplicity)
checkpoint_manager = CheckpointManagerWithDetails(None, None, PaginationMode.date_modified)

# Date range for filtering
start_date = datetime(2024, 10,6)  # 2 December 2024
end_date = datetime(2025, 1, 8)  # 6 December 2024

# Specify the app_id to filter forms
desired_app_id ='cbd88c81d5a9131517e106028f0dd680'  

# Initialize lists to store categorized data
referrals_data = []
AEs_data = []
general_data = []

# Fetch forms iteratively
# Fetch forms using manual pagination
all_forms = []
offset = 0
while True:
    forms = api_client.iterate(
        'form',
        form_paginator,
        checkpoint_manager=checkpoint_manager,
        params={'limit': 100, 'offset': offset}  # Adjust offset manually
    )
    
    batch = list(forms)  # Fetch current batch of forms
    if not batch:  # Break if no more forms
        break
    
    all_forms.extend(batch)
    offset += 100  # Move to the next page

    # Optional: Stop after collecting 100 submissions for testing
    if len(all_forms) >= 100:
        break






filteredResults =[]
for i in all_forms:
    if i["app_id"] ==desired_app_id:
        filteredResults.append(i)

print(filteredResults)
# Filter and categorize forms by app_id and date
for form in forms:
    if form.get('app_id') == desired_app_id:
        print(form)
        form_received_date = datetime.strptime(form['received_on'], "%Y-%m-%dT%H:%M:%S.%fZ")
        if start_date <= form_received_date <= end_date:
            general_data.append(form)
# Convert each list to a pandas DataFrame
general_df = pd.json_normalize(general_data)
general_df.to_excel('test.xlsx')

general_df.columns = [re.split(r'[./]', col)[-1] for col in general_df.columns]

# New columns that should NOT be deleted
columns_to_retain = [
    'AERecordingMonth', 'AERecordingSite', 'AERecordingYear', 'aeComments', 'ae_classification', 
    'ae_type_code', 'checkMonthValidation', 'checkYearValidation', 'circumcising_cadre', 'client_age', 
    'date_ae_identified', 'mcMethod', 'vmmc_number', 'followUpTotal', 'recordingMonth', 
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'reason_for_referral', 'services_referred', 'facilityName', 
    'District', 'recordingMonth', 'year', 'totalAES','adverse_events', 'Site_Name', 'totalReferralstoOtherServices'
]

# Columns that must be numeric (including the new ones)
numeric_columns = [
    'client_age', 'fu15-19', 'fu20-24', 'fu25-29', 'fu30-34', 'fu40-44', 'fu50',
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'referralToOtherServices',
    'total_mcs_referred_for_srh_services', 'total_mcs_referred_for_sti_services', 'checkifFacilityHasBeenSaved',
    'hivNegativeNC15-19', 'hivNegativeNC20-24', 'hivNegativeNC25-29', 'hivNegativeNC30-34', 'hivNegativeNC35-39', 
    'hivNegativeNC40-44', 'hivNegativeNC45-49', 'hivNegativeNC50', 'total_surgicalDisposable', 'hivPositive30-34',
    'hivPositiveNC15-19', 'hivPositiveNC20-24', 'hivPositiveNC25-29', 'hivPositiveNC35-39', 'hivPositiveNC40-44',
    'hivPositiveNC45-49', 'hivPositiveNC50', 'total15-19NCHIVTested', 'total20-24NCHIVTested', 'total25-29NCHIVTested',
    'total30-34NCHIVTested', 'total35-39NCHIVTested', 'total40-44NCHIVTested', 'total45-49NCHIVTested', 
    'total50NCHIVTested', 'total_surgicalReusable', 'totalHIVPositiveNC', 'totalhivNegativeNC', 
    'uncircumcisedClientsForHTS', 'hivNegative15-19', 'hivNegative20-24', 'hivNegative25-29', 'hivNegative30-34', 
    'hivNegative40-44', 'hivNegative50', 'total_surgicalDisposable', 'hivPositive15-19', 'hivPositive20-24','hivPositive25-29',
    'hivPositive30-34','hivPositive35-39','hivPositive40-44','hivPositive45-49','hivPositive50',
    'total15-19HIVTested', 'total20-24HIVTested', 'total25-29HIVTested', 'total30-34HIVTested', 'total35-39HIVTested',
    'total40-44HIVTested', 'total45-49HIVTested', 'total50HIVTested', 'total_surgicalReusable', 'totalHIVPositive',
    'totalHIVUntested', 'totalhivNegative', 'TotalMCsBYMethod', 'sgDisposable15-19', 'sgDisposable20-24', 
    'sgDisposable25-29', 'sgDisposable30-34', 'sgDisposable40-44', 'sgDisposable50', 'total_surgicalDisposable',
    'sgReusable15-19', 'sgReusable20-24', 'sgReusable25-29', 'sgReusable30-34', 'sgReusable40-44', 'sgReusable50',
    'total_surgicalReusable', 'total50ByMethod', 'totalShangringMCs', 'totalSurgicalDisposableMCs', 
    'totalSurgicalReusableMCs', 'mc15-19', 'mc20-24', 'mc25-29', 'mc30-34', 'mc35-39', 'mc40-44', 'mc45-49', 
    'mc50', 'totalMCs', 'fu35-39', 'other_referrals_in_detail', 'total_mcs_referred_to_other_services', 
    'hivNegative35-39', 'sgDisposable35-39', 'sgReusable35-39', 'shangring15-19', 'shangring20-24','shangring25-29', 'shangring30-34',
    'shangring35-39', 'shangring40-44','shangring45-49','shangring50', 'fu45-49', 
    'hivNegative45-49', 'sgDisposable45-49', 'sgReusable45-49','AERecordingYear','kp_referrals_to_care'
]

# general_df['AERecordingYear'] = pd.to_numeric(general_df['AERecordingYear'])
# Combine the two lists (retain columns that are in either columns_to_retain or numeric_columns)
columns_to_keep = list(set(columns_to_retain + numeric_columns))

# Identify missing columns
missing_columns = [col for col in columns_to_keep if col not in general_df.columns]

# Add missing columns to the DataFrame and assign zero
for col in missing_columns:
    general_df[col] = 0

# Drop the columns that are not in the columns_to_keep list
# Sort the columns alphabetically in both DataFrames

# For the 'general_df', sort the columns alphabetically
general_df_sorted = general_df[sorted(general_df[columns_to_keep])]

# For the AE-specific columns, we can do the same
ae_columns = [
    'aeComments', 'ae_type_code', 'date_ae_identified', 'AERecordingYear', 'AERecordingSite', 
    'client_age', 'circumcising_cadre', 'ae_classification', 'AERecordingMonth', 'mcMethod','vmmc_number'
]


referrals_columns =['ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'services_referred','reason_for_referral']



other_referrals = []
ae_data_df_sorted = general_df[ae_columns][sorted(ae_columns)]
ae_data_df_sorted = ae_data_df_sorted[ae_data_df_sorted['AERecordingMonth'].notna()]

referralsDF_sorted = general_df[referrals_columns][sorted(referrals_columns)]
referralsDF_sorted = referralsDF_sorted[referralsDF_sorted['ReferrelRecordingMonth'].notna()]

# Function to flatten the nested referral data
def flatten_referral_data(referral_list):
    flattened_referrals = []
    
    # Loop through each referral in the list
    for referral in referral_list:
        flattened_referral = {}
        
        # Flatten the first level of referral data
        for key, value in referral.items():
            if isinstance(value, dict):
                # If the value is a nested dictionary, flatten it
                for nested_key, nested_value in value.items():
                    flattened_referral[f"{key}_{nested_key}"] = nested_value
            else:
                flattened_referral[key] = value
        
        flattened_referrals.append(flattened_referral)
    
    return flattened_referrals



# Function to unpack nested 'question1_question5' field
def unpack_detailedField(df, column):
    if column  in df.columns:
        # Unpack the dictionary inside 'question1_question5' into separate columns
        question_fields = df[column].apply(pd.Series)
        
        # Merge the unpacked fields back into the main DataFrame
        df = pd.concat([df, question_fields], axis=1)
        
        # Drop the original 'question1_question5' column if no longer needed
        df.drop(column, axis=1, inplace=True)
    
    return df



# Extract the referrals from 'other_referrals_in_detail' column referrals_data = []
singleReferrals =[]
# Loop through each row and check if 'other_referrals_in_detail' is a valid list
for idx, row in general_df.iterrows():
    referral_list = row['other_referrals_in_detail']
    
    # Check if the value is a list and not NaN
    if isinstance(referral_list, list):
        # Flatten the referral data
        flattened_referrals = flatten_referral_data(referral_list)
        for ref in flattened_referrals:
            ref['District'] = row['District']  # Add the District to each referral record
            referrals_data.append(ref)
    else:
        # Handle cases where referral_list is not valid
        if not pd.isna(row['ReferrelRecordingMonth']):  # Check if 'ReferrelRecordingMonth' is not NaN
            _object = {
                'ReferrelRecordingMonth': row['ReferrelRecordingMonth'], 
                'ReferrelRecordingSite': row['ReferrelRecordingSite'], 
                'ReferrelRecordingYear': row['ReferrelRecordingYear'],
                'District': row['District'],
                'reason_for_referral':row['reason_for_referral'],
                'services_referred':row['services_referred']
            }
            singleReferrals.append(_object)






aes_data =[]
singleAEs = []
for idx, row in general_df.iterrows():
    ae_list = row['adverse_events']
    
    # Check if the value is a list and not NaN
    if isinstance(ae_list, list) and not pd.isna(ae_list).any():  # Use .any() to check the entire list
        flattened_aes = flatten_referral_data(ae_list)
        for ref in flattened_aes:
            ref['District'] = row['District']  # Add the District to each referral record
            aes_data.append(ref)

    else:
        if not pd.isna(row['AERecordingMonth']):
            _object = {
                'AERecordingMonth':row['AERecordingMonth'],
                'AERecordingSite':row['AERecordingSite'],
                'AERecordingYear':row['AERecordingYear'],
                'District':row['District'],
                'aeComments':row['aeComments'],
                'ae_classification':row['ae_classification'],
                'ae_type_code':row['ae_type_code'],
                'circumcising_cadre':row['circumcising_cadre'],
                'client_age':row['client_age'],
                'date_ae_identified':row['date_ae_identified'],
                'mcMethod':row['mcMethod'],
                'vmmc_number':row['vmmc_number']
            }
            singleAEs.append(_object)




            
            
# Convert the flattened referrals data into a DataFrame

referrals_df = pd.DataFrame(referrals_data)

# convert the flattened aes data into a df

ae_df = pd.DataFrame(aes_data)

# Unpack the 'question1_question5' field
referrals_df = unpack_detailedField(referrals_df,'question1_question5')

ae_df = unpack_detailedField(ae_df,'question3_question1')

ae_df = unpack_detailedField(ae_df,'question1')

ae_df = ae_df.rename(columns={
    'question3_AERecordingMonth': 'AERecordingMonth',
    'question3_AERecordingSite': 'AERecordingSite',
    'question3_AERecordingYear': 'AERecordingYear'
})

print(ae_df)

if len(singleReferrals)>0:
    tempRefDF = pd.DataFrame(singleReferrals)
    referrals_df = pd.concat([referrals_df,tempRefDF])

if len(singleAEs)>0:
    tempRefDF = pd.DataFrame(singleAEs)
    ae_df = pd.concat([ae_df,tempRefDF])


if not referrals_df.empty:
    referrals_df = referrals_df.drop(columns = ['question1_cancelthisReferralReport',0])

if not ae_df.empty:
    ae_df = ae_df.drop(columns = ['checkMonthValidation','checkYearValidation'])

general_df_sorted = general_df_sorted.drop(columns =['adverse_events','other_referrals_in_detail'])


zazicSites_unique = zazicSites.drop_duplicates(subset='facilityName')

# Create the mapping for unique values
facility_mapping = zazicSites_unique.set_index('facilityName')['facilityType']

# Map facilityType to general_df_sorted
general_df_sorted['facilityType'] = general_df_sorted['facilityName'].map(facility_mapping)

                
# Now save the DataFrame to Excel
with pd.ExcelWriter('data.xlsx', engine='xlsxwriter') as writer:
    # Save the sorted general data to the first sheet
    general_df_sorted.to_excel(writer, sheet_name='Statistics', index=False)
    
    # Save the sorted AE data to a new sheet
    ae_df.to_excel(writer, sheet_name='AEs', index=False)
    
    # Save the flattened referrals data to a new sheet
    referrals_df.to_excel(writer, sheet_name='Referrals', index=False)
# Out:
# [{'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5101, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/c018f816-3866-40ec-9b51-f18ec0edf6cf/form.xml'}}, 'build_id': 'ba065fb2345e4b49a3e61b9f1b0ad097', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '412', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '12', 'fu25-29': '18'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-01-07T09:14:55.976000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Neta Clinic', 'recordingMonth': 'December', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '2'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '1'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Neta Clinic', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elevated BP', 'services_referred': 'OPD'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '12', 'total_mcs_referred_for_sti_services': '12'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Neta ClinicDecember2024', 'facilityName': 'Neta Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '15', 'hivNegative20-24': '12', 'hivNegative25-29': '17', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive25-29': '1', 'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '18', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '1', 'totalHIVUntested': '0', 'totalhivNegative': '44'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '45', 'surgical_disposable': {'sgDisposable15-19': '15', 'sgDisposable20-24': '12', 'sgDisposable25-29': '18', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '45', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MBERENGWA', 'DistrictLabelDisplay': 'District :      MBERENGWA', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      MUSUME - 101157 - MISSION HOSPITAL', 'Site_Name': 'MUSUME - 101157 - MISSION HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '15', 'mc20-24': '12', 'mc25-29': '18', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '45'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v412. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 412, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': 'c018f816-3866-40ec-9b51-f18ec0edf6cf', 'timeEnd': '2025-01-07T09:14:55.976000Z', 'timeStart': '2025-01-07T09:12:32.241000Z', 'userID': 'd ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5101, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/c018f816-3866-40ec-9b51-f18ec0edf6cf/form.xml'}}, 'build_id': 'ba065fb2345e4b49a3e61b9f1b0ad097', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '412', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '12', 'fu25-29': '18'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-01-07T09:14:55.976000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Neta Clinic', 'recordingMonth': 'December', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '2'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '1'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Neta Clinic', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elevated BP', 'services_referred': 'OPD'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '12', 'total_mcs_referred_for_sti_services': '12'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Neta ClinicDecember2024', 'facilityName': 'Neta Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '15', 'hivNegative20-24': '12', 'hivNegative25-29': '17', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive25-29': '1', 'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '18', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '1', 'totalHIVUntested': '0', 'totalhivNegative': '44'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '45', 'surgical_disposable': {'sgDisposable15-19': '15', 'sgDisposable20-24': '12', 'sgDisposable25-29': '18', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '45', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MBERENGWA', 'DistrictLabelDisplay': 'District :      MBERENGWA', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      MUSUME - 101157 - MISSION HOSPITAL', 'Site_Name': 'MUSUME - 101157 - MISSION HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '15', 'mc20-24': '12', 'mc25-29': '18', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '45'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v412. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 412, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': 'c018f816-3866-40ec-9b51-f18ec0edf6cf', 'timeEnd': '2025-01-07T09:14:55.976000Z', 'timeStart': '2025-01-07T09:12:32.241000Z', 'userID': 'd2 ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7300, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/9aac4712-0a31-4b98-aae8-bdf80704f3f4/form.xml'}}, 'build_id': 'fa3c431444e14d54bb2624a75c0ba4db', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '409', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'December', 'AERecordingSite': 'Musume Hospital', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '25', 'date_ae_identified': '2024-12-18', 'mcMethod': 'Surgical', 'vmmc_number': '009857'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '8', 'fu20-24': '6', 'fu30-34': '10', 'fu40-44': '1'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-01-07T07:55:52.985000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Musume Hospital', 'recordingMonth': 'December', 'savedFacilities': 'Musume HospitalDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '2'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Musume Hospital', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'client had fever', 'services_referred': 'OPD'}}}, {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Musume Hospital', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elevated BP', 'services_referred': 'Hypertensive'}}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '11', 'total_mcs_referred_for_sti_services': '11'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Musume HospitalDecember2024', 'facilityName': 'Musume Hospital', 'savedFacilities': 'Musume HospitalDecember2024'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '2', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '2', 'total20-24NCHIVTested': '0', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '2', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '8', 'hivNegative20-24': '6', 'hivNegative30-34': '10', 'hivNegative40-44': '1', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUnte ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5617, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/97418192-c46a-466c-9b06-07da6948e656/form.xml'}}, 'build_id': '6cda6dc10ca34004999b097a019f6d82', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '400', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'December', 'AERecordingSite': 'Chipuriro', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client is healing', 'ae_classification': 'Severe', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '25', 'date_ae_identified': '2024-12-06', 'mcMethod': 'Surgical', 'vmmc_number': '008886'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25', 'fu20-24': '10', 'fu25-29': '9', 'fu30-34': '2'}}, 'commcare_usercase': {'case': {'@case_id': '8a402b83559c45d78df66825c9d67f1f', '@date_modified': '2025-01-06T06:50:23.234000Z', '@user_id': '970d6f38ae0b4441a32cd1a15cd852db', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Chipuriro', 'recordingMonth': 'December', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '2'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '5', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'ChipuriroDecember2024', 'facilityName': 'Chipuriro', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '25', 'hivNegative20-24': '10', 'hivNegative25-29': '7', 'hivNegative30-34': '2', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive25-29': '2', 'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '9', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '2', 'totalHIVUntested': '0', 'totalhivNegative': '44'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '46', 'surgical_disposable': {'sgDisposable15-19': '0', 'sgDisposable20-24': '0', 'sgDisposable25-29': '0', 'sgDisposable30-34': '0', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable15-19': '25', 'sgReusable20-24': '10', 'sgReusable25-29': '9', 'sgReusable30-34': '2', 'total_surgicalReusable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '0', 'totalSurgicalReusableMCs': '46'}, 'location_details': {'District': 'GURUVE', 'DistrictLabelDisplay': 'District :      GURUVE', 'Province': 'MASHONALAND CENTRAL', 'ProvinceLabelDisplay': 'Province :      MASHONALAND CENTRAL', 'SiteLabelDisplay': 'Site  :      GURUVE - 100553 - DISTRICT HOSPITAL', 'Site_Name': 'GURUVE - 100553 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '25', 'mc20-24': '10', 'mc25-29': '9', 'mc30-34': '2', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '46'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App  ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6127, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/48792816-c87b-4774-89dc-5aeb2e2e6e25/form.xml'}}, 'build_id': '6cda6dc10ca34004999b097a019f6d82', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '400', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '8', 'fu20-24': '6', 'fu30-34': '10'}}, 'commcare_usercase': {'case': {'@case_id': 'a80c46d3231640fd8c55f749973adc25', '@date_modified': '2025-01-03T06:59:56.043000Z', '@user_id': '41c47d57bc31473c8e8c8d8cf3a78062', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Jahana Clinic', 'recordingMonth': 'December', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024Gwanyika Rural Health CentreDecember2024Gokwe South District HospitalDecember2024Jahana ClinicDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '2'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '15', 'total_mcs_referred_for_sti_services': '12'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Jahana ClinicDecember2024', 'facilityName': 'Jahana Clinic', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024Gwanyika Rural Health CentreDecember2024Gokwe South District HospitalDecember2024Jahana ClinicDecember2024'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '0', 'hivPositiveNC20-24': '2', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '0', 'total20-24NCHIVTested': '2', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '2', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '8', 'hivNegative20-24': '6', 'hivNegative30-34': '10', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '24'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '24', 'surgical_disposable': {'sgDisposable15-19': '8', 'sgDisposable20-24': '6', 'sgDisposable30-34': '10', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '24', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'GOKWE SOUTH', 'DistrictLabelDisplay': 'District :      GOKWE SOUTH', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      GOKWE - 100513 - DISTRICT HOSPITAL', 'Site_Name': 'GOKWE - 100513 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'di ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6299, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/87ba24a9-20ce-4247-8352-094be33ba37e/form.xml'}}, 'build_id': '6cda6dc10ca34004999b097a019f6d82', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '400', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'December', 'AERecordingSite': 'Guruve District Hospital', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Doctor', 'client_age': '25', 'date_ae_identified': '2024-12-02', 'mcMethod': 'Surgical', 'vmmc_number': '000456'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '10', 'fu20-24': '15', 'fu25-29': '6', 'fu30-34': '2', 'fu40-44': '1'}}, 'commcare_usercase': {'case': {'@case_id': '8a402b83559c45d78df66825c9d67f1f', '@date_modified': '2025-01-03T06:56:17.774000Z', '@user_id': '970d6f38ae0b4441a32cd1a15cd852db', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Guruve District Hospital', 'recordingMonth': 'December', 'savedFacilities': 'Guruve District HospitalDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '2'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Guruve District Hospital', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Elavated BP', 'services_referred': 'Hypertensive'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '6', 'total_mcs_referred_for_sti_services': '6'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Guruve District HospitalDecember2024', 'facilityName': 'Guruve District Hospital', 'savedFacilities': 'Guruve District HospitalDecember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '10', 'hivNegative20-24': '15', 'hivNegative25-29': '4', 'hivNegative30-34': '2', 'hivNegative40-44': '1', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive25-29': '2', 'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '6', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '2', 'totalHIVUntested': '0', 'totalhivNegative': '32'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '34', 'shangring_by_age': {'shangring20-24': '3', 'total_shangringMCs': 'OK'}, 'surgical_disposable': {'sgDisposable15-19': '0', 'sgDisposable20-24': '0', 'sgDisposable25-29': '0', 'sgDisposable30-34': '0', 'sgDisposable40-44': '0', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable15-19': '10', 'sgReusable20-24': '12', 'sgReusable25-29': '6', 'sgReusable30-34': '2', 'sgReusable40-44': '1', 'total_surgicalReusable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '3', 'totalSurgicalDisposableMCs': '0', 'totalSurgicalReusableMCs': '31'}, 'location_details': {'District': 'GURUVE', 'DistrictLabelDisplay': 'District :      GURUVE', 'Province': 'MASHONALAND CENTRAL', 'ProvinceLabelDisplay': 'Province :      MASHONALAND CENTRAL', 'SiteLabelDisplay': 'Site  :      GURUVE - 100553 - DISTRICT HOSPITAL', ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7415, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/23907f78-5f83-4146-886a-425306526b68/form.xml'}}, 'build_id': '18b954b4cbe646a2bbc8a06b0c420f6e', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '395', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25', 'fu20-24': '10', 'fu25-29': '8'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-01-02T07:00:38.560000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Sankonjana', 'recordingMonth': 'December', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '3'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Sankonjana', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client has rash and was linked to OPD', 'services_referred': 'OPD'}}}, {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Sankonjana', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '1'}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '2', 'total_mcs_referred_for_sti_services': '1'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'SankonjanaDecember2024', 'facilityName': 'Sankonjana', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '1', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '2', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '1', 'total20-24NCHIVTested': '0', 'total25-29NCHIVTested': '2', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '3', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '25', 'hivNegative20-24': '10', 'hivNegative25-29': '8', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HI ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5750, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/3b25ab17-06a1-417b-a61a-7cca40db62dc/form.xml'}}, 'build_id': '18b954b4cbe646a2bbc8a06b0c420f6e', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '395', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25', 'fu20-24': '15', 'fu25-29': '19', 'fu30-34': '14'}}, 'commcare_usercase': {'case': {'@case_id': 'a80c46d3231640fd8c55f749973adc25', '@date_modified': '2024-12-13T07:21:26.649000Z', '@user_id': '41c47d57bc31473c8e8c8d8cf3a78062', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Gokwe South District Hospital', 'recordingMonth': 'December', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024Gwanyika Rural Health CentreDecember2024Gokwe South District HospitalDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '56', 'total_hiv_positive_linked_to_care': '1'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Gokwe South District Hospital', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elavated BP', 'services_referred': 'Hypertensive'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '14', 'total_mcs_referred_for_sti_services': '25'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Gokwe South District HospitalDecember2024', 'facilityName': 'Gokwe South District Hospital', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024Gwanyika Rural Health CentreDecember2024Gokwe South District HospitalDecember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '25', 'hivNegative20-24': '15', 'hivNegative25-29': '15', 'hivNegative30-34': '14', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive25-29': '1', 'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '16', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '1', 'totalHIVUntested': '3', 'totalhivNegative': '69'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '73', 'shangring_by_age': {'shangring30-34': '2', 'total_shangringMCs': 'OK'}, 'surgical_disposable': {'sgDisposable15-19': '25', 'sgDisposable20-24': '15', 'sgDisposable25-29': '19', 'sgDisposable30-34': '12', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable30-34': '0', 'total_surgicalReusable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '2', 'totalSurgicalDisposableMCs': '71', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'GOKWE SOUTH', 'DistrictLabelDisplay': 'District :      GOKWE SOUTH', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      GOKWE - 100513 - DISTRICT HOSPITAL', 'Site_Name': 'GOKWE - 100513 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '25', 'mc20-24': '15', 'mc25-29': '19', 'mc30-34': '14', 'mc35-3 ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5977, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/a267a2c5-943f-4fb7-b321-9134b7d85ffd/form.xml'}}, 'build_id': '75216ec9dce94ee7ba95c416bd4135d0', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '387', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'December', 'AERecordingSite': 'Gwanyika Rural Health Centre', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client is healing', 'ae_classification': 'Severe', 'ae_type_code': 'BL', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '24', 'date_ae_identified': '2024-12-12', 'mcMethod': 'Surgical', 'vmmc_number': '345534'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25', 'fu20-24': '12'}}, 'commcare_usercase': {'case': {'@case_id': 'a80c46d3231640fd8c55f749973adc25', '@date_modified': '2024-12-12T05:49:13.509000Z', '@user_id': '41c47d57bc31473c8e8c8d8cf3a78062', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Gwanyika Rural Health Centre', 'recordingMonth': 'December', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024Gwanyika Rural Health CentreDecember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '0'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Gwanyika Rural Health Centre', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had high fever', 'services_referred': 'OPD'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '12', 'total_mcs_referred_for_sti_services': '12'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Gwanyika Rural Health CentreDecember2024', 'facilityName': 'Gwanyika Rural Health Centre', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024Gwanyika Rural Health CentreDecember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '25', 'hivNegative20-24': '12', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '37'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '37', 'surgical_disposable': {'sgDisposable15-19': '0', 'sgDisposable20-24': '0', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable15-19': '25', 'sgReusable20-24': '12', 'total_surgicalReusable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '0', 'totalSurgicalReusableMCs': '37'}, 'location_details': {'District': 'GOKWE SOUTH', 'DistrictLabelDisplay': 'District :      GOKWE SOUTH', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      GOKWE - 100513 - DISTRICT HOSPITAL', 'Site_Name': 'GOKWE - 100513 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6593, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/b7db3a73-300c-4f1e-9b0a-97e8f38e56fc/form.xml'}}, 'build_id': 'dc967ebba2124257b3f7b8abf1a71e4d', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '386', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': [{'question3': {'AERecordingMonth': 'November', 'AERecordingSite': 'Krima Clinic', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client healing', 'ae_classification': 'Severe', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '25', 'date_ae_identified': '2024-11-10', 'mcMethod': 'Surgical', 'vmmc_number': '467233'}}}}, {'question3': {'AERecordingMonth': 'November', 'AERecordingSite': 'Krima Clinic', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client healing', 'ae_classification': 'Moderate', 'ae_type_code': 'BL', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '18', 'date_ae_identified': '2024-11-08', 'mcMethod': 'Surgical', 'vmmc_number': '245555'}}}}], 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25'}}, 'commcare_usercase': {'case': {'@case_id': 'a80c46d3231640fd8c55f749973adc25', '@date_modified': '2024-12-10T07:36:34.061000Z', '@user_id': '41c47d57bc31473c8e8c8d8cf3a78062', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Krima Clinic', 'recordingMonth': 'November', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '2', 'total_hiv_positive_linked_to_care': '0'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'November', 'ReferrelRecordingSite': 'Krima Clinic', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'high fever', 'services_referred': 'OPD'}}}, {'ReferrelRecordingMonth': 'November', 'ReferrelRecordingSite': 'Krima Clinic', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had high BP', 'services_referred': 'Hypertensive'}}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Krima ClinicNovember2024', 'facilityName': 'Krima Clinic', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024Krima ClinicNovember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '25', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '25'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '25', 'surgical_disposable': {'sgDisposable15-19': '25', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '25', 'totalSurgicalReusableMCs': '0'}, 'location ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7119, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/194f4dbe-b7e5-4945-b276-ab2137d257d9/form.xml'}}, 'build_id': 'dc967ebba2124257b3f7b8abf1a71e4d', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '386', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'November', 'AERecordingSite': 'Katema RDC', 'AERecordingYear': '2024', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'BL', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '25', 'date_ae_identified': '2024-11-14', 'mcMethod': 'Surgical', 'vmmc_number': '234556'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '13', 'fu20-24': '15', 'fu25-29': '18', 'fu35-39': '21', 'fu40-44': '13', 'fu45-49': '12', 'fu50': '2'}}, 'commcare_usercase': {'case': {'@case_id': 'a80c46d3231640fd8c55f749973adc25', '@date_modified': '2024-12-10T06:12:30.667000Z', '@user_id': '41c47d57bc31473c8e8c8d8cf3a78062', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Katema RDC', 'recordingMonth': 'November', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '6', 'total_hiv_positive_linked_to_care': '4'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'November', 'ReferrelRecordingSite': 'Katema RDC', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had  severe fever', 'services_referred': 'OPD'}}}, {'ReferrelRecordingMonth': 'November', 'ReferrelRecordingSite': 'Katema RDC', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '1'}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '5', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Katema RDCNovember2024', 'facilityName': 'Katema RDC', 'savedFacilities': 'Huchu ClinicNovember2024Jahana ClinicOctober2024Jahana ClinicNovember2024Katema RDCNovember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '5', 'hivNegative20-24': '0', 'hivNegative25-29': '2', 'hivNegative35-39': '6', 'hivNegative40-44': '0', 'hivNegative45-49': '0', 'hivNegative50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'hivPositive20-24': '0', 'hivPositive25-29': '2', 'hivPositive35-39': '2', 'hivPositive40-44': '0', 'hivPositive45-49': '0', 'hivPositive50': '0', 'total15-19HIVTested': '5', 'total20-24HIVTested': '0', 'total25-29HIVTested': '4', 'total30-34HIVTested': '', 'total35-39HIVTested': '8', 'total40-44HIVTested': '0', 'total45-49HIVTested': '0', 'total50HIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '4', 'totalHIVUntested': '77', 'totalhivNegative': '13'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '94', 'surgical_disposable': {'sgDisposable15-19': '0', 'sgDisposable20-24': '0', 'sgDisposable25-29': '0', 'sgDisposable35-39': '0', 'sgDisposable40-44': '0', 'sgDisposable45-49': '0', 'sgDisposable50': '0', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable15-19': '13', 'sgReusable20-24': '15', 'sgReusable25-29': '18', 'sgReusable35-39': '21', 'sgReusable40-44' ...
# ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4780, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/ecbd15d4-b0e9-4218-b06a-2bc8bb4231a5/form.xml'}}, 'build_id': '5356ae2dc9854083a4eb5d019ef22312', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '371', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '28'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2024-12-03T07:26:28.550000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Kezi', 'recordingMonth': 'September', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '16', 'total_hiv_positive_linked_to_care': '0'}, 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}, 'total_mcs_referred_to_other_services': '0'}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'KeziSeptember2024', 'facilityName': 'Kezi', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '28', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalhivNegative': '28'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '28', 'surgical_disposable': {'sgDisposable15-19': '28', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '28', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MATOBO', 'DistrictLabelDisplay': 'District :      MATOBO', 'Province': 'MATABELELAND SOUTH', 'ProvinceLabelDisplay': 'Province :      MATABELELAND SOUTH', 'SiteLabelDisplay': 'Site  :      MAPHISA - 100890 - DISTRICT HOSPITAL', 'Site_Name': 'MAPHISA - 100890 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '28', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '28'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v371. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 371, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': 'ecbd15d4-b0e9-4218-b06a-2bc8bb4231a5', 'timeEnd': '2024-12-03T07:26:28.550000Z', 'timeStart': '2024-12-03T07:25:40.115000Z', 'userID': '148b582ced074b30a11c93abdad751e5', 'username': 'amutenha'}, 'recordingPeriodLi ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5941, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/ff596a1e-6812-4323-bd1c-bb93978045aa/form.xml'}}, 'build_id': '5356ae2dc9854083a4eb5d019ef22312', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '371', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '15', 'fu20-24': '30', 'fu25-29': '43', 'fu30-34': '12', 'fu35-39': '2'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2024-12-03T07:14:14.202000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Maphisa Hospital', 'recordingMonth': 'September', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '20', 'total_hiv_positive_linked_to_care': '6'}, 'other_referrals_in_detail': {'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'client had a rash not circumcised', 'services_referred': 'OPD'}}}, 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '20', 'total_mcs_referred_for_sti_services': '20'}, 'total_mcs_referred_to_other_services': '1'}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Maphisa HospitalSeptember2024', 'facilityName': 'Maphisa Hospital', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'hivNegative20-24': '27', 'hivNegative25-29': '43', 'hivNegative30-34': '12', 'hivNegative35-39': '2', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '3', 'hivPositive20-24': '3', 'total15-19HIVTested': '15', 'total20-24HIVTested': '30', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '6', 'totalhivNegative': '96'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '102', 'shangring_by_age': {'shangring20-24': '3', 'total_shangringMCs': 'OK'}, 'surgical_disposable': {'sgDisposable15-19': '0', 'sgDisposable20-24': '0', 'sgDisposable25-29': '0', 'sgDisposable30-34': '0', 'sgDisposable35-39': '0', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable15-19': '15', 'sgReusable20-24': '27', 'sgReusable25-29': '43', 'sgReusable30-34': '12', 'sgReusable35-39': '2', 'total_surgicalReusable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '3', 'totalSurgicalDisposableMCs': '0', 'totalSurgicalReusableMCs': '99'}, 'location_details': {'District': 'MATOBO', 'DistrictLabelDisplay': 'District :      MATOBO', 'Province': 'MATABELELAND SOUTH', 'ProvinceLabelDisplay': 'Province :      MATABELELAND SOUTH', 'SiteLabelDisplay': 'Site  :      MAPHISA - 100890 - DISTRICT HOSPITAL', 'Site_Name': 'MAPHISA - 100890 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disagg ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6967, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/c33c5407-b08d-465f-a559-80aab99cee76/form.xml'}}, 'build_id': '5356ae2dc9854083a4eb5d019ef22312', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '371', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client healing', 'ae_classification': 'Moderate', 'ae_type_code': 'CO-A', 'circumcising_cadre': 'Nurse', 'client_age': '25', 'date_ae_identified': '2024-10-02', 'mcMethod': 'Surgical', 'vmmc_number': '566777'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '23', 'fu20-24': '25'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2024-12-03T07:00:41.591000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Natisa', 'recordingMonth': 'September', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024'}}}, 'copy-1-of-grpHTS': {'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '25', 'total_hiv_positive_linked_to_care': '7'}, 'other_referrals_in_detail': {'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had high blood', 'services_referred': 'Hypertensive'}}}, 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '21', 'total_mcs_referred_for_sti_services': '21'}, 'total_mcs_referred_to_other_services': '1'}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'NatisaSeptember2024', 'facilityName': 'Natisa', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '2', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '0', 'hivPositiveNC20-24': '2', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '2', 'total20-24NCHIVTested': '2', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '2', 'totalhivNegativeNC': '2', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '18', 'hivNegative20-24': '52', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '1', 'hivPositive20-24': '4', 'total15-19HIVTested': '19', 'total20-24HIVTested': '56', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '5', 'totalhivNegative': '70'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '79', 'surgical_disposable': {'sgDisposable15-19': '0', 'sgDisposable20-24': '0', 'total_surgicalDisposable': 'OK'}, ' ...
#   AERecordingMonth AERecordingSite AERecordingYear     District  \
# 0         November    Krima Clinic            2024  GOKWE SOUTH
# 1         November    Krima Clinic            2024  GOKWE SOUTH
# 2         November     Mbembeswana            2024       MATOBO
# 3         November     Mbembeswana            2024       MATOBO
# 4              NaN             NaN             NaN       MATOBO
# 5              NaN             NaN             NaN       MATOBO
#
#   cancelthisAEReport              aeComments ae_classification ae_type_code  \
# 0                             Client healing            Severe          COA
# 1                             Client healing          Moderate           BL
# 2                          Client is healing            Severe          COA
# 3                          Client is healing          Moderate          SSE
# 4                     Client Healimg at home            Severe          COA
# 5                             Client Healing          Moderate          SSE
#
#   checkMonthValidation checkYearValidation circumcising_cadre client_age  \
# 0                    1                   1              Nurse         25
# 1                    1                   1              Nurse         18
# 2                  NaN                 NaN                            25
# 3                  NaN                 NaN              Nurse         35
# 4                  NaN                 NaN              Nurse         25
# 5                  NaN                 NaN              Nurse         23
#
#   date_ae_identified  mcMethod vmmc_number
# 0         2024-11-10  Surgical      467233
# 1         2024-11-08  Surgical      245555
# 2         2024-10-03  Surgical      233446
# 3         2024-10-03  Surgical        3467
# 4         2024-09-03  Surgical      234455
# 5         2024-12-03  Surgical      578988

# %%
general_df_sorted
# Out:
#    AERecordingMonth                       AERecordingSite AERecordingYear  \
# 0               NaN                                   NaN             NaN
# 1          December                       Musume Hospital            2024
# 2          December                             Chipuriro            2024
# 3               NaN                                   NaN             NaN
# 4          December              Guruve District Hospital            2024
# 5               NaN                                   NaN             NaN
# 6               NaN                                   NaN             NaN
# 7          December          Gwanyika Rural Health Centre            2024
# 8               NaN                                   NaN             NaN
# 9          November                            Katema RDC            2024
# 10         November                         Jahana Clinic            2024
# 11              NaN                                   NaN             NaN
# 12         November                          Huchu Clinic            2024
# 13         December                                  Kezi            2024
# 14              NaN                                   NaN             NaN
# 15          October                           Mbembeswana            2024
# 16          October  MAPHISA - 100890 - DISTRICT HOSPITAL            2024
# 17              NaN                                   NaN             NaN
# 18              NaN                                   NaN             NaN
# 19              NaN                                   NaN             NaN
# 20              NaN                                   NaN             NaN
#
#        District ReferrelRecordingMonth                 ReferrelRecordingSite  \
# 0     MBERENGWA               December                           Neta Clinic
# 1     MBERENGWA                    NaN                                   NaN
# 2        GURUVE                    NaN                                   NaN
# 3   GOKWE SOUTH                    NaN                                   NaN
# 4        GURUVE               December              Guruve District Hospital
# 5        MATOBO                    NaN                                   NaN
# 6   GOKWE SOUTH               December         Gokwe South District Hospital
# 7   GOKWE SOUTH               December          Gwanyika Rural Health Centre
# 8   GOKWE SOUTH                    NaN                                   NaN
# 9   GOKWE SOUTH                    NaN                                   NaN
# 10  GOKWE SOUTH                    NaN                                   NaN
# 11  GOKWE SOUTH                    NaN                                   NaN
# 12  GOKWE SOUTH               November                          Huchu Clinic
# 13       MATOBO               December                                  Kezi
# 14       MATOBO                    NaN                                   NaN
# 15       MATOBO                October                           Mbembeswana
# 16       MATOBO                October  MAPHISA - 100890 - DISTRICT HOSPITAL
# 17       MATOBO                    NaN                                   NaN
# 18       MATOBO                    NaN                                   NaN
# 19       MATOBO                    NaN                                   NaN
# 20       MATOBO                    NaN                                   NaN
#
#    ReferrelRecordingYear                             Site_Name  \
# 0                   2024    MUSUME - 101157 - MISSION HOSPITAL
# 1                    NaN    MUSUME - 101157 - MISSION HOSPITAL
# 2                    NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 3                    NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 4                   2024   GURUVE - 100553 - DISTRICT HOSPITAL
# 5                    NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 6                   2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 7                   2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 8                    NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 9                    NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 10                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 11                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 12                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 13                  2024  MAPHISA - 100890 - DISTRICT HOSPITAL
# 14                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 15                  2024  MAPHISA - 100890 - DISTRICT HOSPITAL
# 16                  2024  MAPHISA - 100890 - DISTRICT HOSPITAL
# 17                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 18                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 19                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 20                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
#
#    TotalMCsBYMethod                                       aeComments  ...  \
# 0                45                                              NaN  ...
# 1                25                                Client is healing  ...
# 2                46                                Client is healing  ...
# 3                24                                              NaN  ...
# 4                34                                Client is healing  ...
# 5                43                                              NaN  ...
# 6                73                                              NaN  ...
# 7                37                                Client is healing  ...
# 8                25                                              NaN  ...
# 9                94                                Client is healing  ...
# 10               80  Sature elavated  by lignocaine,\nclient healing  ...
# 11               35                                              NaN  ...
# 12               60                                Client is healing  ...
# 13               97                                Client is healing  ...
# 14              144                                              NaN  ...
# 15              144                                Client is healing  ...
# 16               69                                   client healing  ...
# 17              108                                              NaN  ...
# 18               28                                              NaN  ...
# 19              102                                              NaN  ...
# 20               79                                   Client healing  ...
#
#    total_surgicalReusable total_surgicalReusable total_surgicalReusable  \
# 0                     NaN                     OK                    NaN
# 1                     NaN                     OK                     OK
# 2                      OK                     OK                    NaN
# 3                     NaN                     OK                     OK
# 4                      OK                     OK                    NaN
# 5                      OK                     OK                     OK
# 6                      OK                     OK                    NaN
# 7                      OK                     OK                    NaN
# 8                     NaN                     OK                    NaN
# 9                      OK                     OK                    NaN
# 10                     OK                     OK                     OK
# 11                     OK                     OK                    NaN
# 12                     OK                     OK                     OK
# 13                     OK                     OK                     OK
# 14                     OK                     OK                    NaN
# 15                     OK                     OK                     OK
# 16                     OK                     OK                    NaN
# 17                     OK                     OK                    NaN
# 18                    NaN                     OK                    NaN
# 19                     OK                     OK                    NaN
# 20                     OK                     OK                     OK
#
#    total_surgicalReusable totalhivNegative totalhivNegativeNC  \
# 0                     NaN               44                  0
# 1                     NaN               25                  0
# 2                      OK               44                  0
# 3                     NaN               24                  0
# 4                      OK               32                  0
# 5                      OK               43                  0
# 6                      OK               69                  0
# 7                      OK               37                  0
# 8                     NaN               25                  0
# 9                      OK               13                  0
# 10                     OK               80                  1
# 11                     OK               35                  0
# 12                     OK               59                  0
# 13                     OK               91                  0
# 14                     OK              144                  0
# 15                     OK              135                 37
# 16                     OK               66                  0
# 17                     OK              108                  0
# 18                    NaN               28                  0
# 19                     OK               96                  0
# 20                     OK               70                  2
#
#    uncircumcisedClientsForHTS vmmc_number  year facilityType
# 0                           0         NaN  2024          NaN
# 1                           1      009857  2024          NaN
# 2                           0      008886  2024          NaN
# 3                           1         NaN  2024     Outreach
# 4                           0      000456  2024          NaN
# 5                           1         NaN  2024     Outreach
# 6                           0         NaN  2024       Static
# 7                           0      345534  2024     Outreach
# 8                           0         NaN  2024     Outreach
# 9                           0      234556  2024     Outreach
# 10                          1      234455  2024     Outreach
# 11                          0         NaN  2024     Outreach
# 12                          1       00056  2024     Outreach
# 13                          1        1234  2024     Outreach
# 14                          0         NaN  2024     Outreach
# 15                          1        1233  2024     Outreach
# 16                          0       34565  2024     Outreach
# 17                          0         NaN  2024     Outreach
# 18                          0         NaN  2024     Outreach
# 19                          0         NaN  2024       Static
# 20                          1      566777  2024     Outreach
#
# [21 rows x 155 columns]
