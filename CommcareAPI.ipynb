# %%
import pandas as pd
from commcare_export.checkpoint import CheckpointManagerWithDetails
from commcare_export.commcare_hq_client import CommCareHqClient, AUTH_MODE_APIKEY
from commcare_export.commcare_minilinq import get_paginator, PaginationMode
from datetime import datetime
import re

# CommCare credentials
username = 'amutenha@zimttech.org'  # Replace with your actual CommCare username
domain = 'zdip-qa'  # Your CommCare project domain
hq_host = 'https://zdip.zimttech.org'  # Your CommCare HQ custom host
API_KEY = 'd80e5490704f950ce01be884e84a9da40310a762'  # Replace with the API key generated in CommCare


zazicSites= pd.read_excel('zazicFacilities.xlsx')
# Initialize API client
api_client = CommCareHqClient(hq_host, domain, username, API_KEY, AUTH_MODE_APIKEY)

# Create a paginator for the 'form' resource (fetching data from a form)
form_paginator = get_paginator(resource='form', pagination_mode=PaginationMode.date_modified, page_size=100)
form_paginator.init()

# Initialize checkpoint manager (None used here for simplicity)
checkpoint_manager = CheckpointManagerWithDetails(None, None, PaginationMode.date_modified)

# Date range for filtering
start_date = datetime(2024, 12,6)  # 2 December 2024
end_date = datetime(2025, 2, 28)  # 6 December 2024

# Specify the app_id to filter forms
desired_app_id ='cbd88c81d5a9131517e106028f0dd680'  

# Initialize lists to store categorized data
referrals_data = []
AEs_data = []
general_data = []

# Fetch forms iteratively
# Fetch forms using manual pagination
all_forms = []
offset = 0
while True:
    forms = api_client.iterate(
        'form',
        form_paginator,
        checkpoint_manager=checkpoint_manager,
        params={'limit': 2000, 'offset': offset}  # Adjust offset manually
    )
    
    batch = list(forms)  # Fetch current batch of forms
    if not batch:  # Break if no more forms
        break
    
    all_forms.extend(batch)
    offset += 100  # Move to the next page

    # Optional: Stop after collecting 100 submissions for testing
    if len(all_forms) >= 100:
        break






filteredResults =[]
for i in all_forms:
    if i["app_id"] ==desired_app_id:
        filteredResults.append(i)

print(filteredResults)
# Filter and categorize forms by app_id and date
for form in forms:
    if form.get('app_id') == desired_app_id:
        print(form)
        form_received_date = datetime.strptime(form['received_on'], "%Y-%m-%dT%H:%M:%S.%fZ")
        if start_date <= form_received_date <= end_date:
            general_data.append(form)
# Convert each list to a pandas DataFrame
general_df = pd.json_normalize(general_data)
general_df.to_excel('test.xlsx')

general_df.columns = [re.split(r'[./]', col)[-1] for col in general_df.columns]

# New columns that should NOT be deleted
columns_to_retain = [
    'AERecordingMonth', 'AERecordingSite', 'AERecordingYear', 'aeComments', 'ae_classification', 
    'ae_type_code', 'checkMonthValidation', 'checkYearValidation', 'circumcising_cadre', 'client_age', 
    'date_ae_identified', 'mcMethod', 'vmmc_number', 'followUpTotal', 'recordingMonth', 
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'reason_for_referral', 'services_referred', 'facilityName', 
    'District', 'recordingMonth', 'year', 'totalAES','adverse_events', 'Site_Name', 'totalReferralstoOtherServices'
]

# Columns that must be numeric (including the new ones)
numeric_columns = [
    'client_age', 'fu15-19', 'fu20-24', 'fu25-29', 'fu30-34', 'fu40-44', 'fu50',
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'referralToOtherServices',
    'total_mcs_referred_for_srh_services', 'total_mcs_referred_for_sti_services', 'checkifFacilityHasBeenSaved',
    'hivNegativeNC15-19', 'hivNegativeNC20-24', 'hivNegativeNC25-29', 'hivNegativeNC30-34', 'hivNegativeNC35-39', 
    'hivNegativeNC40-44', 'hivNegativeNC45-49', 'hivNegativeNC50', 'total_surgicalDisposable', 'hivPositive30-34',
    'hivPositiveNC15-19', 'hivPositiveNC20-24', 'hivPositiveNC25-29', 'hivPositiveNC35-39', 'hivPositiveNC40-44',
    'hivPositiveNC45-49', 'hivPositiveNC50', 'total15-19NCHIVTested', 'total20-24NCHIVTested', 'total25-29NCHIVTested',
    'total30-34NCHIVTested', 'total35-39NCHIVTested', 'total40-44NCHIVTested', 'total45-49NCHIVTested', 
    'total50NCHIVTested', 'total_surgicalReusable', 'totalHIVPositiveNC', 'totalhivNegativeNC', 
    'uncircumcisedClientsForHTS', 'hivNegative15-19', 'hivNegative20-24', 'hivNegative25-29', 'hivNegative30-34', 
    'hivNegative40-44', 'hivNegative50', 'total_surgicalDisposable', 'hivPositive15-19', 'hivPositive20-24','hivPositive25-29',
    'hivPositive30-34','hivPositive35-39','hivPositive40-44','hivPositive45-49','hivPositive50',
    'total15-19HIVTested', 'total20-24HIVTested', 'total25-29HIVTested', 'total30-34HIVTested', 'total35-39HIVTested',
    'total40-44HIVTested', 'total45-49HIVTested', 'total50HIVTested', 'total_surgicalReusable', 'totalHIVPositive',
    'totalHIVUntested', 'totalhivNegative', 'TotalMCsBYMethod', 'sgDisposable15-19', 'sgDisposable20-24', 
    'sgDisposable25-29', 'sgDisposable30-34', 'sgDisposable40-44', 'sgDisposable50', 'total_surgicalDisposable',
    'sgReusable15-19', 'sgReusable20-24', 'sgReusable25-29', 'sgReusable30-34', 'sgReusable40-44', 'sgReusable50',
    'total_surgicalReusable', 'total50ByMethod', 'totalShangringMCs', 'totalSurgicalDisposableMCs', 
    'totalSurgicalReusableMCs', 'mc15-19', 'mc20-24', 'mc25-29', 'mc30-34', 'mc35-39', 'mc40-44', 'mc45-49', 
    'mc50', 'totalMCs', 'fu35-39', 'other_referrals_in_detail', 'total_mcs_referred_to_other_services', 
    'hivNegative35-39', 'sgDisposable35-39', 'sgReusable35-39', 'shangring15-19', 'shangring20-24','shangring25-29', 'shangring30-34',
    'shangring35-39', 'shangring40-44','shangring45-49','shangring50', 'fu45-49', 
    'hivNegative45-49', 'sgDisposable45-49', 'sgReusable45-49','AERecordingYear','kp_referrals_to_care'
]

# general_df['AERecordingYear'] = pd.to_numeric(general_df['AERecordingYear'])
# Combine the two lists (retain columns that are in either columns_to_retain or numeric_columns)
columns_to_keep = list(set(columns_to_retain + numeric_columns))

# Identify missing columns
missing_columns = [col for col in columns_to_keep if col not in general_df.columns]

# Add missing columns to the DataFrame and assign zero
for col in missing_columns:
    general_df[col] = 0

# Drop the columns that are not in the columns_to_keep list
# Sort the columns alphabetically in both DataFrames

# For the 'general_df', sort the columns alphabetically
general_df_sorted = general_df[sorted(general_df[columns_to_keep])]

# For the AE-specific columns, we can do the same
ae_columns = [
    'aeComments', 'ae_type_code', 'date_ae_identified', 'AERecordingYear', 'AERecordingSite', 
    'client_age', 'circumcising_cadre', 'ae_classification', 'AERecordingMonth', 'mcMethod','vmmc_number'
]


referrals_columns =['ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'services_referred','reason_for_referral']



other_referrals = []
ae_data_df_sorted = general_df[ae_columns][sorted(ae_columns)]
ae_data_df_sorted = ae_data_df_sorted[ae_data_df_sorted['AERecordingMonth'].notna()]

referralsDF_sorted = general_df[referrals_columns][sorted(referrals_columns)]
referralsDF_sorted = referralsDF_sorted[referralsDF_sorted['ReferrelRecordingMonth'].notna()]

# Function to flatten the nested referral data
def flatten_referral_data(referral_list):
    flattened_referrals = []
    
    # Loop through each referral in the list
    for referral in referral_list:
        flattened_referral = {}
        
        # Flatten the first level of referral data
        for key, value in referral.items():
            if isinstance(value, dict):
                # If the value is a nested dictionary, flatten it
                for nested_key, nested_value in value.items():
                    flattened_referral[f"{key}_{nested_key}"] = nested_value
            else:
                flattened_referral[key] = value
        
        flattened_referrals.append(flattened_referral)
    
    return flattened_referrals



# Function to unpack nested 'question1_question5' field
def unpack_detailedField(df, column):
    if column  in df.columns:
        # Unpack the dictionary inside 'question1_question5' into separate columns
        question_fields = df[column].apply(pd.Series)
        
        # Merge the unpacked fields back into the main DataFrame
        df = pd.concat([df, question_fields], axis=1)
        
        # Drop the original 'question1_question5' column if no longer needed
        df.drop(column, axis=1, inplace=True)
    
    return df



# Extract the referrals from 'other_referrals_in_detail' column referrals_data = []
singleReferrals =[]
# Loop through each row and check if 'other_referrals_in_detail' is a valid list
for idx, row in general_df.iterrows():
    referral_list = row['other_referrals_in_detail']
    
    # Check if the value is a list and not NaN
    if isinstance(referral_list, list):
        # Flatten the referral data
        flattened_referrals = flatten_referral_data(referral_list)
        for ref in flattened_referrals:
            ref['District'] = row['District']  # Add the District to each referral record
            referrals_data.append(ref)
    else:
        # Handle cases where referral_list is not valid
        if not pd.isna(row['ReferrelRecordingMonth']):  # Check if 'ReferrelRecordingMonth' is not NaN
            _object = {
                'ReferrelRecordingMonth': row['ReferrelRecordingMonth'], 
                'ReferrelRecordingSite': row['ReferrelRecordingSite'], 
                'ReferrelRecordingYear': row['ReferrelRecordingYear'],
                'District': row['District'],
                'reason_for_referral':row['reason_for_referral'],
                'services_referred':row['services_referred']
            }
            singleReferrals.append(_object)






aes_data =[]
singleAEs = []
for idx, row in general_df.iterrows():
    ae_list = row['adverse_events']
    
    # Check if the value is a list and not NaN
    if isinstance(ae_list, list) and not pd.isna(ae_list).any():  # Use .any() to check the entire list
        flattened_aes = flatten_referral_data(ae_list)
        for ref in flattened_aes:
            ref['District'] = row['District']  # Add the District to each referral record
            aes_data.append(ref)

    else:
        if not pd.isna(row['AERecordingMonth']):
            _object = {
                'AERecordingMonth':row['AERecordingMonth'],
                'AERecordingSite':row['AERecordingSite'],
                'AERecordingYear':row['AERecordingYear'],
                'District':row['District'],
                'aeComments':row['aeComments'],
                'ae_classification':row['ae_classification'],
                'ae_type_code':row['ae_type_code'],
                'circumcising_cadre':row['circumcising_cadre'],
                'client_age':row['client_age'],
                'date_ae_identified':row['date_ae_identified'],
                'mcMethod':row['mcMethod'],
                'vmmc_number':row['vmmc_number']
            }
            singleAEs.append(_object)




            
            
# Convert the flattened referrals data into a DataFrame

referrals_df = pd.DataFrame(referrals_data)

# convert the flattened aes data into a df

ae_df = pd.DataFrame(aes_data)

# Unpack the 'question1_question5' field
referrals_df = unpack_detailedField(referrals_df,'question1_question5')

ae_df = unpack_detailedField(ae_df,'question3_question1')

ae_df = unpack_detailedField(ae_df,'question1')

ae_df = ae_df.rename(columns={
    'question3_AERecordingMonth': 'AERecordingMonth',
    'question3_AERecordingSite': 'AERecordingSite',
    'question3_AERecordingYear': 'AERecordingYear'
})

print(ae_df)

if len(singleReferrals)>0:
    tempRefDF = pd.DataFrame(singleReferrals)
    referrals_df = pd.concat([referrals_df,tempRefDF])

if len(singleAEs)>0:
    tempRefDF = pd.DataFrame(singleAEs)
    ae_df = pd.concat([ae_df,tempRefDF])


if not referrals_df.empty:
    referrals_df = referrals_df.drop(columns = ['question1_cancelthisReferralReport',0])

if not ae_df.empty:
    try:
        ae_df = ae_df.drop(columns = ['checkMonthValidation','checkYearValidation'])
    except:
        pass

general_df_sorted = general_df_sorted.drop(columns =['adverse_events','other_referrals_in_detail'])


zazicSites_unique = zazicSites.drop_duplicates(subset='facilityName')

# Create the mapping for unique values
facility_mapping = zazicSites_unique.set_index('facilityName')['facilityType']

# Map facilityType to general_df_sorted
general_df_sorted['facilityType'] = general_df_sorted['facilityName'].map(facility_mapping)

                
# Now save the DataFrame to Excel
with pd.ExcelWriter('data.xlsx', engine='xlsxwriter') as writer:
    # Save the sorted general data to the first sheet
    general_df_sorted.to_excel(writer, sheet_name='Statistics', index=False)
    
    # Save the sorted AE data to a new sheet
    ae_df.to_excel(writer, sheet_name='AEs', index=False)
    
    # Save the flattened referrals data to a new sheet
    referrals_df.to_excel(writer, sheet_name='Referrals', index=False)
# Out:
# [{'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7925, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/615d8e53-0ca6-458e-8128-6399c3d83c25/form.xml'}}, 'build_id': 'f5c8506889894a4cbe9e8b8a092b59f8', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '416', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'January', 'AERecordingSite': 'Guruve District Hospital', 'AERecordingYear': '2025', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'AE was properly addressed , client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '18', 'date_ae_identified': '2025-01-19', 'mcMethod': 'Surgical', 'vmmc_number': '00012'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '8'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-02-19T13:19:19.873000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Guruve District Hospital', 'recordingMonth': 'January', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025Guruve District HospitalJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '3'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Guruve District Hospital', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client exhibited signs of the condition', 'services_referred': 'Diabetes Services'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Guruve District HospitalJanuary2025', 'facilityName': 'Guruve District Hospital', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025Guruve District HospitalJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '2', 'hivPositiveNC20-24': '1', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '2', 'total20-24NCHIVTested': '1', 'total25-29NCHIVTested': '0', 'total30-34NCHIVT ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7925, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/615d8e53-0ca6-458e-8128-6399c3d83c25/form.xml'}}, 'build_id': 'f5c8506889894a4cbe9e8b8a092b59f8', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '416', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'January', 'AERecordingSite': 'Guruve District Hospital', 'AERecordingYear': '2025', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'AE was properly addressed , client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '18', 'date_ae_identified': '2025-01-19', 'mcMethod': 'Surgical', 'vmmc_number': '00012'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '8'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-02-19T13:19:19.873000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Guruve District Hospital', 'recordingMonth': 'January', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025Guruve District HospitalJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '3'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Guruve District Hospital', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client exhibited signs of the condition', 'services_referred': 'Diabetes Services'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Guruve District HospitalJanuary2025', 'facilityName': 'Guruve District Hospital', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025Guruve District HospitalJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '2', 'hivPositiveNC20-24': '1', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '2', 'total20-24NCHIVTested': '1', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTe ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6873, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/fb6deeeb-c0fd-4cec-b699-5331b5e18c05/form.xml'}}, 'build_id': 'c5c99ae231314a268fe097bb448e1757', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '415', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '10', 'fu25-29': '6'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-02-14T05:49:04.769000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Svita Clinic', 'recordingMonth': 'January', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025Svita ClinicJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '2'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '2', 'total_hiv_positive_linked_to_care': '0'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Svita Clinic', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elavated BP', 'services_referred': 'Hypertensive'}}}, {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Svita Clinic', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'client exhibited signs of Diabetes', 'services_referred': 'Diabetes'}}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Svita ClinicJanuary2025', 'facilityName': 'Svita Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025Svita ClinicJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '12', 'hivNegativeNC20-24': '10', 'hivNegativeNC25-29': '9', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '0', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '12', 'total20-24NCHIVTested': '10', 'total25-29NCHIVTested': '9', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '31', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'hivNegative20-24': '10', 'hivNegative25-29': '9', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '31'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '31', 'surgical_disposable': {'sgDisposable15-19': '12', 'sgDisposable20-24': '10', 'sgDisposable25-29': '9', 'total_surgicalDisposable': 'OK ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4642, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/3282670c-5bd5-47eb-8a61-1b79818ecabd/form.xml'}}, 'build_id': 'c5c99ae231314a268fe097bb448e1757', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '415', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '22'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-01-20T12:59:16.010000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Negove Clinic', 'recordingMonth': 'January', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '2', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '3', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Negove ClinicJanuary2025', 'facilityName': 'Negove Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'total15-19HIVTested': '12', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '13', 'totalhivNegative': '12'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '25', 'surgical_disposable': {'sgDisposable15-19': '25', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '25', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MBERENGWA', 'DistrictLabelDisplay': 'District :      MBERENGWA', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      MUSUME - 101157 - MISSION HOSPITAL', 'Site_Name': 'MUSUME - 101157 - MISSION HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '25', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '25'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v415. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 415, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': '3282670c-5bd5-47eb-8a61-1b79818ecabd', 'timeEnd': '2025-01-20T12:59:16.010000Z', 'timeStart': '2025-01-20T12:54:40.384000Z', 'userID': 'd2e158e62cf442a493becb3793a04b2c', 'username': 'tsadomba'}, 'recordingPeriodList': {'recordingMonth': 'January', 'year': '2025'}, 'totalAES': '0'}, 'id': '3282670c-5bd5-47eb-8a61-1b79818ecabd', 'indexed_on': '2025-01-20T12:59:17.317258Z', 'initial_processing_complete': True, ' ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5369, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/51156860-4661-48cd-86c1-f22d5d25085b/form.xml'}}, 'build_id': 'c5c99ae231314a268fe097bb448e1757', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '415', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'November', 'AERecordingSite': 'Negove Clinic', 'AERecordingYear': '2025', 'question1': {'cancelthisAEReport': '1'}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25', 'fu20-24': '10'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-01-20T08:43:28.298000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Negove Clinic', 'recordingMonth': 'November', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '25', 'total_hiv_positive_linked_to_care': '1'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'November', 'ReferrelRecordingSite': 'Negove Clinic', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client was showing Malaria symptoms', 'services_referred': 'OPD'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '3', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Negove ClinicNovember2025', 'facilityName': 'Negove Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '18', 'hivNegative20-24': '10', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '1', 'total15-19HIVTested': '19', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '1', 'totalHIVUntested': '6', 'totalhivNegative': '28'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '35', 'surgical_disposable': {'sgDisposable15-19': '25', 'sgDisposable20-24': '10', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '35', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MBERENGWA', 'DistrictLabelDisplay': 'District :      MBERENGWA', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      MUSUME - 101157 - MISSION HOSPITAL', 'Site_Name': 'MUSUME - 101157 - MISSION HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '25', 'mc20-24': '10', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '35'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v415. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 415, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f8 ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7631, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/fa2cb754-cf7c-40e6-b269-7635a820d6a6/form.xml'}}, 'build_id': 'a7af704cb06b41fa89b9725ec5c39b9b', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '414', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'January', 'AERecordingSite': 'Mbembeswana', 'AERecordingYear': '2025', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'Client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '23', 'date_ae_identified': '2025-01-14', 'mcMethod': 'Surgical', 'vmmc_number': '00789'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25', 'fu20-24': '10'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-01-14T14:25:00.548000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Mbembeswana', 'recordingMonth': 'January', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '8', 'total_hiv_positive_linked_to_care': '2'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Mbembeswana', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had rash and fever', 'services_referred': 'OPD'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '3'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'MbembeswanaJanuary2025', 'facilityName': 'Mbembeswana', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '1', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '1', 'total20-24NCHIVTested': '0', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '1', 't ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5645, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/24905608-1e8a-4469-a760-24e2a2ff0864/form.xml'}}, 'build_id': 'a7af704cb06b41fa89b9725ec5c39b9b', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '414', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '45'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-01-14T09:50:29.454000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Beula', 'recordingMonth': 'January', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '2'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Beula', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'client was showing symptoms linked to diabetes condition', 'services_referred': 'Diabetes Services'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'BeulaJanuary2025', 'facilityName': 'Beula', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '35', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '2', 'total15-19HIVTested': '37', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '2', 'totalHIVUntested': '8', 'totalhivNegative': '35'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '45', 'surgical_disposable': {'sgDisposable15-19': '45', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '45', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MATOBO', 'DistrictLabelDisplay': 'District :      MATOBO', 'Province': 'MATABELELAND SOUTH', 'ProvinceLabelDisplay': 'Province :      MATABELELAND SOUTH', 'SiteLabelDisplay': 'Site  :      MAPHISA - 100890 - DISTRICT HOSPITAL', 'Site_Name': 'MAPHISA - 100890 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '45', 'mc20-2 ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4685, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/0fa81146-c58d-4b34-b7b4-5e302fa55b52/form.xml'}}, 'build_id': 'a7af704cb06b41fa89b9725ec5c39b9b', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '414', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '9'}}, 'commcare_usercase': {'case': {'@case_id': '8a402b83559c45d78df66825c9d67f1f', '@date_modified': '2025-01-14T09:10:04.392000Z', '@user_id': '970d6f38ae0b4441a32cd1a15cd852db', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Bvochora', 'recordingMonth': 'January', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024BirkdaleJanuary2025BrandonJanuary2025BvochoraJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'BvochoraJanuary2025', 'facilityName': 'Bvochora', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024BirkdaleJanuary2025BrandonJanuary2025BvochoraJanuary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': ''}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '9', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '9'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '9', 'surgical_disposable': {'sgDisposable15-19': '0', 'total_surgicalDisposable': 'OK'}, 'surgical_reusable': {'sgReusable15-19': '9', 'total_surgicalReusable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '0', 'totalSurgicalReusableMCs': '9'}, 'location_details': {'District': 'GURUVE', 'DistrictLabelDisplay': 'District :      GURUVE', 'Province': 'MASHONALAND CENTRAL', 'ProvinceLabelDisplay': 'Province :      MASHONALAND CENTRAL', 'SiteLabelDisplay': 'Site  :      GURUVE - 100553 - DISTRICT HOSPITAL', 'Site_Name': 'GURUVE - 100553 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '9', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '9'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v414. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 414, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': '0fa81146-c58d-4b34-b7b4-5e302fa55b52', 'timeEnd': '2025-01-14T09:10:04.392000Z', 'timeStart': '2025-01-14T09:09:12.577000Z', 'userID': '970d6f38ae0b4441a32cd1a15cd852db', 'username': 'tnyemba'}, 'recordingPeriodList': {'recordingMonth': 'January', 'year': '2025'}, 'totalAES': '0'}, 'id': '0fa81146-c58d-4b34-b7b4-5e302fa55b52', 'indexed_on': '2025-01-14T0 ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4554, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/82b38500-2985-47c0-ba68-6837cb8e8c82/form.xml'}}, 'build_id': 'a7af704cb06b41fa89b9725ec5c39b9b', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '414', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '25'}}, 'commcare_usercase': {'case': {'@case_id': '8a402b83559c45d78df66825c9d67f1f', '@date_modified': '2025-01-14T08:21:03.189000Z', '@user_id': '970d6f38ae0b4441a32cd1a15cd852db', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Brandon', 'recordingMonth': 'January', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024BirkdaleJanuary2025BrandonJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'BrandonJanuary2025', 'facilityName': 'Brandon', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024BirkdaleJanuary2025BrandonJanuary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '25', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '25'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '25', 'surgical_disposable': {'sgDisposable15-19': '25', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '25', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'GURUVE', 'DistrictLabelDisplay': 'District :      GURUVE', 'Province': 'MASHONALAND CENTRAL', 'ProvinceLabelDisplay': 'Province :      MASHONALAND CENTRAL', 'SiteLabelDisplay': 'Site  :      GURUVE - 100553 - DISTRICT HOSPITAL', 'Site_Name': 'GURUVE - 100553 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '25', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '25'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v414. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 414, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': '82b38500-2985-47c0-ba68-6837cb8e8c82', 'timeEnd': '2025-01-14T08:21:03.189000Z', 'timeStart': '2025-01-14T08:20:17.120000Z', 'userID': '970d6f38ae0b4441a32cd1a15cd852db', 'username': 'tnyemba'}, 'recordingPeriodList': {'recordingMonth': 'January', 'year': '2025'}, 'totalAES': '0'}, 'id': '82b38500-2985-47c0-ba68-6837cb8e8c82', 'indexed_on': '2025-01-14T08:21:04.994291Z', 'initial_processing_complete': True, 'is_phone_submission': True, 'metadata': {'appVersion':  ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 5189, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/2628ae46-ccc2-4581-a436-89a6e32456f7/form.xml'}}, 'build_id': '008bb5cb51ba41d2a81a9f0089d894f7', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '413', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '20', 'fu20-24': '10', 'fu30-34': '6'}}, 'commcare_usercase': {'case': {'@case_id': '8a402b83559c45d78df66825c9d67f1f', '@date_modified': '2025-01-14T06:09:13.356000Z', '@user_id': '970d6f38ae0b4441a32cd1a15cd852db', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Birkdale', 'recordingMonth': 'January', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024BirkdaleJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '1'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '0'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Birkdale', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elevated BP', 'services_referred': 'Hypertensive'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '12', 'total_mcs_referred_for_sti_services': '12'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'BirkdaleJanuary2025', 'facilityName': 'Birkdale', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024BirkdaleJanuary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '20', 'hivNegative20-24': '8', 'hivNegative30-34': '6', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive20-24': '0', 'total15-19HIVTested': '', 'total20-24HIVTested': '8', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '2', 'totalhivNegative': '34'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '36', 'surgical_disposable': {'sgDisposable15-19': '20', 'sgDisposable20-24': '10', 'sgDisposable30-34': '6', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '36', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'GURUVE', 'DistrictLabelDisplay': 'District :      GURUVE', 'Province': 'MASHONALAND CENTRAL', 'ProvinceLabelDisplay': 'Province :      MASHONALAND CENTRAL', 'SiteLabelDisplay': 'Site  :      GURUVE - 100553 - DISTRICT HOSPITAL', 'Site_Name': 'GURUVE - 100553 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '20', 'mc20-24': '10', 'mc25-29': '0', 'mc30-34': '6', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '36'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v413. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 413, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': '2628ae46-ccc2-4581-a436-89a6e32456f7', 'timeEnd' ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6068, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/9df3de8d-e650-409b-beb5-5fa23f3db512/form.xml'}}, 'build_id': None, 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': '2025-01-14T09:16:11.679048Z', 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '412', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '14'}}, 'commcare_usercase': {'case': {'@case_id': '8a402b83559c45d78df66825c9d67f1f', '@date_modified': '2025-01-07T10:19:40.720000Z', '@user_id': '970d6f38ae0b4441a32cd1a15cd852db', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Gota', 'recordingMonth': 'December', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '2'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '12', 'total_hiv_positive_linked_to_care': '9'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'December', 'ReferrelRecordingSite': 'Gota', 'ReferrelRecordingYear': '2024', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'client referred for malaria treatment', 'services_referred': 'OPD'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '13', 'total_mcs_referred_for_sti_services': '12'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'GotaDecember2024', 'facilityName': 'Gota', 'savedFacilities': 'Guruve District HospitalDecember2024ChipuriroDecember2024GotaDecember2024'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '1', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '9', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '10', 'total20-24NCHIVTested': '0', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '9', 'totalhivNegativeNC': '1', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '15', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '15'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '15', 'surgical_disposable': {'sgDisposable15-19': '15', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '15', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'GURUVE', 'DistrictLabelDisplay': 'District :      GURUVE', 'Province': 'MASHONALAND CENTRAL', 'ProvinceLabelDisplay': 'Province :      MASHONALAND CENTRAL', 'SiteLabelDisplay': 'Site  :      GURUVE - 100553 - DISTRICT HOSPITAL', 'Site_Name': 'GURUVE - 100553 - DISTRICT HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disagg ...
# ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4642, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/3282670c-5bd5-47eb-8a61-1b79818ecabd/form.xml'}}, 'build_id': 'c5c99ae231314a268fe097bb448e1757', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '415', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '22'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-01-20T12:59:16.010000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Negove Clinic', 'recordingMonth': 'January', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '2', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '3', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Negove ClinicJanuary2025', 'facilityName': 'Negove Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'total15-19HIVTested': '12', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '13', 'totalhivNegative': '12'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '25', 'surgical_disposable': {'sgDisposable15-19': '25', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '25', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'MBERENGWA', 'DistrictLabelDisplay': 'District :      MBERENGWA', 'Province': 'MIDLANDS', 'ProvinceLabelDisplay': 'Province :      MIDLANDS', 'SiteLabelDisplay': 'Site  :      MUSUME - 101157 - MISSION HOSPITAL', 'Site_Name': 'MUSUME - 101157 - MISSION HOSPITAL', 'countryID': 'ZIMBABWE', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '25', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '25'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.54.1"(467561). App v415. CommCare Version 2.54.1. Build 467561, built on: 2024-10-25', 'app_build_version': 415, 'commcare_version': '2.54.1', 'deviceID': 'commcare_c0bf9f85-6d1f-4563-a7b5-e60f61118366', 'drift': '0', 'geo_point': None, 'instanceID': '3282670c-5bd5-47eb-8a61-1b79818ecabd', 'timeEnd': '2025-01-20T12:59:16.010000Z', 'timeStart': '2025-01-20T12:54:40.384000Z', 'userID': 'd2e158e62cf442a493becb3793a04b2c', 'username': 'tsadomba'}, 'recordingPeriodList': {'recordingMonth': 'January', 'year': '2025'}, 'totalAES': '0'}, 'id': '3282670c-5bd5-47eb-8a61-1b79818ecabd', 'indexed_on': '2025-01-20T12:59:17.317258Z', 'initial_processing_complete': True, ' ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 6873, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/fb6deeeb-c0fd-4cec-b699-5331b5e18c05/form.xml'}}, 'build_id': 'c5c99ae231314a268fe097bb448e1757', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '415', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '10', 'fu25-29': '6'}}, 'commcare_usercase': {'case': {'@case_id': '8d1778403dab4c378136124f960aedb8', '@date_modified': '2025-02-14T05:49:04.769000Z', '@user_id': 'd2e158e62cf442a493becb3793a04b2c', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Svita Clinic', 'recordingMonth': 'January', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025Svita ClinicJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '2'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '2', 'total_hiv_positive_linked_to_care': '0'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Svita Clinic', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elavated BP', 'services_referred': 'Hypertensive'}}}, {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Svita Clinic', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'client exhibited signs of Diabetes', 'services_referred': 'Diabetes'}}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Svita ClinicJanuary2025', 'facilityName': 'Svita Clinic', 'savedFacilities': 'Musume HospitalDecember2024Neta ClinicDecember2024Svita ClinicDecember2024Negove ClinicNovember2025Negove ClinicJanuary2025Svita ClinicJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '12', 'hivNegativeNC20-24': '10', 'hivNegativeNC25-29': '9', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '0', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '12', 'total20-24NCHIVTested': '10', 'total25-29NCHIVTested': '9', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '31', 'uncircumcisedClientsForHTS': '1'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'hivNegative20-24': '10', 'hivNegative25-29': '9', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '31'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '31', 'surgical_disposable': {'sgDisposable15-19': '12', 'sgDisposable20-24': '10', 'sgDisposable25-29': '9', 'total_surgicalDisposable': 'OK ...
# {'app_id': 'cbd88c81d5a9131517e106028f0dd680', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7925, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/615d8e53-0ca6-458e-8128-6399c3d83c25/form.xml'}}, 'build_id': 'f5c8506889894a4cbe9e8b8a092b59f8', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC  Data Collection Form', '@uiVersion': '1', '@version': '416', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'adverse_events': {'question3': {'AERecordingMonth': 'January', 'AERecordingSite': 'Guruve District Hospital', 'AERecordingYear': '2025', 'question1': {'cancelthisAEReport': '', 'question1': {'aeComments': 'AE was properly addressed , client is healing', 'ae_classification': 'Moderate', 'ae_type_code': 'COA', 'checkMonthValidation': '1', 'checkYearValidation': '1', 'circumcising_cadre': 'Nurse', 'client_age': '18', 'date_ae_identified': '2025-01-19', 'mcMethod': 'Surgical', 'vmmc_number': '00012'}}}}, 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '8'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-02-19T13:19:19.873000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facility_name': 'Guruve District Hospital', 'recordingMonth': 'January', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025Guruve District HospitalJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'kp_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '15', 'total_hiv_positive_linked_to_care': '3'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'January', 'ReferrelRecordingSite': 'Guruve District Hospital', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client exhibited signs of the condition', 'services_referred': 'Diabetes Services'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Guruve District HospitalJanuary2025', 'facilityName': 'Guruve District Hospital', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025Guruve District HospitalJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '0', 'hivNegativeNC20-24': '0', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive30-34': '0', 'hivPositiveNC15-19': '2', 'hivPositiveNC20-24': '1', 'hivPositiveNC25-29': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '2', 'total20-24NCHIVTested': '1', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTe ...
#   AERecordingMonth AERecordingSite AERecordingYear     District  \
# 0         November    Krima Clinic            2024  GOKWE SOUTH
# 1         November    Krima Clinic            2024  GOKWE SOUTH
# 2         November    Krima Clinic            2024  GOKWE SOUTH
# 3         November    Krima Clinic            2024  GOKWE SOUTH
#
#   cancelthisAEReport      aeComments ae_classification ae_type_code  \
# 0                     Client healing            Severe          COA
# 1                     Client healing          Moderate           BL
# 2                     Client healing            Severe          COA
# 3                     Client healing          Moderate           BL
#
#   checkMonthValidation checkYearValidation circumcising_cadre client_age  \
# 0                    1                   1              Nurse         25
# 1                    1                   1              Nurse         18
# 2                    1                   1              Nurse         25
# 3                    1                   1              Nurse         18
#
#   date_ae_identified  mcMethod vmmc_number
# 0         2024-11-10  Surgical      467233
# 1         2024-11-08  Surgical      245555
# 2         2024-11-10  Surgical      467233
# 3         2024-11-08  Surgical      245555

# %%
general_df_sorted
# Out:
#    AERecordingMonth               AERecordingSite AERecordingYear  \
# 0           January      Guruve District Hospital            2025
# 1               NaN                           NaN             NaN
# 2               NaN                           NaN             NaN
# 3          November                 Negove Clinic            2025
# 4           January                   Mbembeswana            2025
# 5               NaN                           NaN             NaN
# 6               NaN                           NaN             NaN
# 7               NaN                           NaN             NaN
# 8               NaN                           NaN             NaN
# 9               NaN                           NaN             NaN
# 10         December                  Svita Clinic            2024
# 11              NaN                           NaN             NaN
# 12         December               Musume Hospital            2024
# 13         December                     Chipuriro            2024
# 14              NaN                           NaN             NaN
# 15         December      Guruve District Hospital            2024
# 16              NaN                           NaN             NaN
# 17              NaN                           NaN             NaN
# 18         December  Gwanyika Rural Health Centre            2024
# 19              NaN                           NaN             NaN
# 20         November                    Katema RDC            2024
# 21         November                 Jahana Clinic            2024
# 22              NaN                           NaN             NaN
# 23         November                  Huchu Clinic            2024
# 24         November                  Huchu Clinic            2024
# 25              NaN                           NaN             NaN
# 26         November                 Jahana Clinic            2024
# 27         November                    Katema RDC            2024
# 28              NaN                           NaN             NaN
# 29         December  Gwanyika Rural Health Centre            2024
# 30              NaN                           NaN             NaN
# 31              NaN                           NaN             NaN
# 32         December      Guruve District Hospital            2024
# 33              NaN                           NaN             NaN
# 34         December                     Chipuriro            2024
# 35         December               Musume Hospital            2024
# 36              NaN                           NaN             NaN
# 37         December                  Svita Clinic            2024
# 38              NaN                           NaN             NaN
# 39              NaN                           NaN             NaN
# 40              NaN                           NaN             NaN
# 41              NaN                           NaN             NaN
# 42              NaN                           NaN             NaN
# 43          January                   Mbembeswana            2025
# 44         November                 Negove Clinic            2025
# 45              NaN                           NaN             NaN
# 46              NaN                           NaN             NaN
# 47          January      Guruve District Hospital            2025
#
#        District ReferrelRecordingMonth          ReferrelRecordingSite  \
# 0        GURUVE                January       Guruve District Hospital
# 1     MBERENGWA                    NaN                            NaN
# 2     MBERENGWA                    NaN                            NaN
# 3     MBERENGWA               November                  Negove Clinic
# 4        MATOBO                January                    Mbembeswana
# 5        MATOBO                January                          Beula
# 6        GURUVE                    NaN                            NaN
# 7        GURUVE                    NaN                            NaN
# 8        GURUVE                January                       Birkdale
# 9        GURUVE               December                           Gota
# 10    MBERENGWA               December                   Svita Clinic
# 11    MBERENGWA               December                    Neta Clinic
# 12    MBERENGWA                    NaN                            NaN
# 13       GURUVE                    NaN                            NaN
# 14  GOKWE SOUTH                    NaN                            NaN
# 15       GURUVE               December       Guruve District Hospital
# 16       MATOBO                    NaN                            NaN
# 17  GOKWE SOUTH               December  Gokwe South District Hospital
# 18  GOKWE SOUTH               December   Gwanyika Rural Health Centre
# 19  GOKWE SOUTH                    NaN                            NaN
# 20  GOKWE SOUTH                    NaN                            NaN
# 21  GOKWE SOUTH                    NaN                            NaN
# 22  GOKWE SOUTH                    NaN                            NaN
# 23  GOKWE SOUTH               November                   Huchu Clinic
# 24  GOKWE SOUTH               November                   Huchu Clinic
# 25  GOKWE SOUTH                    NaN                            NaN
# 26  GOKWE SOUTH                    NaN                            NaN
# 27  GOKWE SOUTH                    NaN                            NaN
# 28  GOKWE SOUTH                    NaN                            NaN
# 29  GOKWE SOUTH               December   Gwanyika Rural Health Centre
# 30  GOKWE SOUTH               December  Gokwe South District Hospital
# 31       MATOBO                    NaN                            NaN
# 32       GURUVE               December       Guruve District Hospital
# 33  GOKWE SOUTH                    NaN                            NaN
# 34       GURUVE                    NaN                            NaN
# 35    MBERENGWA                    NaN                            NaN
# 36    MBERENGWA               December                    Neta Clinic
# 37    MBERENGWA               December                   Svita Clinic
# 38       GURUVE                January                       Birkdale
# 39       GURUVE                    NaN                            NaN
# 40       GURUVE                    NaN                            NaN
# 41       GURUVE               December                           Gota
# 42       MATOBO                January                          Beula
# 43       MATOBO                January                    Mbembeswana
# 44    MBERENGWA               November                  Negove Clinic
# 45    MBERENGWA                    NaN                            NaN
# 46    MBERENGWA                    NaN                            NaN
# 47       GURUVE                January       Guruve District Hospital
#
#    ReferrelRecordingYear                             Site_Name  \
# 0                   2025   GURUVE - 100553 - DISTRICT HOSPITAL
# 1                    NaN    MUSUME - 101157 - MISSION HOSPITAL
# 2                    NaN    MUSUME - 101157 - MISSION HOSPITAL
# 3                   2025    MUSUME - 101157 - MISSION HOSPITAL
# 4                   2025  MAPHISA - 100890 - DISTRICT HOSPITAL
# 5                   2025  MAPHISA - 100890 - DISTRICT HOSPITAL
# 6                    NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 7                    NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 8                   2025   GURUVE - 100553 - DISTRICT HOSPITAL
# 9                   2024   GURUVE - 100553 - DISTRICT HOSPITAL
# 10                  2024    MUSUME - 101157 - MISSION HOSPITAL
# 11                  2024    MUSUME - 101157 - MISSION HOSPITAL
# 12                   NaN    MUSUME - 101157 - MISSION HOSPITAL
# 13                   NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 14                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 15                  2024   GURUVE - 100553 - DISTRICT HOSPITAL
# 16                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 17                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 18                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 19                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 20                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 21                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 22                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 23                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 24                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 25                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 26                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 27                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 28                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 29                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 30                  2024    GOKWE - 100513 - DISTRICT HOSPITAL
# 31                   NaN  MAPHISA - 100890 - DISTRICT HOSPITAL
# 32                  2024   GURUVE - 100553 - DISTRICT HOSPITAL
# 33                   NaN    GOKWE - 100513 - DISTRICT HOSPITAL
# 34                   NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 35                   NaN    MUSUME - 101157 - MISSION HOSPITAL
# 36                  2024    MUSUME - 101157 - MISSION HOSPITAL
# 37                  2024    MUSUME - 101157 - MISSION HOSPITAL
# 38                  2025   GURUVE - 100553 - DISTRICT HOSPITAL
# 39                   NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 40                   NaN   GURUVE - 100553 - DISTRICT HOSPITAL
# 41                  2024   GURUVE - 100553 - DISTRICT HOSPITAL
# 42                  2025  MAPHISA - 100890 - DISTRICT HOSPITAL
# 43                  2025  MAPHISA - 100890 - DISTRICT HOSPITAL
# 44                  2025    MUSUME - 101157 - MISSION HOSPITAL
# 45                   NaN    MUSUME - 101157 - MISSION HOSPITAL
# 46                   NaN    MUSUME - 101157 - MISSION HOSPITAL
# 47                  2025   GURUVE - 100553 - DISTRICT HOSPITAL
#
#    TotalMCsBYMethod                                       aeComments  ...  \
# 0                22    AE was properly addressed , client is healing  ...
# 1                31                                              NaN  ...
# 2                25                                              NaN  ...
# 3                35                                              NaN  ...
# 4                35                                Client is healing  ...
# 5                45                                              NaN  ...
# 6                 9                                              NaN  ...
# 7                25                                              NaN  ...
# 8                36                                              NaN  ...
# 9                15                                              NaN  ...
# 10               43                                Client is healing  ...
# 11               45                                              NaN  ...
# 12               25                                Client is healing  ...
# 13               46                                Client is healing  ...
# 14               24                                              NaN  ...
# 15               34                                Client is healing  ...
# 16               43                                              NaN  ...
# 17               73                                              NaN  ...
# 18               37                                Client is healing  ...
# 19               25                                              NaN  ...
# 20               94                                Client is healing  ...
# 21               80  Sature elavated  by lignocaine,\nclient healing  ...
# 22               35                                              NaN  ...
# 23               60                                Client is healing  ...
# 24               60                                Client is healing  ...
# 25               35                                              NaN  ...
# 26               80  Sature elavated  by lignocaine,\nclient healing  ...
# 27               94                                Client is healing  ...
# 28               25                                              NaN  ...
# 29               37                                Client is healing  ...
# 30               73                                              NaN  ...
# 31               43                                              NaN  ...
# 32               34                                Client is healing  ...
# 33               24                                              NaN  ...
# 34               46                                Client is healing  ...
# 35               25                                Client is healing  ...
# 36               45                                              NaN  ...
# 37               43                                Client is healing  ...
# 38               36                                              NaN  ...
# 39               25                                              NaN  ...
# 40                9                                              NaN  ...
# 41               15                                              NaN  ...
# 42               45                                              NaN  ...
# 43               35                                Client is healing  ...
# 44               35                                              NaN  ...
# 45               25                                              NaN  ...
# 46               31                                              NaN  ...
# 47               22    AE was properly addressed , client is healing  ...
#
#    total_surgicalReusable total_surgicalReusable total_surgicalReusable  \
# 0                      OK                     OK                     OK
# 1                     NaN                     OK                     OK
# 2                     NaN                    NaN                     OK
# 3                     NaN                    NaN                     OK
# 4                     NaN                     OK                     OK
# 5                     NaN                    NaN                     OK
# 6                      OK                    NaN                     OK
# 7                     NaN                    NaN                     OK
# 8                     NaN                    NaN                     OK
# 9                     NaN                     OK                     OK
# 10                    NaN                    NaN                     OK
# 11                    NaN                    NaN                     OK
# 12                    NaN                     OK                     OK
# 13                     OK                    NaN                     OK
# 14                    NaN                     OK                     OK
# 15                     OK                    NaN                     OK
# 16                     OK                     OK                     OK
# 17                     OK                    NaN                     OK
# 18                     OK                    NaN                     OK
# 19                    NaN                    NaN                     OK
# 20                     OK                    NaN                     OK
# 21                     OK                     OK                     OK
# 22                     OK                    NaN                     OK
# 23                     OK                     OK                     OK
# 24                     OK                     OK                     OK
# 25                     OK                    NaN                     OK
# 26                     OK                     OK                     OK
# 27                     OK                    NaN                     OK
# 28                    NaN                    NaN                     OK
# 29                     OK                    NaN                     OK
# 30                     OK                    NaN                     OK
# 31                     OK                     OK                     OK
# 32                     OK                    NaN                     OK
# 33                    NaN                     OK                     OK
# 34                     OK                    NaN                     OK
# 35                    NaN                     OK                     OK
# 36                    NaN                    NaN                     OK
# 37                    NaN                    NaN                     OK
# 38                    NaN                    NaN                     OK
# 39                    NaN                    NaN                     OK
# 40                     OK                    NaN                     OK
# 41                    NaN                     OK                     OK
# 42                    NaN                    NaN                     OK
# 43                    NaN                     OK                     OK
# 44                    NaN                    NaN                     OK
# 45                    NaN                    NaN                     OK
# 46                    NaN                     OK                     OK
# 47                     OK                     OK                     OK
#
#    total_surgicalReusable totalhivNegative totalhivNegativeNC  \
# 0                      OK               22                  0
# 1                     NaN               31                 31
# 2                     NaN               12                  0
# 3                     NaN               28                  0
# 4                     NaN               34                  0
# 5                     NaN               35                  0
# 6                      OK                9                  0
# 7                     NaN               25                  0
# 8                     NaN               34                  0
# 9                     NaN               15                  1
# 10                    NaN               43                  0
# 11                    NaN               44                  0
# 12                    NaN               25                  0
# 13                     OK               44                  0
# 14                    NaN               24                  0
# 15                     OK               32                  0
# 16                     OK               43                  0
# 17                     OK               69                  0
# 18                     OK               37                  0
# 19                    NaN               25                  0
# 20                     OK               13                  0
# 21                     OK               80                  1
# 22                     OK               35                  0
# 23                     OK               59                  0
# 24                     OK               59                  0
# 25                     OK               35                  0
# 26                     OK               80                  1
# 27                     OK               13                  0
# 28                    NaN               25                  0
# 29                     OK               37                  0
# 30                     OK               69                  0
# 31                     OK               43                  0
# 32                     OK               32                  0
# 33                    NaN               24                  0
# 34                     OK               44                  0
# 35                    NaN               25                  0
# 36                    NaN               44                  0
# 37                    NaN               43                  0
# 38                    NaN               34                  0
# 39                    NaN               25                  0
# 40                     OK                9                  0
# 41                    NaN               15                  1
# 42                    NaN               35                  0
# 43                    NaN               34                  0
# 44                    NaN               28                  0
# 45                    NaN               12                  0
# 46                    NaN               31                 31
# 47                     OK               22                  0
#
#    uncircumcisedClientsForHTS vmmc_number  year facilityType
# 0                           1       00012  2025          NaN
# 1                           1         NaN  2025          NaN
# 2                           0         NaN  2025          NaN
# 3                           0         NaN  2025          NaN
# 4                           1       00789  2025     Outreach
# 5                           0         NaN  2025     Outreach
# 6                                     NaN  2025          NaN
# 7                           0         NaN  2025          NaN
# 8                           0         NaN  2025          NaN
# 9                           1         NaN  2025          NaN
# 10                          0     0585858  2024          NaN
# 11                          0         NaN  2024          NaN
# 12                          1      009857  2024          NaN
# 13                          0      008886  2024          NaN
# 14                          1         NaN  2024     Outreach
# 15                          0      000456  2024          NaN
# 16                          1         NaN  2024     Outreach
# 17                          0         NaN  2024       Static
# 18                          0      345534  2024     Outreach
# 19                          0         NaN  2024     Outreach
# 20                          0      234556  2024     Outreach
# 21                          1      234455  2024     Outreach
# 22                          0         NaN  2024     Outreach
# 23                          1       00056  2024     Outreach
# 24                          1       00056  2024     Outreach
# 25                          0         NaN  2024     Outreach
# 26                          1      234455  2024     Outreach
# 27                          0      234556  2024     Outreach
# 28                          0         NaN  2024     Outreach
# 29                          0      345534  2024     Outreach
# 30                          0         NaN  2024       Static
# 31                          1         NaN  2024     Outreach
# 32                          0      000456  2024          NaN
# 33                          1         NaN  2024     Outreach
# 34                          0      008886  2024          NaN
# 35                          1      009857  2024          NaN
# 36                          0         NaN  2024          NaN
# 37                          0     0585858  2024          NaN
# 38                          0         NaN  2025          NaN
# 39                          0         NaN  2025          NaN
# 40                                    NaN  2025          NaN
# 41                          1         NaN  2025          NaN
# 42                          0         NaN  2025     Outreach
# 43                          1       00789  2025     Outreach
# 44                          0         NaN  2025          NaN
# 45                          0         NaN  2025          NaN
# 46                          1         NaN  2025          NaN
# 47                          1       00012  2025          NaN
#
# [48 rows x 155 columns]
