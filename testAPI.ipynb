# %%
import pandas as pd
from commcare_export.checkpoint import CheckpointManagerWithDetails
from commcare_export.commcare_hq_client import CommCareHqClient, AUTH_MODE_APIKEY
from commcare_export.commcare_minilinq import get_paginator, PaginationMode
from datetime import datetime
import re

# CommCare credentials
username = 'amutenha@zimttech.org'  # Replace with your actual CommCare username
domain = 'zdip'  # Your CommCare project domain
hq_host = 'https://zdip.zimttech.org'  # Your CommCare HQ custom host
API_KEY = '92fbb3f98433a6929a33015273ebe7b38b6dac39'  # Replace with the API key generated in CommCare


zazicSites= pd.read_excel('zazicFacilities.xlsx')

data = pd.ExcelFile('ZDIPlookup.xlsx')

lookupTable = pd.read_excel(data,'previousVMMCSubmissions')

lookupTable.columns = [col.replace('field: ', '') if col.startswith('field: ') else col for col in lookupTable.columns]

# Initialize API client
api_client = CommCareHqClient(hq_host, domain, username, API_KEY, AUTH_MODE_APIKEY)

# Create a paginator for the 'form' resource (fetching data from a form)
form_paginator = get_paginator(resource='form', pagination_mode=PaginationMode.date_modified, page_size=100)
form_paginator.init()

# Initialize checkpoint manager (None used here for simplicity)
checkpoint_manager = CheckpointManagerWithDetails(None, None, PaginationMode.date_modified)

# Date range for filtering
start_date = datetime(2025, 3, 3)  # 2 December 2024
end_date = datetime(2025, 12, 25)  # 6 December 2024

# Specify the app_id to filter forms
desired_app_id ='4e6668dfd6adb19fe71beb316114b48f'  


referrals_data = []
AEs_data = []
general_data = []

# Fetch forms iteratively
# Fetch forms using manual pagination
all_forms = []
offset = 0

params = {
    'limit':10000000,
    'app_id': desired_app_id,
    'received_on_start': start_date.strftime('%Y-%m-%dT%H:%M:%S'),
    'received_on_end': end_date.strftime('%Y-%m-%dT%H:%M:%S')
}

forms = api_client.iterate(
    'form',
    form_paginator,
    checkpoint_manager=checkpoint_manager,
    params=params
)

for form in forms:
    all_forms.append(form)
    if len(all_forms) >= 600:  # Early stopping if desired
        break

# %%
# Print a few fetched forms to verify filtering
for form in all_forms[:5]:  
    print(f"Received On: {form.get('received_on')}, App ID: {form.get('app_id')}")

filteredResults =[]
for i in all_forms:
    if i["app_id"] ==desired_app_id:
        filteredResults.append(i)

print(filteredResults)
# Filter and categorize forms by app_id and date
for form in forms:
    if form.get('app_id') == desired_app_id:
        print(form)
        form_received_date = datetime.strptime(form['received_on'], "%Y-%m-%dT%H:%M:%S.%fZ")
        if start_date <= form_received_date <= end_date:
            general_data.append(form)
# Convert each list to a pandas DataFrame
general_df = pd.json_normalize(general_data)
general_df.to_excel('test.xlsx')

general_df.columns = [re.split(r'[./]', col)[-1] for col in general_df.columns]
# Out:
# Received On: 2025-06-11T13:27:55.938474Z, App ID: 4e6668dfd6adb19fe71beb316114b48f
# Received On: 2025-06-11T13:27:55.634052Z, App ID: 4e6668dfd6adb19fe71beb316114b48f
# Received On: 2025-06-11T13:27:55.388455Z, App ID: 4e6668dfd6adb19fe71beb316114b48f
# Received On: 2025-06-11T13:27:55.018606Z, App ID: 4e6668dfd6adb19fe71beb316114b48f
# Received On: 2025-06-11T13:27:54.743215Z, App ID: 4e6668dfd6adb19fe71beb316114b48f
# [{'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 14477, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/15a1606a-5983-4fb1-a44e-999ebfdf6b37/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '33', 'fu15-19': '13', 'fu20-24': '13', 'fu25-29': '5', 'fu30-34': '2', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:27:24.885000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Waddilove Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025Nyembanzvere ClinicMay2025Waddilove ClinicMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Waddilove ClinicMay2025', 'facilityName': 'Waddilove Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025Nyembanzvere ClinicMay2025Waddilove ClinicMay2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv15-19calculated': 'Default Value', 'hiv20-24calculated' ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 14477, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/15a1606a-5983-4fb1-a44e-999ebfdf6b37/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '33', 'fu15-19': '13', 'fu20-24': '13', 'fu25-29': '5', 'fu30-34': '2', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:27:24.885000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Waddilove Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025Nyembanzvere ClinicMay2025Waddilove ClinicMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Waddilove ClinicMay2025', 'facilityName': 'Waddilove Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025Nyembanzvere ClinicMay2025Waddilove ClinicMay2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv15-19calculated': 'Default Value', 'hiv20-24calculated': ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 14443, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/27aa4c5d-4bad-4738-8268-99c7e88352fc/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '41', 'fu15-19': '19', 'fu20-24': '12', 'fu25-29': '9', 'fu30-34': '1', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:22:05.982000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Nyembanzvere Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025Nyembanzvere ClinicMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '2', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Nyembanzvere ClinicMay2025', 'facilityName': 'Nyembanzvere Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025Nyembanzvere ClinicMay2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv15-19calculated': 'Default Value', 'hiv20-24calculated': 'Default Value', 'hiv25-29calculated ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4813, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/f624d3eb-7c3b-4da8-9106-14ac1ccf13a6/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:18:28.420000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Mudzimurema Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025'}}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Mudzimurema ClinicMay2025', 'facilityName': 'Mudzimurema Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025Mudzimurema ClinicMay2025'}, 'formSubmissionList': {'formType': 'submission'}, 'location_details': {'District': 'MARONDERA', 'DistrictLabelDisplay': 'District :      MARONDERA', 'Province': 'MASHONALAND EAST', 'ProvinceLabelDisplay': 'Province :      MASHONALAND EAST', 'SiteLabelDisplay': 'Site  :      MAHUSEKWA - 100829 - HOSPITAL', 'Site_Name': 'MAHUSEKWA - 100829 - HOSPITAL', 'countryID': 'Zimbabwe', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc35-39CorrectionValue': '0', 'mc_by_age_disaggregation': {'age15-19Title': '15-19 yrs', 'age20-24Title': '20-24 yrs', 'age25-29Title': '25-29 yrs', 'age30-34Title': '30-34 yrs', 'age35-39Title': '35-39 yrs', 'age40-44Title': '40-44 yrs', 'age45-49Title': '45-49 yrs', 'age50Title': '50+ yrs', 'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '0', 'mc15-19CorrectionValue': '0', 'mc20-24': '0', 'mc20-24CorrectionValue': '0', 'mc25-29': '0', 'mc25-29CorrectionValue': '0', 'mc30-34': '0', 'mc30-34CorrectionValue': '0', 'mc35-39': '0', 'mc35-39CorrectionValue': '0', 'mc40-44': '0', 'mc40-44CorrectionValue': '0', 'mc45-49': '0', 'mc45-49CorrectionValue': '0', 'mc50': '', 'mc50CorrectionValue': '0', 'totalMCs': '0'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.56"(471791). App v23. CommCare Version 2.56.0. Build 471791, built on: 2025-04-11', 'app_build_version': 23, 'commcare_version': '2.56.0', 'deviceID': 'commcare_a9a02215-9fa4-4942-ac3c-737b6741adca', 'drift': '0', 'geo_point': None, 'instanceID': 'f624d3eb- ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 13844, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/35d374cd-9eb9-476f-96f9-fa8ca9f3607f/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '13', 'fu15-19': '3', 'fu20-24': '7', 'fu25-29': '3', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:17:30.570000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Mahusekwa District Hospital', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '1'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Mahusekwa District HospitalMay2025', 'facilityName': 'Mahusekwa District Hospital', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025Mahusekwa District HospitalMay2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv15-19calculated': 'Default Value', 'hiv20-24calculated': 'Default Value', 'hiv25-29calculated': 'Default Value', 'hiv30-34calculated': 'Default Value', 'hiv35-39calculated': 'Default Value' ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 14024, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/b277d597-6a2c-4b69-b3e4-3126f977a09e/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '12', 'fu15-19': '6', 'fu20-24': '4', 'fu25-29': '2', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:14:34.869000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Chakadini Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Chakadini ClinicMay2025', 'facilityName': 'Chakadini Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025Chakadini ClinicMay2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv15-19calculated': 'Default Value', 'hiv20-24calculated': 'Default Value', 'hiv25-29calculated': 'Default Value', 'hiv30-34calculated': 'Default Value', 'hiv35-39calculated': 'Default Value', 'hiv40-44calculated': 'Default Value', 'hiv45-49calculated': 'Default Value', 'hiv50calculated': 'D ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 16829, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/19fc02a0-8828-48c1-a9bf-4928affad83d/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '24', 'fu15-19': '11', 'fu20-24': '7', 'fu25-29': '4', 'fu30-34': '2', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '3edf78d42aeb4255a162c9e38c3f6fb9', '@date_modified': '2025-06-11T13:10:35.929000Z', '@user_id': 'efcaa54d36ed4239ab8493e6093a6fe4', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Border Church Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '1'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Border Church ClinicMay2025', 'facilityName': 'Border Church Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Border Church ClinicFebruary2025Border Church ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Madam ombre ClinicApril2025Mahusekwa District HospitalApril2025Mudzimurema ClinicApril2025Nyembanzvere ClinicApril2025Waddilove ClinicApril2025Chakadini ClinicApril2025Chimbwanda ClinicApril2025Border Church ClinicApril2025Border Church ClinicApril2025Border Church ClinicMay2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hiv15-19NCQs': '', 'hiv20-24NCQs': '', 'hiv25-29NCQs': '', 'hiv30-34NCQs': '', 'hiv35-39NCQs': '', 'hiv40-44NCQs': '', 'hiv45-49NCQs': '', 'hiv50NCQs': '', 'hivNegativeNC15-19': '0', 'hivNegativeNC15-19calculation': 'Default Value', 'hivNegativeNC20-24': '0', 'hivNegativeNC20-24calculation': 'Default Value', 'hivNegativeNC25-29': '1', 'hivNegativeNC25-29calculation': 'Default Value', 'hivNegativeNC30-34': '1', 'hivNegativeNC30-34calcula ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 10931, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/93ad28c3-6a70-44df-aaaf-a29ffe46ef0b/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-current_value_-_initialfu15-19': 'OK', 'copy-2-of-current_value_-_initialfu15-19': 'OK', 'current_value_-_initialfu15-19': 'OK', 'followUpTotal': '6', 'fu15-19': '4', 'fu20-24': '1', 'fu25-29': '1', 'fuAgeUpdate': '15-19_yrs 20-24_yrs 25-29_yrs', 'initialfu15-19': '0', 'initialfu20-24': '0', 'initialfu25-29': '0', 'initialfu30-34': '0', 'initialfu35-39': '0', 'initialfu40-44': '0', 'initialfu45-49': '0', 'initialfu50': '0', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '0b1fb9a7b9c94be084802c4c7ac90591', '@date_modified': '2025-06-04T08:59:37.567000Z', '@user_id': '434453a99ff5426389cc252b2c346737', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Moy Clinic', 'formType': 'correction', 'mc15-19calculated': '4', 'recordingMonth': 'April', 'savedFacilities': 'Kushinga ClinicApril2025Zebra downs ClinicApril2025Moy ClinicApril2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'highRiskStatus': ''}, 'linkages_due_to_hiv_test_results': {'LinkagesSelection': ''}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'copy-1-of-LinkagesSelection': ''}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Moy ClinicApril2025', 'facilityName': 'Moy Clinic', 'facilityValidation': 'This facility has not data recorded  for the time period April 2025', 'mc15-19calculated': '4', 'mc20-24calculated': '1', 'mc25-29calculated': '1', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kushinga ClinicApril2025Zebra downs ClinicApril2025Moy ClinicApril2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': ''}, 'formSubmissionList': {'formType': 'correction'}, 'grpHTS': {'hiv15-19calculated': '1', 'hiv20-24calculated': '1', 'hiv25-29calculated': '1', 'hiv30-34calculated': '0', 'hiv35-39calculated': '0', 'hiv40-44calculated': '0', 'hiv45-49calculated': '0', 'hiv50calculated': '0', 'hivNegative15-19Qst': 'Recorded Value (15-19 yrs) -> 1', 'hivNegative15-19Validation': 'Input must be equal to or less than the total MCs in the age group 15-19 yrs which equates to 4', 'hivNegative20-24Qst': 'Recorded Value (20-24 yrs) -> 1', 'hivNegative20-24Validation': 'Input must be equal to or less than the total MCs in the age group 20-24 yrs which equates to 1', 'hivNegative25-29Qst': 'Recorded Value (25-29 yrs) -> 1', 'hivNegative25-29Validation': 'Input must be equal to or less than the total MCs in the age group 25-29 yrs which equates to 1', 'hivNegative30-34Qst': 'Recorded Value (30-34 yrs) -> 0', 'hivNegative30-34Validation': 'Input must be equal to or less than the total MCs in the age group 30-34 yrs, which equates to 0', 'hivNegative35-39Qst': 'Recorded Value (35-39 yrs) -> 0', 'hivNegative35-39Validation': 'Input must be equal to or less than the total MCs in  ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 10800, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/757b0a4c-3925-443e-aedf-78b58f52af0a/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-current_value_-_initialfu15-19': 'OK', 'current_value_-_initialfu15-19': 'OK', 'followUpTotal': '7', 'fu15-19': '5', 'fu20-24': '2', 'fuAgeUpdate': '15-19_yrs 20-24_yrs', 'initialfu15-19': '0', 'initialfu20-24': '0', 'initialfu25-29': '0', 'initialfu30-34': '0', 'initialfu35-39': '0', 'initialfu40-44': '0', 'initialfu45-49': '0', 'initialfu50': '0', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '0b1fb9a7b9c94be084802c4c7ac90591', '@date_modified': '2025-06-04T08:58:07.745000Z', '@user_id': '434453a99ff5426389cc252b2c346737', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Zebra downs Clinic', 'formType': 'correction', 'mc15-19calculated': '5', 'recordingMonth': 'April', 'savedFacilities': 'Kushinga ClinicApril2025Zebra downs ClinicApril2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'highRiskStatus': ''}, 'linkages_due_to_hiv_test_results': {'LinkagesSelection': ''}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'copy-1-of-LinkagesSelection': ''}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Zebra downs ClinicApril2025', 'facilityName': 'Zebra downs Clinic', 'facilityValidation': 'This facility has not data recorded  for the time period April 2025', 'mc15-19calculated': '5', 'mc20-24calculated': '2', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kushinga ClinicApril2025Zebra downs ClinicApril2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': ''}, 'formSubmissionList': {'formType': 'correction'}, 'grpHTS': {'hiv15-19calculated': '0', 'hiv20-24calculated': '2', 'hiv25-29calculated': '0', 'hiv30-34calculated': '0', 'hiv35-39calculated': '0', 'hiv40-44calculated': '0', 'hiv45-49calculated': '0', 'hiv50calculated': '0', 'hivNegative15-19Qst': 'Recorded Value (15-19 yrs) -> 0', 'hivNegative15-19Validation': 'Input must be equal to or less than the total MCs in the age group 15-19 yrs which equates to 5', 'hivNegative20-24Qst': 'Recorded Value (20-24 yrs) -> 2', 'hivNegative20-24Validation': 'Input must be equal to or less than the total MCs in the age group 20-24 yrs which equates to 2', 'hivNegative25-29Qst': 'Recorded Value (25-29 yrs) -> 0', 'hivNegative25-29Validation': 'Input must be equal to or less than the total MCs in the age group 25-29 yrs which equates to 0', 'hivNegative30-34Qst': 'Recorded Value (30-34 yrs) -> 0', 'hivNegative30-34Validation': 'Input must be equal to or less than the total MCs in the age group 30-34 yrs, which equates to 0', 'hivNegative35-39Qst': 'Recorded Value (35-39 yrs) -> 0', 'hivNegative35-39Validation': 'Input must be equal to or less than the total MCs in the age group 35-39 yrs, which equates to 0', 'hivNegative40-44Qst': 'Recorded Value (40-4 ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 16156, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/e439f83a-688b-4992-8f17-97622f9e25e0/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-current_value_-_initialfu15-19': 'OK', 'copy-2-of-current_value_-_initialfu15-19': 'OK', 'copy-3-of-current_value_-_initialfu15-19': 'OK', 'copy-4-of-current_value_-_initialfu15-19': 'OK', 'copy-5-of-current_value_-_initialfu15-19': 'OK', 'copy-6-of-current_value_-_initialfu15-19': 'OK', 'copy-7-of-current_value_-_initialfu15-19': 'OK', 'current_value_-_initialfu15-19': 'OK', 'followUpTotal': '15', 'fu15-19': '1', 'fu20-24': '4', 'fu25-29': '8', 'fu30-34': '0', 'fu35-39': '0', 'fu40-44': '2', 'fu45-49': '0', 'fu50': '0', 'fuAgeUpdate': '15-19_yrs 20-24_yrs 25-29_yrs 30-34_yrs_ 35-39_yrs 40-44_yrs 45-49_yrs 50+_yrs', 'initialfu15-19': '0', 'initialfu20-24': '0', 'initialfu25-29': '2', 'initialfu30-34': '0', 'initialfu35-39': '0', 'initialfu40-44': '1', 'initialfu45-49': '0', 'initialfu50': '0', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': '0b1fb9a7b9c94be084802c4c7ac90591', '@date_modified': '2025-06-04T07:50:24.324000Z', '@user_id': '434453a99ff5426389cc252b2c346737', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Kushinga Clinic', 'formType': 'correction', 'mc15-19calculated': '0', 'recordingMonth': 'April', 'savedFacilities': 'Kushinga ClinicApril2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'highRiskStatus': ''}, 'linkages_due_to_hiv_test_results': {'LinkagesSelection': ''}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'copy-1-of-LinkagesSelection': ''}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Kushinga ClinicApril2025', 'facilityName': 'Kushinga Clinic', 'facilityValidation': 'This facility has not data recorded  for the time period April 2025', 'mc15-19calculated': '0', 'mc20-24calculated': '1', 'mc25-29calculated': '3', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '2', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kushinga ClinicApril2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': ''}, 'formSubmissionList': {'formType': 'correction'}, 'grpHTS': {'hiv15-19calculated': '0', 'hiv20-24calculated': '0', 'hiv25-29calculated': '0', 'hiv30-34calculated': '0', 'hiv35-39calculated': '0', 'hiv40-44calculated': '0', 'hiv45-49calculated': '0', 'hiv50calculated': '0', 'hivNegative15-19Qst': 'Recorded Value (15-19 yrs) -> 0', 'hivNegative15-19Validation': 'Input must be equal to or less than the total MCs in the  age group 15-19 yrs which equates to 1', 'hivNegative20-24Qst': 'Recorded Value (20-24 yrs) -> 0', 'hivNegative20-24Validation': 'Input must be equal to or less than the total MCs in the  age group 20-24 yrs which equates to 4', 'hivNegative25-29Qst': 'Recorded Value (25-29 yrs) -> 0', 'hivNegative25-29Validation': 'Input must be equal to or less than the total MCs in the  age group 25-29 yrs which equates to 8', 'hivNegative30-34Qst': 'Rec ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 14238, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/a3a27b67-6fc8-4756-b481-f6651c285630/form.xml'}}, 'build_id': 'daf85d7ca2424f82bacf8e1d8229d053', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '23', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'followUpTotal': '23', 'fu15-19': '12', 'fu20-24': '5', 'fu25-29': '3', 'fu30-34': '2', 'fu35-39': '1', 'initialfu15-19': 'Default Value', 'initialfu20-24': 'Default Value', 'initialfu25-29': 'Default Value', 'initialfu30-34': 'Default Value', 'initialfu35-39': 'Default Value', 'initialfu40-44': 'Default Value', 'initialfu45-49': 'Default Value', 'initialfu50': 'Default Value', 'validateIfAnyFuNotSelected': '0', 'validateNotSelectedfu15-19': '0', 'validateNotSelectedfu20-24': '0', 'validateNotSelectedfu25-29': '0', 'validateNotSelectedfu30-34': '0', 'validateNotSelectedfu35-39': '0', 'validateNotSelectedfu40-44': '0', 'validateNotSelectedfu45-49': '0', 'validateNotSelectedfu50': '0', 'validatefuString': 'Age group(s)               need to be updated for Client Follow-up Section'}}, 'commcare_usercase': {'case': {'@case_id': 'ec7c10778d7d4f0696a7438aca99b0e9', '@date_modified': '2025-06-04T07:36:51.594000Z', '@user_id': 'a74317c95f3c463c96999e7ea4d19e47', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Tengwe Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'May', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025MurambiFebruary2025Chinhere clinicFebruary2025Chivende clinicFebruary2025Beagest ClinicFebruary2025Masikati ClinicFebruary2025Murambi ClinicFebruary2025Beagest ClinicMarch2025Chinhere clinicMarch2025Chivende clinicMarch2025Masikati ClinicMarch2025Murambi ClinicMarch2025Tengwe ClinicMarch2025Beagest ClinicApril2025Chinhere ClinicApril2025Masikati ClinicApril2025Murambi ClinicApril2025Tengwe ClinicApril2025Chivende ClinicApril2025Beagest ClinicMay2025Chinhere ClinicMay2025Chivende ClinicMay2025Masikati ClinicMay2025Murambi ClinicMay2025Tengwe ClinicMay2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'other_referrals_in_detail': {'ReferrelRecordingMonth': 'May', 'ReferrelRecordingSite': 'Tengwe Clinic', 'ReferrelRecordingYear': '2025', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Malaria', 'services_referred': 'Clinic'}}}, 'referralToOtherServices': '1', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Tengwe ClinicMay2025', 'facilityName': 'Tengwe Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period May 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025MurambiFebruary2025Chinhere clinicFebruary2025Chivende clinicFebruary2025Beagest ClinicFebruary2025Masikati ClinicFebruary2025Murambi ClinicFebruary2025Beagest ClinicMarch2025Chinhere clinicMarch2025Chivende clinicMarch2025Masikati ClinicMarch2025Murambi ClinicMarch2025Tengwe ClinicMarch2025Beagest ClinicApril2025Chinhere ClinicApril2025Masikati ClinicApri ...
# ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 2573, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/badf0c77-7722-4c77-a8ba-258507e2c85f/form.xml'}}, 'build_id': 'b7db4c3d8b234ee6983235715c3872ea', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '10', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'commcare_usercase': {'case': {'@case_id': 'ec7c10778d7d4f0696a7438aca99b0e9', '@date_modified': '2025-03-04T13:38:21.667000Z', '@user_id': 'a74317c95f3c463c96999e7ea4d19e47', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Chinhere clinic', 'recordingMonth': 'February', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025MurambiFebruary2025Chinhere clinicFebruary2025'}}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Chinhere clinicFebruary2025', 'facilityName': 'Chinhere clinic', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025MurambiFebruary2025Chinhere clinicFebruary2025'}, 'location_details': {'District': 'HURUNGWE', 'DistrictLabelDisplay': 'District :      HURUNGWE', 'Province': 'MASHONALAND WEST', 'ProvinceLabelDisplay': 'Province :      MASHONALAND WEST', 'SiteLabelDisplay': 'Site  :      TENGWE - 101886 - CLINIC', 'Site_Name': 'TENGWE - 101886 - CLINIC', 'countryID': 'Zimbabwe', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '0', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '0'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.55.0"(467579). App v10. CommCare Version 2.55.0. Build 467579, built on: 2025-01-15', 'app_build_version': 10, 'commcare_version': '2.55.0', 'deviceID': 'commcare_9d7061d4-2fb6-4b3f-838d-3f38eba90be1', 'drift': '0', 'geo_point': None, 'instanceID': 'badf0c77-7722-4c77-a8ba-258507e2c85f', 'timeEnd': '2025-03-04T13:38:21.667000Z', 'timeStart': '2025-03-04T13:38:01.312000Z', 'userID': 'a74317c95f3c463c96999e7ea4d19e47', 'username': 'cmadziwa'}, 'recordingPeriodList': {'recordingMonth': 'February', 'year': '2025'}}, 'id': 'badf0c77-7722-4c77-a8ba-258507e2c85f', 'indexed_on': '2025-03-04T13:38:51.087608Z', 'initial_processing_complete': True, 'is_phone_submission': True, 'metadata': {'appVersion': 'CommCare Android, version "2.55.0"(467579). App v10. CommCare Version 2.55.0. Build 467579, built on: 2025-01-15', 'app_build_version': 10, 'commcare_version': '2.55.0', 'deviceID': 'commcare_9d7061d4-2fb6-4b3f-838d-3f38eba90be1', 'drift': '0', 'geo_point': None, 'instanceID': 'badf0c77-7722-4c77-a8ba-258507e2c85f', 'location': None, 'timeEnd': '2025-03-04T13:38:21.667000Z', 'timeStart': '2025-03-04T13:38:01.312000Z', 'userID': 'a74317c95f3c463c96999e7ea4d19e47', 'username': 'cmadziwa'}, 'problem': None, 'received_on': '2025-03-04T13:38:28.685864Z', 'resource_uri': '', 'server_modified_on': '2025-03-04T13:38:28.753278Z', 'submit_ip': '77.246.52.176', 'type': 'data', 'uiversion': '1', 'version': '10'}
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4704, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/ee397593-fa04-400b-a098-2517992bba5a/form.xml'}}, 'build_id': 'a1dc65ee60cb45daadeb2e9ffc178a86', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '8', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '2', 'fu20-24': '3', 'fu25-29': '0'}}, 'commcare_usercase': {'case': {'@case_id': 'ec7c10778d7d4f0696a7438aca99b0e9', '@date_modified': '2025-03-04T13:19:27.141000Z', '@user_id': 'a74317c95f3c463c96999e7ea4d19e47', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Murambi', 'recordingMonth': 'February', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025MurambiFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'MurambiFebruary2025', 'facilityName': 'Murambi', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025MurambiFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '0', 'hivNegative20-24': '5', 'hivNegative25-29': '1', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'total15-19HIVTested': '0', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '5', 'totalhivNegative': '6'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '11', 'surgical_disposable': {'sgDisposable15-19': '5', 'sgDisposable20-24': '5', 'sgDisposable25-29': '1', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '11', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'HURUNGWE', 'DistrictLabelDisplay': 'District :      HURUNGWE', 'Province': 'MASHONALAND WEST', 'ProvinceLabelDisplay': 'Province :      MASHONALAND WEST', 'SiteLabelDisplay': 'Site  :      TENGWE - 101886 - CLINIC', 'Site_Name': 'TENGWE - 101886 - CLINIC', 'countryID': 'Zimbabwe', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '5', 'mc20-24': '5', 'mc25-29': '1', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '11'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.55.0"(467579). App v8. CommCare Version 2.55.0. Build 467579, built on: 2025-01-15', 'app_build_version': 8, 'commcare_version': '2.55.0', 'deviceID': 'commcare_9d7061d4-2fb6-4b3f-838d-3f38eba90be1', 'drift': '0', 'geo_point': None, 'instanceID': 'ee397593-fa04-400b-a098-2517992bba5a', 'timeEnd': '2025-03-04T13:19:27.141000Z', 'timeStart': '2025-03-04T13:12:14.326000Z', 'userID': 'a74317c95f3c463c96999e7ea4d19e47', 'username': 'cmadziwa'}, 'recordingPeriodList': {'recordingMonth': 'February', 'year': '2025'}, 'totalAES': '0'}, 'id': 'ee397593-fa04-400b-a098-2517992bba5a', 'indexed_on': '2025-03-04T13:19:29.182445Z', 'initial_processing_complete': True, 'is_phone_submi ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4788, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/4271d5bb-5d22-43b3-9699-6175a93880bb/form.xml'}}, 'build_id': 'a1dc65ee60cb45daadeb2e9ffc178a86', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '8', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '8', 'fu20-24': '2', 'fu25-29': '1'}}, 'commcare_usercase': {'case': {'@case_id': 'ec7c10778d7d4f0696a7438aca99b0e9', '@date_modified': '2025-03-04T13:11:56.444000Z', '@user_id': 'a74317c95f3c463c96999e7ea4d19e47', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Masikati', 'recordingMonth': 'February', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'MasikatiFebruary2025', 'facilityName': 'Masikati', 'savedFacilities': 'Tengwe ClinicFebruary2025MasikatiFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '0', 'hivNegative20-24': '0', 'hivNegative25-29': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'hivPositive20-24': '0', 'hivPositive25-29': '0', 'total15-19HIVTested': '0', 'total20-24HIVTested': '0', 'total25-29HIVTested': '0', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '11', 'totalhivNegative': '0'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '11', 'surgical_disposable': {'sgDisposable15-19': '8', 'sgDisposable20-24': '2', 'sgDisposable25-29': '1', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '11', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'HURUNGWE', 'DistrictLabelDisplay': 'District :      HURUNGWE', 'Province': 'MASHONALAND WEST', 'ProvinceLabelDisplay': 'Province :      MASHONALAND WEST', 'SiteLabelDisplay': 'Site  :      TENGWE - 101886 - CLINIC', 'Site_Name': 'TENGWE - 101886 - CLINIC', 'countryID': 'Zimbabwe', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '8', 'mc20-24': '2', 'mc25-29': '1', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '11'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.55.0"(467579). App v8. CommCare Version 2.55.0. Build 467579, built on: 2025-01-15', 'app_build_version': 8, 'commcare_version': '2.55.0', 'deviceID': 'commcare_9d7061d4-2fb6-4b3f-838d-3f38eba90be1', 'drift': '0', 'geo_point': None, 'instanceID': '4271d5bb-5d22-43b3-9699-6175a93880bb', 'timeEnd': '2025-03-04T13:11:56.444000Z', 'timeStart': '2025-03-04T13:05:22.221000Z', 'userID': 'a74317c95f3c463c96999e7ea4d19e47', 'username': 'cmadziwa'}, 'recordingPeriodList': {'recordingMonth': 'February', 'year': '2025'}, 'totalAES': '0'}, 'id': '4271d5bb-5d22-43b3-9699-6175a93880bb', 'indexed_on': '2025-03-04T13:12:01.558358Z', 'initial_processing_complete': Tru ...
# {'app_id': '4e6668dfd6adb19fe71beb316114b48f', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 4452, 'url': 'https://zdip.zimttech.org/a/zdip/api/form_attachment/v1/b8bc25a7-af9a-4262-b100-603790de6741/form.xml'}}, 'build_id': 'a1dc65ee60cb45daadeb2e9ffc178a86', 'domain': 'zdip', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '8', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '11'}}, 'commcare_usercase': {'case': {'@case_id': 'ec7c10778d7d4f0696a7438aca99b0e9', '@date_modified': '2025-03-04T11:19:34.768000Z', '@user_id': 'a74317c95f3c463c96999e7ea4d19e47', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Tengwe Clinic', 'recordingMonth': 'February', 'savedFacilities': 'Tengwe ClinicFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Tengwe ClinicFebruary2025', 'facilityName': 'Tengwe Clinic', 'savedFacilities': 'Tengwe ClinicFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'total15-19HIVTested': '0', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '15', 'totalhivNegative': '0'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '15', 'surgical_disposable': {'sgDisposable15-19': '15', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangringMCs': '0', 'totalSurgicalDisposableMCs': '15', 'totalSurgicalReusableMCs': '0'}, 'location_details': {'District': 'HURUNGWE', 'DistrictLabelDisplay': 'District :      HURUNGWE', 'Province': 'MASHONALAND WEST', 'ProvinceLabelDisplay': 'Province :      MASHONALAND WEST', 'SiteLabelDisplay': 'Site  :      TENGWE - 101886 - CLINIC', 'Site_Name': 'TENGWE - 101886 - CLINIC', 'countryID': 'Zimbabwe', 'districtName': 'OK', 'provinceName': 'OK', 'siteName': 'OK'}, 'mc_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'mc15-19': '15', 'mc20-24': '0', 'mc25-29': '0', 'mc30-34': '0', 'mc35-39': '0', 'mc40-44': '0', 'mc45-49': '0', 'mc50': '0', 'totalMCs': '15'}, 'meta': {'@xmlns': 'http://openrosa.org/jr/xforms', 'appVersion': 'CommCare Android, version "2.55.0"(467579). App v8. CommCare Version 2.55.0. Build 467579, built on: 2025-01-15', 'app_build_version': 8, 'commcare_version': '2.55.0', 'deviceID': 'commcare_9d7061d4-2fb6-4b3f-838d-3f38eba90be1', 'drift': '0', 'geo_point': None, 'instanceID': 'b8bc25a7-af9a-4262-b100-603790de6741', 'timeEnd': '2025-03-04T11:19:34.768000Z', 'timeStart': '2025-03-04T10:56:40.042000Z', 'userID': 'a74317c95f3c463c96999e7ea4d19e47', 'username': 'cmadziwa'}, 'recordingPeriodList': {'recordingMonth': 'February', 'year': '2025'}, 'totalAES': '0'}, 'id': 'b8bc25a7-af9a-4262-b100-603790de6741', 'indexed_on': '2025-03-04T11:19:42.936242Z', 'initial_processing_complete': True, 'is_phone_submission': True, 'metadata': {'appVersion': 'CommCare Android, version "2.55.0"(467579). App v8. CommCare Version 2.55.0. Build 467579, built on: 2025-01-15', 'app_build_version': 8, 'commcare_ ...

# %%
# New columns that should NOT be deleted
columns_to_retain = [
    'AERecordingMonth', 'AERecordingSite', 'AERecordingYear', 'aeComments', 'ae_classification', 
    'ae_type_code', 'checkMonthValidation', 'checkYearValidation', 'circumcising_cadre', 'client_age', 
    'date_ae_identified', 'mcMethod', 'vmmc_number', 'followUpTotal', 'recordingMonth', 
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'reason_for_referral', 'services_referred', 'facilityName', 
    'District', 'recordingMonth', 'year', 'totalAES','adverse_events', 'Site_Name', 'totalReferralstoOtherServices',
    'formType','received_on','ageGroupsChange', 'fuAgeUpdate','selectedHTSAgeGroups'
]

# Columns that must be numeric (including the new ones)
numeric_columns = [
    'client_age', 'fu15-19', 'fu20-24', 'fu25-29', 'fu30-34', 'fu40-44', 'fu50',
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'referralToOtherServices',
    'total_mcs_referred_for_srh_services', 'total_mcs_referred_for_sti_services', 'checkifFacilityHasBeenSaved',
    'hivNegativeNC15-19', 'hivNegativeNC20-24', 'hivNegativeNC25-29', 'hivNegativeNC30-34', 'hivNegativeNC35-39', 
    'hivNegativeNC40-44', 'hivNegativeNC45-49', 'hivNegativeNC50', 'total_surgicalDisposable', 'hivPositive30-34',
    'hivPositiveNC15-19', 'hivPositiveNC20-24', 'hivPositiveNC25-29', 'hivPositiveNC35-39', 'hivPositiveNC40-44',
    'hivPositiveNC45-49', 'hivPositiveNC50', 'total15-19NCHIVTested', 'total20-24NCHIVTested', 'total25-29NCHIVTested',
    'total30-34NCHIVTested', 'total35-39NCHIVTested', 'total40-44NCHIVTested', 'total45-49NCHIVTested', 
    'total50NCHIVTested', 'total_surgicalReusable', 'totalHIVPositiveNC', 'totalhivNegativeNC', 
    'uncircumcisedClientsForHTS', 'hivNegative15-19', 'hivNegative20-24', 'hivNegative25-29', 'hivNegative30-34', 
    'hivNegative40-44', 'hivNegative50', 'total_surgicalDisposable', 'hivPositive15-19', 'hivPositive20-24','hivPositive25-29',
    'hivPositive30-34','hivPositive35-39','hivPositive40-44','hivPositive45-49','hivPositive50',
    'total15-19HIVTested', 'total20-24HIVTested', 'total25-29HIVTested', 'total30-34HIVTested', 'total35-39HIVTested',
    'total40-44HIVTested', 'total45-49HIVTested', 'total50HIVTested', 'total_surgicalReusable', 'totalHIVPositive',
    'totalHIVUntested', 'totalhivNegative', 'TotalMCsBYMethod', 'sgDisposable15-19', 'sgDisposable20-24', 
    'sgDisposable25-29', 'sgDisposable30-34', 'sgDisposable40-44', 'sgDisposable50', 'total_surgicalDisposable',
    'sgReusable15-19', 'sgReusable20-24', 'sgReusable25-29', 'sgReusable30-34', 'sgReusable40-44', 'sgReusable50',
    'total_surgicalReusable', 'total50ByMethod', 'totalShangringMCs', 'totalSurgicalDisposableMCs', 
    'totalSurgicalReusableMCs', 'mc15-19', 'mc20-24', 'mc25-29', 'mc30-34', 'mc35-39', 'mc40-44', 'mc45-49', 
    'mc50', 'totalMCs', 'fu35-39', 'other_referrals_in_detail', 'total_mcs_referred_to_other_services', 
    'hivNegative35-39', 'sgDisposable35-39', 'sgReusable35-39', 'shangring15-19', 'shangring20-24','shangring25-29', 'shangring30-34',
    'shangring35-39', 'shangring40-44','shangring45-49','shangring50', 'fu45-49', 
    'hivNegative45-49', 'sgDisposable45-49', 'sgReusable45-49','AERecordingYear','high_risk_referrals_to_care'
]

# general_df['AERecordingYear'] = pd.to_numeric(general_df['AERecordingYear'])
# Combine the two lists (retain columns that are in either columns_to_retain or numeric_columns)
columns_to_keep = list(set(columns_to_retain + numeric_columns))

# Identify missing columns
missing_columns = [col for col in columns_to_keep if col not in general_df.columns]

# %%
# Add missing columns to the DataFrame and assign zero
for col in missing_columns:
    general_df[col] = 0

# Drop the columns that are not in the columns_to_keep list
# Sort the columns alphabetically in both DataFrames

# For the 'general_df', sort the columns alphabetically
general_df_sorted = general_df[sorted(general_df[columns_to_keep])]

general_df_sorted ['Site_Name'] = general_df_sorted ['Site_Name'].replace(
    'MARONDERA PROVINCIAL HOSPITAL', 
    'MARONDERA  - 100903 - PROVINCIAL HOSPITAL'
)

# For the AE-specific columns, we can do the same
ae_columns = [
    'aeComments', 'ae_type_code', 'date_ae_identified', 'AERecordingYear', 'AERecordingSite', 
    'client_age', 'circumcising_cadre', 'ae_classification', 'AERecordingMonth', 'mcMethod','vmmc_number'
]


referrals_columns =['ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'services_referred','reason_for_referral']



other_referrals = []
ae_data_df_sorted = general_df[ae_columns][sorted(ae_columns)]
ae_data_df_sorted = ae_data_df_sorted[ae_data_df_sorted['AERecordingMonth'].notna()]

referralsDF_sorted = general_df[referrals_columns][sorted(referrals_columns)]
referralsDF_sorted = referralsDF_sorted[referralsDF_sorted['ReferrelRecordingMonth'].notna()]
# Out:
# C:\Users\AshleyMutenha\AppData\Local\Temp\ipykernel_25396\1591413406.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   general_df_sorted ['Site_Name'] = general_df_sorted ['Site_Name'].replace(

# %%
# Function to flatten the nested referral data
def flatten_referral_data(referral_list):
    flattened_referrals = []
    
    # Loop through each referral in the list
    for referral in referral_list:
        flattened_referral = {}
        
        # Flatten the first level of referral data
        for key, value in referral.items():
            if isinstance(value, dict):
                # If the value is a nested dictionary, flatten it
                for nested_key, nested_value in value.items():
                    flattened_referral[f"{key}_{nested_key}"] = nested_value
            else:
                flattened_referral[key] = value
        
        flattened_referrals.append(flattened_referral)
    
    return flattened_referrals



# Function to unpack nested 'question1_question5' field
def unpack_detailedField(df, column):
    if column  in df.columns:
        # Unpack the dictionary inside 'question1_question5' into separate columns
        question_fields = df[column].apply(pd.Series)
        
        # Merge the unpacked fields back into the main DataFrame
        df = pd.concat([df, question_fields], axis=1)
        
        # Drop the original 'question1_question5' column if no longer needed
        df.drop(column, axis=1, inplace=True)
    
    return df

# %%
# Extract the referrals from 'other_referrals_in_detail' column referrals_data = []
singleReferrals =[]
# Loop through each row and check if 'other_referrals_in_detail' is a valid list
for idx, row in general_df.iterrows():
    referral_list = row['other_referrals_in_detail']
    
    # Check if the value is a list and not NaN
    if isinstance(referral_list, list):
        # Flatten the referral data
        flattened_referrals = flatten_referral_data(referral_list)
        for ref in flattened_referrals:
            ref['District'] = row['District']  # Add the District to each referral record
            referrals_data.append(ref)
    else:
        # Handle cases where referral_list is not valid
        if not pd.isna(row['ReferrelRecordingMonth']):  # Check if 'ReferrelRecordingMonth' is not NaN
            _object = {
                'ReferrelRecordingMonth': row['ReferrelRecordingMonth'], 
                'ReferrelRecordingSite': row['ReferrelRecordingSite'], 
                'ReferrelRecordingYear': row['ReferrelRecordingYear'],
                'District': row['District'],
                'reason_for_referral':row['reason_for_referral'],
                'services_referred':row['services_referred']
            }
            singleReferrals.append(_object)

# %%
aes_data =[]
singleAEs = []
for idx, row in general_df.iterrows():
    ae_list = row['adverse_events']
    
    # Check if the value is a list and not NaN
    if isinstance(ae_list, list) and not pd.isna(ae_list).any():  # Use .any() to check the entire list
        flattened_aes = flatten_referral_data(ae_list)
        for ref in flattened_aes:
            ref['District'] = row['District']  # Add the District to each referral record
            aes_data.append(ref)

    else:
        if not pd.isna(row['AERecordingMonth']):
            _object = {
                'AERecordingMonth':row['AERecordingMonth'],
                'AERecordingSite':row['AERecordingSite'],
                'AERecordingYear':row['AERecordingYear'],
                'District':row['District'],
                'aeComments':row['aeComments'],
                'ae_classification':row['ae_classification'],
                'ae_type_code':row['ae_type_code'],
                'circumcising_cadre':row['circumcising_cadre'],
                'client_age':row['client_age'],
                'date_ae_identified':row['date_ae_identified'],
                'mcMethod':row['mcMethod'],
                'vmmc_number':row['vmmc_number']
            }
            singleAEs.append(_object)

# %%
# Convert the flattened referrals data into a DataFrame

referrals_df = pd.DataFrame(referrals_data)

# convert the flattened aes data into a df

ae_df = pd.DataFrame(aes_data)

# Unpack the 'question1_question5' field
referrals_df = unpack_detailedField(referrals_df,'question1_question5')

ae_df = unpack_detailedField(ae_df,'question3_question1')

ae_df = unpack_detailedField(ae_df,'question1')

ae_df = ae_df.rename(columns={
    'question3_AERecordingMonth': 'AERecordingMonth',
    'question3_AERecordingSite': 'AERecordingSite',
    'question3_AERecordingYear': 'AERecordingYear'
})

print(ae_df)

if len(singleReferrals)>0:
    tempRefDF = pd.DataFrame(singleReferrals)
    referrals_df = pd.concat([referrals_df,tempRefDF])

if len(singleAEs)>0:
    tempRefDF = pd.DataFrame(singleAEs)
    ae_df = pd.concat([ae_df,tempRefDF])


if not referrals_df.empty:
    try:
        referrals_df = referrals_df.drop(columns = ['question1_cancelthisReferralReport',0]).drop_duplicates()
    except:
        pass

if not ae_df.empty:
    try:
        ae_df = ae_df.drop(columns = ['checkMonthValidation','checkYearValidation']).drop_duplicates()
    except:
        pass

general_df_sorted = general_df_sorted.drop(columns =['adverse_events','other_referrals_in_detail']).drop_duplicates()


zazicSites_unique = zazicSites.drop_duplicates(subset='facilityName')


general_df_sorted = general_df_sorted.loc[:, ~general_df_sorted.columns.duplicated(keep='last')]

# Merge to bring in facilityType from zazicSites_unique
general_df_sorted = general_df_sorted.merge(zazicSites_unique[['facilityName', 'facilityType']], 
                                            on='facilityName', 
                                            how='left')

general_df_sorted = general_df_sorted.fillna(0)
# df_filtered= general_df_sorted[~(
#     (general_df_sorted.duplicated(subset=['facilityName', 'recordingMonth', 'year'], keep=False)) &
#     (general_df_sorted['formType'] == 'submission')
# )]

# # Step 2: If multiple 'correction' rows exist, keep the one with the latest 'received_on'
# general_df_sorted = df_filtered.loc[
#     df_filtered.groupby(['facilityName', 'recordingMonth', 'year'])['received_on'].idxmax()
# ]



import pandas as pd

# Step 1: Extract correction rows from general_df_sorted
correction_df = general_df_sorted[general_df_sorted['formType'] == 'correction']

# Step 2: Keep only the latest correction per facility/month/year
latest_corrections = correction_df.sort_values('ageGroupsChange', ascending=False) \
    .drop_duplicates(subset=['facilityName', 'recordingMonth', 'year'])

# Step 3: Create a working copy excluding correction rows
general_df_sorted_updated = general_df_sorted[general_df_sorted['formType'] != 'correction'].copy()

# Step 4: Apply corrections
for _, row in latest_corrections.iterrows():
    facility = row['facilityName']
    month = row['recordingMonth']
    year = row['year']

    # Locate matching rows in the dataset
    mask = (
        (general_df_sorted_updated['facilityName'] == facility) &
        (general_df_sorted_updated['recordingMonth'] == month) &
        (general_df_sorted_updated['year'] == year)
    )

    ### 1. Apply updates from fuAgeUpdate → fuXX-YY columns
    fu_age_str = row.get('fuAgeUpdate')
    fu_age_groups = fu_age_str.split() if isinstance(fu_age_str, str) else []
    for age_group in fu_age_groups:
        col = f"fu{age_group.replace('_yrs', '')}"
        if col in general_df_sorted_updated.columns:
            value = row.get(col)
            if pd.notna(value):
                general_df_sorted_updated.loc[mask, col] = value

    ### 2. Apply updates from ageGroupsChange → mcXX-YY columns
    mc_age_str = row.get('ageGroupsChange')
    mc_age_groups = mc_age_str.split() if isinstance(mc_age_str, str) else []
    for age_group in mc_age_groups:
        suffix = age_group.replace('_yrs', '')
        for prefix in ['mc', 'sgDisposable', 'sgReusable','shangring']:
            col = f"{prefix}{suffix}"           
            if col in general_df_sorted_updated.columns:
                value = row.get(col)
                if pd.notna(value):
                    general_df_sorted_updated.loc[mask, col] = value

    ### 3. Apply updates from selectedHTSAgeGroups → hivPositiveXX-YY and hivNegativeXX-YY
    hts_age_str = row.get('selectedHTSAgeGroups')
    hts_age_groups = hts_age_str.split() if isinstance(hts_age_str, str) else []
    for age_group in hts_age_groups:
        suffix = age_group.replace('_yrs', '')
        for prefix in ['hivPositive', 'hivNegative']:
            col = f"{prefix}{suffix}"
            if col in general_df_sorted_updated.columns:
                value = row.get(col)
                if pd.notna(value):
                    general_df_sorted_updated.loc[mask, col] = value

# Optional: Export the result
general_df_sorted_updated.to_excel("final_corrected_data.xlsx", index=False)



general_df_sorted = general_df_sorted_updated


# import pandas as pd

# # Step 1: Identify the latest 'correction' row for each facilityName, recordingMonth, and year
# latest_correction_idx = general_df_sorted[general_df_sorted['formType'] == 'correction'].groupby(
#     ['facilityName', 'recordingMonth', 'year']
# )['received_on'].idxmax()

# # Step 2: Store the latest correction rows
# latest_corrections = general_df_sorted.loc[latest_correction_idx]

# # Step 3: Define age groups and columns to update
# age_groups = ['15-19_yrs', '20-24_yrs', '25-29_yrs', '30-34_yrs', '35-39_yrs', '40-44_yrs', '45-49_yrs', '50+_yrs']
# columns_to_update = ['mc', 'sgDisposable', 'sgReusable', 'shangring', 'fu', 'hivPositive', 'hivNegative']

# # Copy original DataFrame to apply updates
# final_df = general_df_sorted.copy()

# # Optional: Create a working lookup table
# lookupTable = general_df_sorted[general_df_sorted['formType'] == 'submission'].copy()

# # Step 4: Apply corrections
# for idx, submission_row in general_df_sorted[general_df_sorted['formType'] == 'submission'].iterrows():
#     facility = submission_row['facilityName']
#     month = submission_row['recordingMonth']
#     year = submission_row['year']

#     # Match corresponding correction
#     correction_row = latest_corrections[
#         (latest_corrections['facilityName'] == facility) &
#         (latest_corrections['recordingMonth'] == month) &
#         (latest_corrections['year'] == year)
#     ]

#     if not correction_row.empty:
#         correction_row = correction_row.iloc[0]
#         age_groups_change = correction_row['ageGroupsChange']

#         print(f"\nApplying correction for {facility}, {month}-{year}")
#         print(f"Age groups to update: {age_groups_change}")

#         # Find the index of the row to update in the lookup table
#         target_idx = lookupTable[
#             (lookupTable['facilityName'] == facility) &
#             (lookupTable['recordingMonth'] == month) &
#             (lookupTable['year'] == year)
#         ].index

#         for age_group in age_groups:
#             if age_group in age_groups_change:
#                 for col_prefix in columns_to_update:
#                     col_name = f"{col_prefix}{age_group.split('_')[0]}"  # e.g., fu15-19

#                     if col_name in correction_row and col_name in lookupTable.columns:
#                         new_value = correction_row[col_name]

#                         if not pd.isna(new_value) and len(target_idx) > 0:
#                             lookupTable.loc[target_idx, col_name] = new_value
#                             print(f"Updated {col_name} to {new_value}")

# # Step 5: Remove old rows and replace with updated ones
# updated_ids = lookupTable.index
# final_df = final_df.drop(index=updated_ids, errors='ignore')
# final_df = pd.concat([final_df, lookupTable], ignore_index=True)

# # Optional: Drop correction rows (to keep only corrected submissions)
# final_df = final_df[final_df['formType'] != 'correction']

# # Final dataset is in final_df


# # Step 1: Iterate through submission rows
# for idx, row in general_df_sorted[general_df_sorted['formType'] == 'submission'].iterrows():
#     facility, month, year = row['facilityName'], row['recordingMonth'], row['year']

#     # Step 2: Find corresponding correction row
#     correction_row = latest_corrections[
#         (latest_corrections['facilityName'] == facility) &
#         (latest_corrections['recordingMonth'] == month) &
#         (latest_corrections['year'] == year)
#     ]

#     if not correction_row.empty:  # If a correction row exists
#         # Step 3: Check if a row exists in lookupTable

#         lookup_match = lookupTable[
#             (lookupTable['facilityName'] == facility) &
#             (lookupTable['recordingMonth'] == month) &
#             (lookupTable['year'] == year)
#         ]

#         if not lookup_match.empty:  
#             # Apply corrections to lookupTable row instead of submission row
#             target_idx = lookup_match.index[0]  # Get index of matched row
#             target_df = lookupTable  # Apply updates to lookupTable
            
#             # Step 4: Update the matched row in lookupTable
#             age_groups_change = correction_row['ageGroupsChange'].values[0]
#             for age_group in age_groups:
#                 if age_group in age_groups_change:
#                     for column_prefix in columns_to_update:
#                         column_name = f'{column_prefix}{age_group.split("_")[0]}'
#                         target_df.at[target_idx, column_name] = correction_row[column_name].values[0]

#             # Remove the submission row from final dataframe
#             final_df.drop(index=idx, inplace=True)

#             # Add the updated row from lookupTable to final dataframe
#             final_df = pd.concat([final_df, lookupTable.loc[[target_idx]]], ignore_index=True)

#         else:
#             # No match in lookupTable, apply changes to the original submission row
#             age_groups_change = correction_row['ageGroupsChange'].values[0]
#             for age_group in age_groups:
#                 if age_group in age_groups_change:
#                     for column_prefix in columns_to_update:
#                         column_name = f'{column_prefix}{age_group.split("_")[0]}'
#                         final_df.at[idx, column_name] = correction_row[column_name].values[0]

# Step 5: Remove correction rows from final dataframe
# final_df = final_df[~final_df.index.isin(latest_corrections.index)]
final_df = general_df_sorted.copy()
final_df = final_df[final_df['formType']!='correction']

# Reset index to maintain consistency
final_df.reset_index(drop=True, inplace=True)

final_df = final_df.replace('Madam ombre Clinic','Madamombe Clinic')

final_df = final_df[~final_df["facilityName"].isin(["Masikati", "Murambi"])]

# Now save the DataFrame to Excel
with pd.ExcelWriter('data.xlsx', engine='xlsxwriter') as writer:
    # Save the sorted general data to the first sheet
    final_df.drop_duplicates().to_excel(writer, sheet_name='Statistics', index=False)
    
    # Save the sorted AE data to a new sheet
    ae_df.drop_duplicates().to_excel(writer, sheet_name='AEs', index=False)
    
    # Save the flattened referrals data to a new sheet
    referrals_df.drop_duplicates().to_excel(writer, sheet_name='Referrals', index=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# C:\Users\AshleyMutenha\AppData\Local\Temp\ipykernel_25396\95536984.py:264: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   final_df = final_df.replace('Madam ombre Clinic','Madamombe Clinic')

# %%
final_df
# Out:
#     AERecordingMonth AERecordingSite AERecordingYear   District  \
# 0                  0               0               0  MARONDERA
# 1                  0               0               0  MARONDERA
# 2                  0               0               0  MARONDERA
# 3                  0               0               0  MARONDERA
# 4                  0               0               0  MARONDERA
# ..               ...             ...             ...        ...
# 103                0               0               0   HURUNGWE
# 104                0               0               0   HURUNGWE
# 105                0               0               0   HURUNGWE
# 106                0               0               0   HURUNGWE
# 109                0               0               0   HURUNGWE
#
#     ReferrelRecordingMonth ReferrelRecordingSite ReferrelRecordingYear  \
# 0                        0                     0                     0
# 1                        0                     0                     0
# 2                        0                     0                     0
# 3                        0                     0                     0
# 4                        0                     0                     0
# ..                     ...                   ...                   ...
# 103                      0                     0                     0
# 104                      0                     0                     0
# 105                      0                     0                     0
# 106                      0                     0                     0
# 109                      0                     0                     0
#
#                               Site_Name TotalMCsBYMethod aeComments  ...  \
# 0         MAHUSEKWA - 100829 - HOSPITAL               33          0  ...
# 1         MAHUSEKWA - 100829 - HOSPITAL               41          0  ...
# 2         MAHUSEKWA - 100829 - HOSPITAL                0          0  ...
# 3         MAHUSEKWA - 100829 - HOSPITAL               13          0  ...
# 4         MAHUSEKWA - 100829 - HOSPITAL               12          0  ...
# ..                                  ...              ...        ...  ...
# 103  KAROI - 100715 - DISTRICT HOSPITAL               33          0  ...
# 104  KAROI - 100715 - DISTRICT HOSPITAL               10          0  ...
# 105  KAROI - 100715 - DISTRICT HOSPITAL               44          0  ...
# 106            TENGWE - 101886 - CLINIC                0          0  ...
# 109            TENGWE - 101886 - CLINIC               15          0  ...
#
#     total_mcs_referred_for_sti_services total_mcs_referred_to_other_services  \
# 0                                     0                                    0
# 1                                     0                                    0
# 2                                     0                                    0
# 3                                     1                                    0
# 4                                     0                                    0
# ..                                  ...                                  ...
# 103                                   0                                    0
# 104                                   0                                    0
# 105                                   0                                    0
# 106                                   0                                    0
# 109                                   0                                    0
#
#      total_surgicalDisposable total_surgicalReusable totalhivNegative  \
# 0                           0                      0               15
# 1                           0                      0               20
# 2                           0                      0                0
# 3                           0                      0               13
# 4                           0                      0                5
# ..                        ...                    ...              ...
# 103                         0                      0               11
# 104                         0                      0                9
# 105                         0                      0               37
# 106                         0                      0                0
# 109                         0                      0                0
#
#     totalhivNegativeNC uncircumcisedClientsForHTS vmmc_number  year  \
# 0                    0                          0           0  2025
# 1                    0                          0           0  2025
# 2                    0                          0           0  2025
# 3                    0                          0           0  2025
# 4                    0                          0           0  2025
# ..                 ...                        ...         ...   ...
# 103                  0                          0           0  2025
# 104                  0                          0           0  2025
# 105                  0                          0           0  2025
# 106                  0                          0           0  2025
# 109                  0                          0           0  2025
#
#     facilityType
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 103       Static
# 104     Outreach
# 105     Outreach
# 106     Outreach
# 109       Static
#
# [108 rows x 141 columns]
