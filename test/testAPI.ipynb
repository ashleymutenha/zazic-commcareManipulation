# %%
import pandas as pd
from commcare_export.checkpoint import CheckpointManagerWithDetails
from commcare_export.commcare_hq_client import CommCareHqClient, AUTH_MODE_APIKEY
from commcare_export.commcare_minilinq import get_paginator, PaginationMode
from datetime import datetime
import re

# CommCare credentials
username = 'amutenha@zimttech.org'  # Replace with your actual CommCare username
domain = 'zdip-qa'  # Your CommCare project domain
hq_host = 'https://zdip.zimttech.org'  # Your CommCare HQ custom host
API_KEY = '92fbb3f98433a6929a33015273ebe7b38b6dac39'  # Replace with the API key generated in CommCare


zazicSites= pd.read_excel('zazicFacilities.xlsx')

data = pd.ExcelFile('ZDIPlookup.xlsx')

lookupTable = pd.read_excel(data,'previousVMMCSubmissions')

lookupTable.columns = [col.replace('field: ', '') if col.startswith('field: ') else col for col in lookupTable.columns]

# Initialize API client
api_client = CommCareHqClient(hq_host, domain, username, API_KEY, AUTH_MODE_APIKEY)

# Create a paginator for the 'form' resource (fetching data from a form)
form_paginator = get_paginator(resource='form', pagination_mode=PaginationMode.date_modified, page_size=100)
form_paginator.init()

# Initialize checkpoint manager (None used here for simplicity)
checkpoint_manager = CheckpointManagerWithDetails(None, None, PaginationMode.date_modified)

# Date range for filtering
start_date = datetime(2025, 3,19)  # 2 December 2024
end_date = datetime(2025, 3, 31)  # 6 December 2024

# Specify the app_id to filter forms
desired_app_id ='829256a8e54a410eb4c2f3eeca4e65e5'  


referrals_data = []
AEs_data = []
general_data = []

# Fetch forms iteratively
# Fetch forms using manual pagination
all_forms = []
offset = 0

params = {
    'limit': 500,  # Adjust limit as needed
    'offset': offset,
    'app_id': desired_app_id,  # Filter by specific app_id
    'received_on_start': start_date.strftime('%Y-%m-%dT%H:%M:%S'),
    'received_on_end': end_date.strftime('%Y-%m-%dT%H:%M:%S')
}

while True:
    forms = api_client.iterate(
        'form',
        form_paginator,
        checkpoint_manager=checkpoint_manager,
        params=params  # Apply filters
    )
    
    batch = list(forms)  
    if not batch:  
        break  

    all_forms.extend(batch)
    offset += 200  # Adjust pagination step

    if len(all_forms) >= 600:  # Stop after enough records
        break

# %%
# Print a few fetched forms to verify filtering
for form in all_forms[:5]:  
    print(f"Received On: {form.get('received_on')}, App ID: {form.get('app_id')}")

filteredResults =[]
for i in all_forms:
    if i["app_id"] ==desired_app_id:
        filteredResults.append(i)

print(filteredResults)
# Filter and categorize forms by app_id and date
for form in forms:
    if form.get('app_id') == desired_app_id:
        print(form)
        form_received_date = datetime.strptime(form['received_on'], "%Y-%m-%dT%H:%M:%S.%fZ")
        if start_date <= form_received_date <= end_date:
            general_data.append(form)
# Convert each list to a pandas DataFrame
general_df = pd.json_normalize(general_data)
general_df.to_excel('test.xlsx')

general_df.columns = [re.split(r'[./]', col)[-1] for col in general_df.columns]
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 15143, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/27b8daca-9f1b-463a-a9e0-ce2d10603d5a/form.xml'}}, 'build_id': '80d4d65d4e764bf888ed409cc027567b', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '639', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '21', 'fu20-24': '12'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-28T08:35:41.637000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Gaha Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'January', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025Mnene HospitalFebruary2025Mnene HospitalFebruary2025Gaha ClinicJanuary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '1'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '5', 'total_hiv_positive_linked_to_care': '2'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '1'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Gaha ClinicJanuary2025', 'facilityName': 'Gaha Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period January 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025Mnene HospitalFebruary2025Mnene HospitalFebruary2025Gaha ClinicJanuary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hiv15-19NCQs': '', 'hiv20-24NCQs': '', 'hiv25-29NCQs': '', 'hiv30-34NCQs': '', 'hiv35-39NCQs': '', 'hiv40-44NCQs': '', 'hiv45-49NCQs': '', 'hiv50NCQs': '', 'hivNegativeNC15-19': '0', 'hivNegativeNC15-19calculation': 'Default Value', 'hivNegativeNC20-24': '0', 'hivNegativeNC20-24calculation': 'Default Value', 'hivNegativeNC25-29': '0', 'hivNegativeNC25-29calculation': 'Default Value', 'hivNegativeNC30-34': ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 17051, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/616cf7aa-55c1-425e-b582-8dda2e3d9256/form.xml'}}, 'build_id': '408966dc698746d092386f0b72c28c04', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '604', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '5', 'fu20-24': '4'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-26T10:37:19.725000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Mnene Hospital', 'formType': 'correction', 'mc15-19calculated': '6', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025Mnene HospitalFebruary2025Mnene HospitalFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'highRiskStatus': 'update', 'high_risk_referrals_to_care': '1'}, 'linkages_due_to_hiv_test_results': {'LinkagesSelection': 'linkages_to_prep', 'total_hiv_negative_linked_to_prep': '1'}, 'other_referrals_in_detail': [{'ReferrelRecordingMonth': 'February', 'ReferrelRecordingSite': 'Mnene Hospital', 'ReferrelRecordingYear': 'correction', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client had elavated BP', 'services_referred': 'Hypertensive'}}}, {'ReferrelRecordingMonth': 'February', 'ReferrelRecordingSite': 'Mnene Hospital', 'ReferrelRecordingYear': 'correction', 'question1': {'cancelthisReferralReport': '', 'question5': {'reason_for_referral': 'Client was showing signs of failure in some senses', 'services_referred': 'Neurology'}}}], 'referralToOtherServices': '2', 'referrals_to_sti_and_srh_services': {'copy-1-of-LinkagesSelection': 'referral_sti referral_srh', 'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '1'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Mnene HospitalFebruary2025', 'facilityName': 'Mnene Hospital', 'facilityValidation': 'This facility has not data recorded  for the time period February 2025', 'mc15-19calculated': '6', 'mc20-24calculated': '7', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandaw ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 14254, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/085a9345-949f-4a1d-9852-94cb033b229e/form.xml'}}, 'build_id': '4c070b888eab4561ba52ce8e5619e24a', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '593', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '5', 'fu20-24': '4'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-26T07:29:17.382000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Mnene Hospital', 'formType': 'correction', 'mc15-19calculated': '6', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025Mnene HospitalFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'highRiskStatus': ''}, 'linkages_due_to_hiv_test_results': {'LinkagesSelection': ''}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'copy-1-of-LinkagesSelection': ''}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Mnene HospitalFebruary2025', 'facilityName': 'Mnene Hospital', 'facilityValidation': 'This facility has not data recorded  for the time period February 2025', 'mc15-19calculated': '6', 'mc20-24calculated': '7', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025Mnene HospitalFebruary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'copy-1-of-hiv15-19ncqs': 'OK', 'copy-2-of-hiv15-19ncqs': 'OK', 'copy-3-of-hiv15-19ncqs': 'OK', 'copy-4-of-hiv15-19ncqs': 'OK', 'copy-5-of-hiv15-19ncqs': 'OK', 'copy-6-of-hiv15-19ncqs': 'OK', 'copy-7-of-hiv15-19ncqs': 'OK', 'hiv15-19NCQs': 'Recorded Value (15-19 yrs) -> 2', 'hiv15-19ncqs': 'OK', 'hiv20-24NCQs': 'Recorded Value (20-24 yrs) -> 1', 'hiv25-29NCQs': 'Recorded Value (25-29 yrs) -> 0', 'hiv30-34NCQs': 'Recorded Value (30-34 yrs) -> 0', 'hiv35-39NCQs': 'Recorded Value (35-39 yrs) -> 0', 'hiv40-44NCQs': 'Recorded Value (40-44 yrs) -> 0', 'hiv45-49NCQs': 'Recorded Value (45-49 yrs) -> 0', 'hiv50NCQs': 'Recorded Value (50+ yrs) -> 0', 'hivNegativeNC15-19': '3', 'hivNegativeNC15-19 ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 9375, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/c25adc25-ba6f-439a-aeea-1460e1d998bd/form.xml'}}, 'build_id': 'efa7db7ec2de40d992ece6f57faf7a00', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '485', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '2'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-24T14:07:29.605000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Gaha Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'March', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '0', 'currentFacilityAlias': 'Gaha ClinicMarch2025', 'facilityName': 'Gaha Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period March 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Gaha ClinicMarch2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv15-19calculated': 'Default Value', 'hiv20-24calculated': 'Default Value', 'hiv25-29calculated': 'Default Value', 'hiv30-34calculated': 'Default Value', 'hiv35-39calculated': 'Default Value', 'hiv40-44calculated': 'Default Value', 'hiv45-49calculated': 'Default Value', 'hiv50calculated': 'Default Value', 'hivNegative15-19Qst': '', 'hivNegative15-19Validation': 'Input must be equal to or less than the total MCs in the  age group 15-19 yrs which e ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 9244, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/0a635e98-b1fb-45c1-a073-f8f2c329d930/form.xml'}}, 'build_id': 'dc085815a3cd438599b867b415352abb', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '444', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '11'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-20T14:02:24.643000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Sandawana Clinic', 'formType': 'correction', 'mc15-19calculated': '10', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Sandawana ClinicFebruary2025', 'facilityName': 'Sandawana Clinic', 'facilityValidation': 'This facility has not data recorded  for the time period February 2025', 'mc15-19calculated': '10', 'mc20-24calculated': '5', 'mc25-29calculated': '3', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025Sandawana ClinicFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'correction'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '11', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '8', 'totalhivNegative': '11'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '11', 'shangring_by_age': {'initialsh15-19': '0', 'initialsh20-24': '0', 'initialsh25-29': '1', 'initialsh30-34': '0', 'initial ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7359, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/2194c18e-f321-4eec-bb02-c48ef76a1955/form.xml'}}, 'build_id': 'dc085815a3cd438599b867b415352abb', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '444', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '12', 'fu20-24': '2'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-20T10:36:00.442000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Gaha Clinic', 'formType': 'submission', 'mc15-19calculated': '2', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Gaha ClinicFebruary2025', 'facilityName': 'Gaha Clinic', 'facilityValidation': 'The chosen Facility  was already recorded for the time period February 2025 Choose a facility not yet recorded in the Server', 'mc15-19calculated': '2', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Gaha ClinicFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'hivNegative20-24': '2', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '14'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '14', 'surgical_disposable': {'initialsg15-19': '0', 'initialsg20-24': '0', 'initialsg25-29': '0', 'initialsg ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7181, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/c7f34cdd-ba34-4361-8e47-2c46235a5fb4/form.xml'}}, 'build_id': 'dc085815a3cd438599b867b415352abb', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '444', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '3'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-20T10:12:05.767000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Chiedza Clinic', 'formType': 'correction', 'mc15-19calculated': '2', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'countofFacilityinReportedData': '1', 'currentFacilityAlias': 'Chiedza ClinicFebruary2025', 'facilityName': 'Chiedza Clinic', 'facilityValidation': 'This facility has not data recorded  for the time period February 2025', 'mc15-19calculated': '2', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'correction'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '3', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '3'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '3', 'surgical_disposable': {'initialsg15-19': '0', 'initialsg20-24': '0', 'initialsg25-29': '0', 'initialsg30-34': '0', 'initialsg35-39': '0', 'initialsg40-44': '0', 'initialsg45-49': '0', 'initialsg50': '0', 'question2': 'OK', 'sgDisposab ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7162, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/32ba936c-b37b-40d0-b916-21b1629fa494/form.xml'}}, 'build_id': '19ea5902541d4e97b97a0cf7bd371d82', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '432', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '6', 'fu20-24': '7'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-20T08:23:25.795000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Mnene Hospital', 'formType': 'correction', 'mc15-19calculated': '5', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '2'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '2', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '1', 'total_mcs_referred_for_sti_services': '1'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': 'false', 'currentFacilityAlias': 'Mnene HospitalFebruary2025', 'facilityName': 'Mnene Hospital', 'mc15-19calculated': '5', 'mc20-24calculated': '8', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025Mnene HospitalFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'correction'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '6', 'hivNegative20-24': '7', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '13'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '13', 'surgical_disposable': {'copy-1-of-question2': 'OK', 'initialsg15-19': '5', 'initialsg20-24': '8', 'initialsg25-29': '0', 'initialsg30-34': '0', 'initialsg35-39': '0', 'initialsg40-44': '0', 'initialsg45-49': '0', 'initialsg50': '0', 'question2': 'OK', 'sgDisposable15-19': '6', 'sgDisposable20-24': '7', 'total_surgicalDisposable': 'OK'}, 'total50ByMethod': '', 'totalShangring ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 7198, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/57b44682-a513-4660-a001-9f438c8949cc/form.xml'}}, 'build_id': '19ea5902541d4e97b97a0cf7bd371d82', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '432', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '3', 'fu20-24': '2', 'fu25-29': '1'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-20T07:31:04.243000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Chiedza Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Chiedza ClinicFebruary2025', 'facilityName': 'Chiedza Clinic', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025Chiedza ClinicFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '3', 'hivNegative20-24': '2', 'hivNegative25-29': '1', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '0', 'totalhivNegative': '6'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '6', 'surgical_disposable': {'initialsg15-19': 'Default Value', 'initialsg20-24': 'Default Value', 'initialsg25-29': 'Default Value', 'initialsg30-34': 'Default Value', 'initialsg35-39': 'Default Value', 'initialsg40-44': 'Default Value', 'initialsg45-49': 'Default Value', 'initialsg50': 'Default Value', 'sgDisposable15-19': '3', 'sgDisposable20-24': '2', 'sgDisposable25-29 ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 8057, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/25c511a6-9122-4aea-aebb-88ea8e55c81c/form.xml'}}, 'build_id': '19ea5902541d4e97b97a0cf7bd371d82', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '432', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '10'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-20T07:28:50.435000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Mnene Hospital', 'formType': 'submission', 'mc15-19calculated': '5', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '1'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '6', 'total_hiv_positive_linked_to_care': '1'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '2', 'total_mcs_referred_for_sti_services': '2'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Mnene HospitalFebruary2025', 'facilityName': 'Mnene Hospital', 'mc15-19calculated': '5', 'mc20-24calculated': '8', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025Mnene HospitalFebruary2025'}, 'copy-2-of-grpHTS': {'hiv_negativeList': {'hivNegativeNC15-19': '2', 'hivNegativeNC20-24': '1', 'hivNegativeNC25-29': '0', 'hivNegativeNC30-34': '0', 'hivNegativeNC35-39': '0', 'hivNegativeNC40-44': '0', 'hivNegativeNC45-49': '0', 'hivNegativeNC50': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositiveNC15-19': '1', 'hivPositiveNC20-24': '0', 'hivPositiveNC25-29': '0', 'hivPositiveNC30-34': '0', 'hivPositiveNC35-39': '0', 'hivPositiveNC40-44': '0', 'hivPositiveNC45-49': '0', 'hivPositiveNC50': '0', 'total15-19NCHIVTested': '3', 'total20-24NCHIVTested': '1', 'total25-29NCHIVTested': '0', 'total30-34NCHIVTested': '0', 'total35-39NCHIVTested': '0', 'total40-44NCHIVTested': '0', 'total45-49NCHIVTested': '0', 'total50NCHIVTested': '0', 'total_surgicalReusable': 'OK'}, 'totalHIVPositiveNC': '1', 'totalhivNegativeNC': '3', 'uncircumcisedClientsForHTS': '1'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '12', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'total15-19HIVTested': '', 'total20-24HIVTested': '', 'total25-29HIVTested': '', 'total30-34HIVTested': '', 'total35-39 ...
# {'app_id': '829256a8e54a410eb4c2f3eeca4e65e5', 'archived': False, 'attachments': {'form.xml': {'content_type': 'text/xml', 'length': 8824, 'url': 'https://zdip.zimttech.org/a/zdip-qa/api/form_attachment/v1/6a554179-5485-4e6b-8999-156591db7ae3/form.xml'}}, 'build_id': '2d9873f8f63040a889dcde2e638ec3a3', 'domain': 'zdip-qa', 'edited_by_user_id': None, 'edited_on': None, 'form': {'#type': 'data', '@name': 'ZAZIC VMMC Data Collection Form', '@uiVersion': '1', '@version': '429', '@xmlns': 'http://openrosa.org/formdesigner/2C62E5DB-A039-4F7E-A378-25101817B038', 'client_follow-upGRP': {'follow-up_by_age_disaggregation': {'copy-1-of-mcs_by_age_disaggregations': 'OK', 'followUpTotal': '', 'fu15-19': '10', 'fu20-24': '5', 'fu25-29': '2'}}, 'commcare_usercase': {'case': {'@case_id': 'bb29df93297446d99460cc39ccfc527e', '@date_modified': '2025-03-19T14:50:03.314000Z', '@user_id': '148b582ced074b30a11c93abdad751e5', '@xmlns': 'http://commcarehq.org/case/transaction/v2', 'update': {'facilityName': 'Sandawana Clinic', 'formType': 'submission', 'mc15-19calculated': 'Default Value', 'recordingMonth': 'February', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025'}}}, 'copy-1-of-grpHTS': {'kpLinkagesList': {'high_risk_referrals_to_care': '0'}, 'linkages_due_to_hiv_test_results': {'total_hiv_negative_linked_to_prep': '0', 'total_hiv_positive_linked_to_care': '0'}, 'referralToOtherServices': '0', 'referrals_to_sti_and_srh_services': {'total_mcs_referred_for_srh_services': '0', 'total_mcs_referred_for_sti_services': '0'}}, 'copy-1-of-location_details': {'checkifFacilityHasBeenSaved': '0', 'currentFacilityAlias': 'Sandawana ClinicFebruary2025', 'facilityName': 'Sandawana Clinic', 'mc15-19calculated': 'Default Value', 'mc20-24calculated': '0', 'mc25-29calculated': '0', 'mc30-34calculated': '0', 'mc35-39calculated': '0', 'mc40-44calculated': '0', 'mc45-49calculated': '0', 'mccalculated50': '0', 'savedFacilities': 'Kezi,MbembeswanaNatisaBeula,SankonjanaOct2024NatisaOct2024KeziOct2024Maphisa HospitalOctober2024BeulaOctober2024SankonjanaOctober2024BeulaNovember2024BeulaSeptember2024BeulaMay2024MbembeswanaSeptember2024NatisaSeptember2024Maphisa HospitalSeptember2024KeziSeptember2024SankonjanaSeptember2024KeziOctober2024MbembeswanaOctober2024MbembeswanaNovember2024KeziDecember2024SankonjanaDecember2024BeulaJanuary2025MbembeswanaJanuary2025BeulaFebruary2025Sandawana ClinicFebruary2025'}, 'copy-2-of-grpHTS': {'totalHIVPositiveNC': '0', 'totalhivNegativeNC': '0', 'uncircumcisedClientsForHTS': '0'}, 'formSubmissionList': {'formType': 'submission'}, 'grpHTS': {'hiv_negativeList': {'hivNegative15-19': '0', 'hivNegative20-24': '0', 'hivNegative25-29': '0', 'total_surgicalDisposable': 'OK'}, 'hiv_positiveList': {'hivPositive15-19': '0', 'hivPositive20-24': '0', 'hivPositive25-29': '0', 'total15-19HIVTested': '0', 'total20-24HIVTested': '0', 'total25-29HIVTested': '0', 'total30-34HIVTested': '', 'total35-39HIVTested': '', 'total40-44HIVTested': '', 'total45-49HIVTested': '', 'total50HIVTested': '', 'total_surgicalReusable': 'OK'}, 'totalHIVPositive': '0', 'totalHIVUntested': '18', 'totalhivNegative': '0'}, 'grpMCBYMethod': {'TotalMCsBYMethod': '18', 'shangring_by_age': {'copy-2-of-question1': 'OK', 'initialsh15-19': 'Default Value', 'initialsh20-24': 'Default Value', 'initialsh25-29': 'Default Value', 'initialsh30-34': 'Default Value', 'initialsh35-39': 'Default Value', 'initialsh40-44': 'Default Value', 'initialsh45-49': 'Default Value', 'initialsh50': 'Default Value', 'sh15-19Question': '', 'sh20-24Question': '', 'sh25-29Questio ...

# %%
# New columns that should NOT be deleted
columns_to_retain = [
    'AERecordingMonth', 'AERecordingSite', 'AERecordingYear', 'aeComments', 'ae_classification', 
    'ae_type_code', 'checkMonthValidation', 'checkYearValidation', 'circumcising_cadre', 'client_age', 
    'date_ae_identified', 'mcMethod', 'vmmc_number', 'followUpTotal', 'recordingMonth', 
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'reason_for_referral', 'services_referred', 'facilityName', 
    'District', 'recordingMonth', 'year', 'totalAES','adverse_events', 'Site_Name', 'totalReferralstoOtherServices','formType',
    'received_on','ageGroupsChange','selectedHTSAgeGroups'
]

# Columns that must be numeric (including the new ones)
numeric_columns = [
    'client_age', 'fu15-19', 'fu20-24', 'fu25-29', 'fu30-34', 'fu40-44', 'fu50',
    'total_hiv_negative_linked_to_prep', 'total_hiv_positive_linked_to_care', 'referralToOtherServices',
    'total_mcs_referred_for_srh_services', 'total_mcs_referred_for_sti_services', 'checkifFacilityHasBeenSaved',
    'hivNegativeNC15-19', 'hivNegativeNC20-24', 'hivNegativeNC25-29', 'hivNegativeNC30-34', 'hivNegativeNC35-39', 
    'hivNegativeNC40-44', 'hivNegativeNC45-49', 'hivNegativeNC50', 'total_surgicalDisposable', 'hivPositive30-34',
    'hivPositiveNC15-19', 'hivPositiveNC20-24', 'hivPositiveNC25-29', 'hivPositiveNC35-39', 'hivPositiveNC40-44',
    'hivPositiveNC45-49', 'hivPositiveNC50', 'total15-19NCHIVTested', 'total20-24NCHIVTested', 'total25-29NCHIVTested',
    'total30-34NCHIVTested', 'total35-39NCHIVTested', 'total40-44NCHIVTested', 'total45-49NCHIVTested', 
    'total50NCHIVTested', 'total_surgicalReusable', 'totalHIVPositiveNC', 'totalhivNegativeNC', 
    'uncircumcisedClientsForHTS', 'hivNegative15-19', 'hivNegative20-24', 'hivNegative25-29', 'hivNegative30-34', 
    'hivNegative40-44', 'hivNegative50', 'total_surgicalDisposable', 'hivPositive15-19', 'hivPositive20-24','hivPositive25-29',
    'hivPositive30-34','hivPositive35-39','hivPositive40-44','hivPositive45-49','hivPositive50',
    'total15-19HIVTested', 'total20-24HIVTested', 'total25-29HIVTested', 'total30-34HIVTested', 'total35-39HIVTested',
    'total40-44HIVTested', 'total45-49HIVTested', 'total50HIVTested', 'total_surgicalReusable', 'totalHIVPositive',
    'totalHIVUntested', 'totalhivNegative', 'TotalMCsBYMethod', 'sgDisposable15-19', 'sgDisposable20-24', 
    'sgDisposable25-29', 'sgDisposable30-34', 'sgDisposable40-44', 'sgDisposable50', 'total_surgicalDisposable',
    'sgReusable15-19', 'sgReusable20-24', 'sgReusable25-29', 'sgReusable30-34', 'sgReusable40-44', 'sgReusable50',
    'total_surgicalReusable', 'total50ByMethod', 'totalShangringMCs', 'totalSurgicalDisposableMCs', 
    'totalSurgicalReusableMCs', 'mc15-19', 'mc20-24', 'mc25-29', 'mc30-34', 'mc35-39', 'mc40-44', 'mc45-49', 
    'mc50', 'totalMCs', 'fu35-39', 'other_referrals_in_detail', 'total_mcs_referred_to_other_services', 
    'hivNegative35-39', 'sgDisposable35-39', 'sgReusable35-39', 'shangring15-19', 'shangring20-24','shangring25-29', 'shangring30-34',
    'shangring35-39', 'shangring40-44','shangring45-49','shangring50', 'fu45-49', 
    'hivNegative45-49', 'sgDisposable45-49', 'sgReusable45-49','AERecordingYear','high_risk_referrals_to_care'
]

# general_df['AERecordingYear'] = pd.to_numeric(general_df['AERecordingYear'])
# Combine the two lists (retain columns that are in either columns_to_retain or numeric_columns)
columns_to_keep = list(set(columns_to_retain + numeric_columns))

# Identify missing columns
missing_columns = [col for col in columns_to_keep if col not in general_df.columns]

# %%
# Add missing columns to the DataFrame and assign zero
for col in missing_columns:
    general_df[col] = 0

# Drop the columns that are not in the columns_to_keep list
# Sort the columns alphabetically in both DataFrames

# For the 'general_df', sort the columns alphabetically
general_df_sorted = general_df[sorted(general_df[columns_to_keep])]

# For the AE-specific columns, we can do the same
ae_columns = [
    'aeComments', 'ae_type_code', 'date_ae_identified', 'AERecordingYear', 'AERecordingSite', 
    'client_age', 'circumcising_cadre', 'ae_classification', 'AERecordingMonth', 'mcMethod','vmmc_number'
]


referrals_columns =['ReferrelRecordingMonth', 
    'ReferrelRecordingSite', 'ReferrelRecordingYear', 'services_referred','reason_for_referral']



other_referrals = []
ae_data_df_sorted = general_df[ae_columns][sorted(ae_columns)]
ae_data_df_sorted = ae_data_df_sorted[ae_data_df_sorted['AERecordingMonth'].notna()]

referralsDF_sorted = general_df[referrals_columns][sorted(referrals_columns)]
referralsDF_sorted = referralsDF_sorted[referralsDF_sorted['ReferrelRecordingMonth'].notna()]

# %%
# Function to flatten the nested referral data
def flatten_referral_data(referral_list):
    flattened_referrals = []
    
    # Loop through each referral in the list
    for referral in referral_list:
        flattened_referral = {}
        
        # Flatten the first level of referral data
        for key, value in referral.items():
            if isinstance(value, dict):
                # If the value is a nested dictionary, flatten it
                for nested_key, nested_value in value.items():
                    flattened_referral[f"{key}_{nested_key}"] = nested_value
            else:
                flattened_referral[key] = value
        
        flattened_referrals.append(flattened_referral)
    
    return flattened_referrals



# Function to unpack nested 'question1_question5' field
def unpack_detailedField(df, column):
    if column  in df.columns:
        # Unpack the dictionary inside 'question1_question5' into separate columns
        question_fields = df[column].apply(pd.Series)
        
        # Merge the unpacked fields back into the main DataFrame
        df = pd.concat([df, question_fields], axis=1)
        
        # Drop the original 'question1_question5' column if no longer needed
        df.drop(column, axis=1, inplace=True)
    
    return df

# %%
# Extract the referrals from 'other_referrals_in_detail' column referrals_data = []
singleReferrals =[]
# Loop through each row and check if 'other_referrals_in_detail' is a valid list
for idx, row in general_df.iterrows():
    referral_list = row['other_referrals_in_detail']
    
    # Check if the value is a list and not NaN
    if isinstance(referral_list, list):
        # Flatten the referral data
        flattened_referrals = flatten_referral_data(referral_list)
        for ref in flattened_referrals:
            ref['District'] = row['District']  # Add the District to each referral record
            referrals_data.append(ref)
    else:
        # Handle cases where referral_list is not valid
        if not pd.isna(row['ReferrelRecordingMonth']):  # Check if 'ReferrelRecordingMonth' is not NaN
            _object = {
                'ReferrelRecordingMonth': row['ReferrelRecordingMonth'], 
                'ReferrelRecordingSite': row['ReferrelRecordingSite'], 
                'ReferrelRecordingYear': row['ReferrelRecordingYear'],
                'District': row['District'],
                'reason_for_referral':row['reason_for_referral'],
                'services_referred':row['services_referred']
            }
            singleReferrals.append(_object)

# %%
aes_data =[]
singleAEs = []
for idx, row in general_df.iterrows():
    ae_list = row['adverse_events']
    
    # Check if the value is a list and not NaN
    if isinstance(ae_list, list) and not pd.isna(ae_list).any():  # Use .any() to check the entire list
        flattened_aes = flatten_referral_data(ae_list)
        for ref in flattened_aes:
            ref['District'] = row['District']  # Add the District to each referral record
            aes_data.append(ref)

    else:
        if not pd.isna(row['AERecordingMonth']):
            _object = {
                'AERecordingMonth':row['AERecordingMonth'],
                'AERecordingSite':row['AERecordingSite'],
                'AERecordingYear':row['AERecordingYear'],
                'District':row['District'],
                'aeComments':row['aeComments'],
                'ae_classification':row['ae_classification'],
                'ae_type_code':row['ae_type_code'],
                'circumcising_cadre':row['circumcising_cadre'],
                'client_age':row['client_age'],
                'date_ae_identified':row['date_ae_identified'],
                'mcMethod':row['mcMethod'],
                'vmmc_number':row['vmmc_number']
            }
            singleAEs.append(_object)

# %%
# Convert the flattened referrals data into a DataFrame

referrals_df = pd.DataFrame(referrals_data)

# convert the flattened aes data into a df

ae_df = pd.DataFrame(aes_data)

# Unpack the 'question1_question5' field
referrals_df = unpack_detailedField(referrals_df,'question1_question5')

ae_df = unpack_detailedField(ae_df,'question3_question1')

ae_df = unpack_detailedField(ae_df,'question1')

ae_df = ae_df.rename(columns={
    'question3_AERecordingMonth': 'AERecordingMonth',
    'question3_AERecordingSite': 'AERecordingSite',
    'question3_AERecordingYear': 'AERecordingYear'
})

print(ae_df)

if len(singleReferrals)>0:
    tempRefDF = pd.DataFrame(singleReferrals)
    referrals_df = pd.concat([referrals_df,tempRefDF])

if len(singleAEs)>0:
    tempRefDF = pd.DataFrame(singleAEs)
    ae_df = pd.concat([ae_df,tempRefDF])


if not referrals_df.empty:
    try:
        referrals_df = referrals_df.drop(columns = ['question1_cancelthisReferralReport',0]).drop_duplicates()
    except:
        pass

if not ae_df.empty:
    try:
        ae_df = ae_df.drop(columns = ['checkMonthValidation','checkYearValidation']).drop_duplicates()
    except:
        pass

general_df_sorted = general_df_sorted.drop(columns =['adverse_events','other_referrals_in_detail']).drop_duplicates()


zazicSites_unique = zazicSites.drop_duplicates(subset='facilityName')


general_df_sorted = general_df_sorted.loc[:, ~general_df_sorted.columns.duplicated(keep='last')]

# Merge to bring in facilityType from zazicSites_unique
general_df_sorted = general_df_sorted.merge(zazicSites_unique[['facilityName', 'facilityType']], 
                                            on='facilityName', 
                                            how='left')

columns_to_exclude = ['selectedHTSAgeGroups', 'ageGroupsChange']
# Fill other columns with 0
general_df_sorted.loc[:, [col for col in general_df_sorted.columns if col not in columns_to_exclude]] = (
    general_df_sorted.loc[:, [col for col in general_df_sorted.columns if col not in columns_to_exclude]].fillna(0)
)

# Fill excluded columns with the string "0"
general_df_sorted.loc[:, columns_to_exclude] = general_df_sorted.loc[:, columns_to_exclude].fillna("0")
# df_filtered= general_df_sorted[~(
#     (general_df_sorted.duplicated(subset=['facilityName', 'recordingMonth', 'year'], keep=False)) &
#     (general_df_sorted['formType'] == 'submission')
# )]

# # Step 2: If multiple 'correction' rows exist, keep the one with the latest 'received_on'
# general_df_sorted = df_filtered.loc[
#     df_filtered.groupby(['facilityName', 'recordingMonth', 'year'])['received_on'].idxmax()
# ]

# Step 1: Identify the latest 'correction' row for each facilityName, recordingMonth, and year
latest_correction_idx = general_df_sorted[general_df_sorted['formType'] == 'correction'].groupby(['facilityName', 'recordingMonth', 'year'])['received_on'].idxmax()

latest_corrections = general_df_sorted.loc[latest_correction_idx]

latest_corrections.to_excel("recentCorrections.xlsx")

# Define the age groups you're interested in
age_groups = ['15-19_yrs', '20-24_yrs', '25-29_yrs', '30-34_yrs', '35-39_yrs', '40-44_yrs', '45-49_yrs', '50+_yrs']

# Columns to update for each age group
columns_to_update = ['mc', 'sgDisposable', 'sgReusable', 'shangring']
secondary_columns_to_update = ['hivPositive', 'hivNegative']

# DataFrame to store the final results
final_df = general_df_sorted.copy()

# Step 1: Iterate through submission rows
for idx, row in general_df_sorted[general_df_sorted['formType'] == 'submission'].iterrows():
    facility, month, year = row['facilityName'], row['recordingMonth'], row['year']

    # Step 2: Find corresponding correction row
    correction_row = latest_corrections[
        (latest_corrections['facilityName'] == facility) &
        (latest_corrections['recordingMonth'] == month) &
        (latest_corrections['year'] == year)
    ]

    if not correction_row.empty:  # If a correction row exists
        # Step 3: Check if a row exists in lookupTable
        lookup_match = lookupTable[
            (lookupTable['facilityName'] == facility) &
            (lookupTable['recordingMonth'] == month) &
            (lookupTable['year'] == year)
        ]

        if not lookup_match.empty:  
            # Apply corrections to lookupTable row instead of submission row
            target_idx = lookup_match.index[0]  # Get index of matched row
            target_df = lookupTable  # Apply updates to lookupTable
            
            # Step 4: Update the matched row in lookupTable
            age_groups_change = correction_row['ageGroupsChange'].values[0]
            selected_hta_groups = correction_row['selectedHTSAgeGroups'].values[0]
            print(age_groups_change)
            print(selected_hta_groups)

        

        
            
            for age_group in age_groups:
                if age_group in age_groups_change:
                    for column_prefix in columns_to_update:
                        column_name = f'{column_prefix}{age_group.split("_")[0]}'
                        target_df.at[target_idx, column_name] = correction_row[column_name].values[0]
                
                if age_group in selected_hta_groups:
                    for column_prefix in secondary_columns_to_update:
                        column_name = f'{column_prefix}{age_group.split("_")[0]}'
                        target_df.at[target_idx, column_name] = correction_row[column_name].values[0]
            
            # Remove the submission row from final dataframe
            final_df.drop(index=idx, inplace=True)

            # Add the updated row from lookupTable to final dataframe
            final_df = pd.concat([final_df, lookupTable.loc[[target_idx]]], ignore_index=True)
        
        else:
            # No match in lookupTable, apply changes to the original submission row
            age_groups_change = correction_row['ageGroupsChange'].values[0]
            selected_hta_groups = correction_row['selectedHTSAgeGroups'].values[0]

            print( f"{age_groups_change} ,'ageGrpoups'")
            print(f"{selected_hta_groups} , 'hts' ")
            for age_group in age_groups:
                if age_group in age_groups_change:
                    for column_prefix in columns_to_update:
                        column_name = f'{column_prefix}{age_group.split("_")[0]}'
                        final_df.at[idx, column_name] = correction_row[column_name].values[0]

                if age_group in selected_hta_groups:
                    for column_prefix in secondary_columns_to_update:
                        column_name = f'{column_prefix}{age_group.split("_")[0]}'
                        final_df.at[idx, column_name] = correction_row[column_name].values[0]
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# 15-19_yrs ,'ageGrpoups'
# 0 , 'hts'
# 15-19_yrs 20-24_yrs ,'ageGrpoups'
# 15-19_yrs 20-24_yrs , 'hts'
# 15-19_yrs ,'ageGrpoups'
# 0 , 'hts'

# %%
# Step 5: Remove correction rows from final dataframe
final_df = final_df[final_df['formType'] != 'correction']

# Reset index to maintain consistency
final_df.reset_index(drop=True, inplace=True)


# Now save the DataFrame to Excel
with pd.ExcelWriter('data.xlsx', engine='xlsxwriter') as writer:
    # Save the sorted general data to the first sheet
    final_df.drop_duplicates().to_excel(writer, sheet_name='Statistics', index=False)
    
    # Save the sorted AE data to a new sheet
    ae_df.drop_duplicates().to_excel(writer, sheet_name='AEs', index=False)
    
    # Save the flattened referrals data to a new sheet
    referrals_df.drop_duplicates().to_excel(writer, sheet_name='Referrals', index=False)

# %%
final_df
